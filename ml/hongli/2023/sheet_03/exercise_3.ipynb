# %% [markdown]
# # Task 1

# %%
path = "../../original_files/exercises/Sheet 3/data/dat.csv"

with open(path,'r') as f:
    print(f.read())
# Out:
# "","x1","x2"
# "1",1.1,6.5
# "2",2.1,6.5
# "3",2.1,5.5
# "4",1.1,4.5
# "5",2.1,3.5
# "6",-0.9,-2.5
# "7",-1.9,-4.5
# "8",-0.9,-5.5
# "9",-2.9,-6.5
# "10",-1.9,-7.5

# %% [markdown]
# https://www.geo.fu-berlin.de/en/v/soga-py/Advanced-statistics/Multivariate-Approaches/Principal-Component-Analysis/PCA-in-Python/index.html

# %%
import numpy as np

data = np.loadtxt(path, delimiter=',', skiprows=1, usecols=(1,2))

# Additional normalization step. Here we use unbiased estimation
# data = (data - data.mean(axis=0))/data.std(axis=0, ddof=1)

def PCA (data):
    # Covariance calculation
    centered_data = data - np.mean(data, axis=0)
    cov = 1/(data.shape[0]-1) * centered_data.T @ centered_data
    # eigenvalues and eigenvectors(loadings)
    eigenvalues, loadings = np.linalg.eigh(cov)
    print(loadings)
    # sort the values
    idx = eigenvalues.argsort()[::-1]
    eigenvalues = eigenvalues[idx]; loadings = loadings[:,idx]
    print(eigenvalues)
    # The score is the transformed data
    scores = data@loadings
    return scores, loadings, eigenvalues

scores, loadings, explained_variance = PCA(data)

# Load the PCA module in sklearn for comparison
from sklearn.decomposition import PCA as PCA_
pca = PCA_().fit(data)
# Out:
# [[-0.95438125  0.29859073]
#  [ 0.29859073  0.95438125]]
# [36.86141166  0.40525501]

# %%
# scores
print(scores)
pca.transform(data)
# Out:
# [[-1.19960652 -0.38596896]
#  [-1.56944177 -0.0161337 ]
#  [-1.44747443  0.10583364]
#  [-0.95567183 -0.14203427]
#  [-1.20353974  0.34976833]
#  [ 0.63777009 -0.02793337]
#  [ 1.25154003 -0.15383393]
#  [ 1.00367212  0.33796866]
#  [ 1.86530998 -0.2797345 ]
#  [ 1.61744207  0.2120681 ]]
# array([[-1.19960652,  0.38596896],
#        [-1.56944177,  0.0161337 ],
#        [-1.44747443, -0.10583364],
#        [-0.95567183,  0.14203427],
#        [-1.20353974, -0.34976833],
#        [ 0.63777009,  0.02793337],
#        [ 1.25154003,  0.15383393],
#        [ 1.00367212, -0.33796866],
#        [ 1.86530998,  0.2797345 ],
#        [ 1.61744207, -0.2120681 ]])

# %%
print(explained_variance)
pca.explained_variance_
# Out:
# [1.93724034 0.06275966]
# array([1.93724034, 0.06275966])

# %%
# The loadings are the eigenvectors of the covariance matrix
loadings
# Out:
# array([[-0.70710678,  0.70710678],
#        [-0.70710678, -0.70710678]])

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
fig, ax = plt.subplots(1,1)
ax.scatter(data.T[0], data.T[1], label = "Original normalized data")
ax.axline(xy1=(0,0), xy2=loadings[0], color = 'black', linestyle = 'dashed')
ax.axline(xy1=(0,0), xy2=loadings[1], color = 'black', linestyle = 'dashed')
# Plot an ellipse to represent the importance of each axis, the width and height are the standard deviation of each axis
ellipse = Ellipse((0,0), explained_variance[0]**0.5, explained_variance[1]**0.5, angle= -180/np.pi*np.arccos(loadings[1]@[0,1]), color = 'grey', alpha = 0.3)
ax.scatter(scores.T[0], scores.T[1], label = "Rotated data after PCA")
ax.add_artist(ellipse)

ax.legend()
ax.grid()
ax.axis('equal')
plt.show()

# %% [markdown]
# # Task 2 Multi-dimensional scaling
#
# Implement a PCoA (Classical multidimensional scaling, principal coordinates analysis) in two dimensions.
# Use the packages Scikit-Learn, Numpy, Matplotlib and the dataset eurodist.csv. Plot the results.

# %% [markdown]
# https://en.wikipedia.org/wiki/Multidimensional_scaling

# %%
from sklearn.manifold import MDS
path = "../../original_files/exercises/Sheet 3/data/eurodist.csv"

data = np.genfromtxt(path, delimiter=',')
data = np.delete(data, 0, axis = 0)
data = np.delete(data, 0, axis = 1)


pcoa = MDS(dissimilarity="precomputed", max_iter = 300, eps=1e-6, normalized_stress='auto')
pcoa.fit(data)
coordinates = pcoa.fit_transform(data)

# %%
pcoa.stress_
# Out:
# 3356497.366009377

# %%
cities = np.loadtxt(path, dtype=str, delimiter=",", usecols=(0), skiprows= 1)
# help(np.loadtxt)
cities = np.char.strip(cities, '"')
cities
# Out:
# array(['Athens', 'Barcelona', 'Brussels', 'Calais', 'Cherbourg',
#        'Cologne', 'Copenhagen', 'Geneva', 'Gibraltar', 'Hamburg',
#        'Hook of Holland', 'Lisbon', 'Lyons', 'Madrid', 'Marseilles',
#        'Milan', 'Munich', 'Paris', 'Rome', 'Stockholm', 'Vienna'],
#       dtype='<U17')

# %%
fig, ax = plt.subplots(1,1,figsize = (15,10))
ax.scatter(data[:, 0], data[:,1], label = "original (2D Athens-Barcelona representation)")
ax.scatter(coordinates[:, 0], coordinates[:, 1], label = "MDS(PCoA)")

for i, text in enumerate(cities):
    ax.annotate(text, (data[i,0], data[i,1]))
    ax.annotate(text, (coordinates[i,0], coordinates[i,1]))

ax.legend(loc = "lower left")
ax.grid()
plt.show()

# %% [markdown]
# Bonus: Is the implementation of MDS in Scikit-Learn a classic MDS (PCoA)? (With justification)

# %% [markdown]
# Yes. If the option "metric" is set as True.
#
# - The metric MDS takes a distance matrix as an input.
# - As shown above, the metric MDS maps the distance matrix to a 2-dimentional map.
# - Most importantly, the metric MDS preserves the distance between pair of features **as much as possible**:

# %%
for i in range(len(cities)):
    for j in range(i+1):
        print('Distance between {} and {}: '.format(cities[i], cities[j]))
        print('    Original: {}'.format(data[i,j]))
        print('    Euclidean after MDS: {}'.format(((coordinates[i,0] - coordinates[j,0])**2 + (coordinates[i,1] - coordinates[j,1])**2)**0.5))
# Out:
# Distance between Athens and Athens:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Barcelona and Athens:
#     Original: 3313.0
#     Euclidean after MDS: 3115.682643534531
# Distance between Barcelona and Barcelona:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Brussels and Athens:
#     Original: 2963.0
#     Euclidean after MDS: 2993.8104491916756
# Distance between Brussels and Barcelona:
#     Original: 1318.0
#     Euclidean after MDS: 1316.6054775836717
# Distance between Brussels and Brussels:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Calais and Athens:
#     Original: 3175.0
#     Euclidean after MDS: 3180.704866478495
# Distance between Calais and Barcelona:
#     Original: 1326.0
#     Euclidean after MDS: 1288.5460623532524
# Distance between Calais and Brussels:
#     Original: 204.0
#     Euclidean after MDS: 197.71395460071898
# Distance between Calais and Calais:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Cherbourg and Athens:
#     Original: 3339.0
#     Euclidean after MDS: 3427.747307786072
# Distance between Cherbourg and Barcelona:
#     Original: 1294.0
#     Euclidean after MDS: 1127.6014085147629
# Distance between Cherbourg and Brussels:
#     Original: 583.0
#     Euclidean after MDS: 538.3407497251904
# Distance between Cherbourg and Calais:
#     Original: 460.0
#     Euclidean after MDS: 358.2462085434248
# Distance between Cherbourg and Cherbourg:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Cologne and Athens:
#     Original: 2762.0
#     Euclidean after MDS: 2892.589156113442
# Distance between Cologne and Barcelona:
#     Original: 1498.0
#     Euclidean after MDS: 1529.5737164359907
# Distance between Cologne and Brussels:
#     Original: 206.0
#     Euclidean after MDS: 247.98800925292412
# Distance between Cologne and Calais:
#     Original: 409.0
#     Euclidean after MDS: 413.5699855713673
# Distance between Cologne and Cherbourg:
#     Original: 785.0
#     Euclidean after MDS: 770.9020528068526
# Distance between Cologne and Cologne:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Copenhagen and Athens:
#     Original: 3276.0
#     Euclidean after MDS: 3189.530012103693
# Distance between Copenhagen and Barcelona:
#     Original: 2218.0
#     Euclidean after MDS: 2227.294652304562
# Distance between Copenhagen and Brussels:
#     Original: 966.0
#     Euclidean after MDS: 911.540319588317
# Distance between Copenhagen and Calais:
#     Original: 1136.0
#     Euclidean after MDS: 983.5269620144868
# Distance between Copenhagen and Cherbourg:
#     Original: 1545.0
#     Euclidean after MDS: 1298.8968014646728
# Distance between Copenhagen and Cologne:
#     Original: 760.0
#     Euclidean after MDS: 708.451188830851
# Distance between Copenhagen and Copenhagen:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Geneva and Athens:
#     Original: 2610.0
#     Euclidean after MDS: 2585.839856678189
# Distance between Geneva and Barcelona:
#     Original: 803.0
#     Euclidean after MDS: 812.7698515044442
# Distance between Geneva and Brussels:
#     Original: 677.0
#     Euclidean after MDS: 723.2133273091061
# Distance between Geneva and Calais:
#     Original: 747.0
#     Euclidean after MDS: 814.1635646024436
# Distance between Geneva and Cherbourg:
#     Original: 853.0
#     Euclidean after MDS: 909.3945417985668
# Distance between Geneva and Cologne:
#     Original: 1662.0
#     Euclidean after MDS: 852.8046617859316
# Distance between Geneva and Copenhagen:
#     Original: 1418.0
#     Euclidean after MDS: 1554.566023869035
# Distance between Geneva and Geneva:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Gibraltar and Athens:
#     Original: 4485.0
#     Euclidean after MDS: 4214.997179063779
# Distance between Gibraltar and Barcelona:
#     Original: 1172.0
#     Euclidean after MDS: 1188.9172596322853
# Distance between Gibraltar and Brussels:
#     Original: 2256.0
#     Euclidean after MDS: 2305.3403201996243
# Distance between Gibraltar and Calais:
#     Original: 2224.0
#     Euclidean after MDS: 2200.0240081068137
# Distance between Gibraltar and Cherbourg:
#     Original: 2047.0
#     Euclidean after MDS: 1897.2494369987646
# Distance between Gibraltar and Cologne:
#     Original: 2436.0
#     Euclidean after MDS: 2548.7229398224677
# Distance between Gibraltar and Copenhagen:
#     Original: 3196.0
#     Euclidean after MDS: 3182.486996242155
# Distance between Gibraltar and Geneva:
#     Original: 1975.0
#     Euclidean after MDS: 1980.1454616665997
# Distance between Gibraltar and Gibraltar:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Hamburg and Athens:
#     Original: 2977.0
#     Euclidean after MDS: 2952.187423789008
# Distance between Hamburg and Barcelona:
#     Original: 2018.0
#     Euclidean after MDS: 1916.6329282309828
# Distance between Hamburg and Brussels:
#     Original: 597.0
#     Euclidean after MDS: 618.5059692257665
# Distance between Hamburg and Calais:
#     Original: 714.0
#     Euclidean after MDS: 736.1198596755534
# Distance between Hamburg and Cherbourg:
#     Original: 1115.0
#     Euclidean after MDS: 1084.051365994833
# Distance between Hamburg and Cologne:
#     Original: 460.0
#     Euclidean after MDS: 387.15145966169064
# Distance between Hamburg and Copenhagen:
#     Original: 460.0
#     Euclidean after MDS: 343.9827474028542
# Distance between Hamburg and Geneva:
#     Original: 1118.0
#     Euclidean after MDS: 1216.4705835137945
# Distance between Hamburg and Gibraltar:
#     Original: 2897.0
#     Euclidean after MDS: 2922.1035232387912
# Distance between Hamburg and Hamburg:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Hook of Holland and Athens:
#     Original: 3030.0
#     Euclidean after MDS: 3077.1361859103017
# Distance between Hook of Holland and Barcelona:
#     Original: 1490.0
#     Euclidean after MDS: 1539.0274635116405
# Distance between Hook of Holland and Brussels:
#     Original: 172.0
#     Euclidean after MDS: 226.8953250923014
# Distance between Hook of Holland and Calais:
#     Original: 330.0
#     Euclidean after MDS: 301.2403396242928
# Distance between Hook of Holland and Cherbourg:
#     Original: 731.0
#     Euclidean after MDS: 650.8600708745339
# Distance between Hook of Holland and Cologne:
#     Original: 269.0
#     Euclidean after MDS: 185.86448228661425
# Distance between Hook of Holland and Copenhagen:
#     Original: 269.0
#     Euclidean after MDS: 695.6211730632291
# Distance between Hook of Holland and Geneva:
#     Original: 895.0
#     Euclidean after MDS: 938.8548391545239
# Distance between Hook of Holland and Gibraltar:
#     Original: 2428.0
#     Euclidean after MDS: 2496.3032936420736
# Distance between Hook of Holland and Hamburg:
#     Original: 550.0
#     Euclidean after MDS: 435.14250844015385
# Distance between Hook of Holland and Hook of Holland:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Lisbon and Athens:
#     Original: 4532.0
#     Euclidean after MDS: 4390.27357422641
# Distance between Lisbon and Barcelona:
#     Original: 1305.0
#     Euclidean after MDS: 1275.2944149606835
# Distance between Lisbon and Brussels:
#     Original: 2084.0
#     Euclidean after MDS: 2060.856438117285
# Distance between Lisbon and Calais:
#     Original: 2052.0
#     Euclidean after MDS: 1915.8232338387593
# Distance between Lisbon and Cherbourg:
#     Original: 1827.0
#     Euclidean after MDS: 1571.6354044816653
# Distance between Lisbon and Cologne:
#     Original: 2290.0
#     Euclidean after MDS: 2308.50756473147
# Distance between Lisbon and Copenhagen:
#     Original: 2971.0
#     Euclidean after MDS: 2865.9839624944843
# Distance between Lisbon and Geneva:
#     Original: 1936.0
#     Euclidean after MDS: 1933.0209847413362
# Distance between Lisbon and Gibraltar:
#     Original: 676.0
#     Euclidean after MDS: 612.2824533537565
# Distance between Lisbon and Hamburg:
#     Original: 2671.0
#     Euclidean after MDS: 2651.5367660261254
# Distance between Lisbon and Hook of Holland:
#     Original: 2280.0
#     Euclidean after MDS: 2216.4036461922256
# Distance between Lisbon and Lisbon:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Lyons and Athens:
#     Original: 2753.0
#     Euclidean after MDS: 2777.717135138715
# Distance between Lyons and Barcelona:
#     Original: 645.0
#     Euclidean after MDS: 721.534520744964
# Distance between Lyons and Brussels:
#     Original: 690.0
#     Euclidean after MDS: 656.7583842379098
# Distance between Lyons and Calais:
#     Original: 739.0
#     Euclidean after MDS: 704.1595323067546
# Distance between Lyons and Cherbourg:
#     Original: 789.0
#     Euclidean after MDS: 741.9406978959432
# Distance between Lyons and Cologne:
#     Original: 714.0
#     Euclidean after MDS: 833.9155954074048
# Distance between Lyons and Copenhagen:
#     Original: 1458.0
#     Euclidean after MDS: 1542.0463638341148
# Distance between Lyons and Geneva:
#     Original: 158.0
#     Euclidean after MDS: 191.88096710178908
# Distance between Lyons and Gibraltar:
#     Original: 1817.0
#     Euclidean after MDS: 1850.1644751216852
# Distance between Lyons and Hamburg:
#     Original: 1159.0
#     Euclidean after MDS: 1216.0867930162663
# Distance between Lyons and Hook of Holland:
#     Original: 863.0
#     Euclidean after MDS: 882.8114153893832
# Distance between Lyons and Lisbon:
#     Original: 1178.0
#     Euclidean after MDS: 1764.7591801826647
# Distance between Lyons and Lyons:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Madrid and Athens:
#     Original: 3949.0
#     Euclidean after MDS: 3799.2828140794854
# Distance between Madrid and Barcelona:
#     Original: 636.0
#     Euclidean after MDS: 684.5888714377234
# Distance between Madrid and Brussels:
#     Original: 1558.0
#     Euclidean after MDS: 1625.9409843515875
# Distance between Madrid and Calais:
#     Original: 1550.0
#     Euclidean after MDS: 1516.5762707502379
# Distance between Madrid and Cherbourg:
#     Original: 1347.0
#     Euclidean after MDS: 1216.5979604351305
# Distance between Madrid and Cologne:
#     Original: 1764.0
#     Euclidean after MDS: 1871.0443735446636
# Distance between Madrid and Copenhagen:
#     Original: 2498.0
#     Euclidean after MDS: 2498.860407953119
# Distance between Madrid and Geneva:
#     Original: 1439.0
#     Euclidean after MDS: 1375.284377274295
# Distance between Madrid and Gibraltar:
#     Original: 698.0
#     Euclidean after MDS: 683.6279674714683
# Distance between Madrid and Hamburg:
#     Original: 2198.0
#     Euclidean after MDS: 2241.016753004173
# Distance between Madrid and Hook of Holland:
#     Original: 1730.0
#     Euclidean after MDS: 1813.5171893803197
# Distance between Madrid and Lisbon:
#     Original: 668.0
#     Euclidean after MDS: 590.9989448729477
# Distance between Madrid and Lyons:
#     Original: 1281.0
#     Euclidean after MDS: 1221.3621589821955
# Distance between Madrid and Madrid:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Marseilles and Athens:
#     Original: 2865.0
#     Euclidean after MDS: 2720.7243721030995
# Distance between Marseilles and Barcelona:
#     Original: 521.0
#     Euclidean after MDS: 495.426247387582
# Distance between Marseilles and Brussels:
#     Original: 1011.0
#     Euclidean after MDS: 976.0600264453043
# Distance between Marseilles and Calais:
#     Original: 1059.0
#     Euclidean after MDS: 1015.3413472112759
# Distance between Marseilles and Cherbourg:
#     Original: 1101.0
#     Euclidean after MDS: 996.2284581906678
# Distance between Marseilles and Cologne:
#     Original: 1035.0
#     Euclidean after MDS: 1146.2666219566624
# Distance between Marseilles and Copenhagen:
#     Original: 1778.0
#     Euclidean after MDS: 1854.558895450491
# Distance between Marseilles and Geneva:
#     Original: 425.0
#     Euclidean after MDS: 332.8700381291
# Distance between Marseilles and Gibraltar:
#     Original: 1693.0
#     Euclidean after MDS: 1680.8919652716568
# Distance between Marseilles and Hamburg:
#     Original: 1479.0
#     Euclidean after MDS: 1523.5063244469586
# Distance between Marseilles and Hook of Holland:
#     Original: 1183.0
#     Euclidean after MDS: 1201.9697401019218
# Distance between Marseilles and Lisbon:
#     Original: 1762.0
#     Euclidean after MDS: 1699.0989719629888
# Distance between Marseilles and Lyons:
#     Original: 320.0
#     Euclidean after MDS: 319.3141934140958
# Distance between Marseilles and Madrid:
#     Original: 1157.0
#     Euclidean after MDS: 1118.4243555993048
# Distance between Marseilles and Marseilles:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Milan and Athens:
#     Original: 2282.0
#     Euclidean after MDS: 2269.7901295560478
# Distance between Milan and Barcelona:
#     Original: 1014.0
#     Euclidean after MDS: 1061.5138691494983
# Distance between Milan and Brussels:
#     Original: 925.0
#     Euclidean after MDS: 878.060428161422
# Distance between Milan and Calais:
#     Original: 1077.0
#     Euclidean after MDS: 1018.7232058280546
# Distance between Milan and Cherbourg:
#     Original: 1209.0
#     Euclidean after MDS: 1185.647590017716
# Distance between Milan and Cologne:
#     Original: 911.0
#     Euclidean after MDS: 925.1840917949224
# Distance between Milan and Copenhagen:
#     Original: 1537.0
#     Euclidean after MDS: 1575.4174092272817
# Distance between Milan and Geneva:
#     Original: 328.0
#     Euclidean after MDS: 321.43152889830196
# Distance between Milan and Gibraltar:
#     Original: 2185.0
#     Euclidean after MDS: 2248.662108269383
# Distance between Milan and Hamburg:
#     Original: 1238.0
#     Euclidean after MDS: 1231.8166745939054
# Distance between Milan and Hook of Holland:
#     Original: 1098.0
#     Euclidean after MDS: 1059.6026938284529
# Distance between Milan and Lisbon:
#     Original: 2250.0
#     Euclidean after MDS: 2241.117781380894
# Distance between Milan and Lyons:
#     Original: 328.0
#     Euclidean after MDS: 511.6754717409258
# Distance between Milan and Madrid:
#     Original: 1724.0
#     Euclidean after MDS: 1672.6271755306075
# Distance between Milan and Marseilles:
#     Original: 618.0
#     Euclidean after MDS: 567.8190121689165
# Distance between Milan and Milan:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Munich and Athens:
#     Original: 2179.0
#     Euclidean after MDS: 2276.8971752506286
# Distance between Munich and Barcelona:
#     Original: 1365.0
#     Euclidean after MDS: 1451.6147509403793
# Distance between Munich and Brussels:
#     Original: 747.0
#     Euclidean after MDS: 718.1232472121352
# Distance between Munich and Calais:
#     Original: 977.0
#     Euclidean after MDS: 909.2357111244752
# Distance between Munich and Cherbourg:
#     Original: 1160.0
#     Euclidean after MDS: 1195.1492306321588
# Distance between Munich and Cologne:
#     Original: 583.0
#     Euclidean after MDS: 635.2697957660706
# Distance between Munich and Copenhagen:
#     Original: 1104.0
#     Euclidean after MDS: 1171.0609926585926
# Distance between Munich and Geneva:
#     Original: 591.0
#     Euclidean after MDS: 638.9185024551889
# Distance between Munich and Gibraltar:
#     Original: 2565.0
#     Euclidean after MDS: 2613.0751006006976
# Distance between Munich and Hamburg:
#     Original: 805.0
#     Euclidean after MDS: 838.4636449823154
# Distance between Munich and Hook of Holland:
#     Original: 851.0
#     Euclidean after MDS: 812.7087048471495
# Distance between Munich and Lisbon:
#     Original: 2507.0
#     Euclidean after MDS: 2519.1441400539225
# Distance between Munich and Lyons:
#     Original: 724.0
#     Euclidean after MDS: 766.8685287558806
# Distance between Munich and Madrid:
#     Original: 2010.0
#     Euclidean after MDS: 1987.443277494024
# Distance between Munich and Marseilles:
#     Original: 1109.0
#     Euclidean after MDS: 964.5500310058322
# Distance between Munich and Milan:
#     Original: 331.0
#     Euclidean after MDS: 469.3878119336707
# Distance between Munich and Munich:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Paris and Athens:
#     Original: 3000.0
#     Euclidean after MDS: 3041.5426932777164
# Distance between Paris and Barcelona:
#     Original: 1033.0
#     Euclidean after MDS: 1047.879747109356
# Distance between Paris and Brussels:
#     Original: 285.0
#     Euclidean after MDS: 279.82810242248416
# Distance between Paris and Calais:
#     Original: 280.0
#     Euclidean after MDS: 259.6732995605574
# Distance between Paris and Cherbourg:
#     Original: 340.0
#     Euclidean after MDS: 387.0876637434039
# Distance between Paris and Cologne:
#     Original: 465.0
#     Euclidean after MDS: 520.540962905338
# Distance between Paris and Copenhagen:
#     Original: 1176.0
#     Euclidean after MDS: 1187.300346167908
# Distance between Paris and Geneva:
#     Original: 513.0
#     Euclidean after MDS: 572.4736941079218
# Distance between Paris and Gibraltar:
#     Original: 1971.0
#     Euclidean after MDS: 2028.1970376323902
# Distance between Paris and Hamburg:
#     Original: 877.0
#     Euclidean after MDS: 898.1353072422486
# Distance between Paris and Hook of Holland:
#     Original: 457.0
#     Euclidean after MDS: 493.14963126665907
# Distance between Paris and Lisbon:
#     Original: 1799.0
#     Euclidean after MDS: 1804.9649049513328
# Distance between Paris and Lyons:
#     Original: 471.0
#     Euclidean after MDS: 446.6548497155708
# Distance between Paris and Madrid:
#     Original: 1273.0
#     Euclidean after MDS: 1350.930700369628
# Distance between Paris and Marseilles:
#     Original: 792.0
#     Euclidean after MDS: 755.7254488289341
# Distance between Paris and Milan:
#     Original: 856.0
#     Euclidean after MDS: 814.7580263190077
# Distance between Paris and Munich:
#     Original: 821.0
#     Euclidean after MDS: 815.1296587245473
# Distance between Paris and Paris:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Rome and Athens:
#     Original: 817.0
#     Euclidean after MDS: 1624.2149941132786
# Distance between Rome and Barcelona:
#     Original: 1460.0
#     Euclidean after MDS: 1508.142297197418
# Distance between Rome and Brussels:
#     Original: 1511.0
#     Euclidean after MDS: 1552.5775371045577
# Distance between Rome and Calais:
#     Original: 1662.0
#     Euclidean after MDS: 1709.4591183746948
# Distance between Rome and Cherbourg:
#     Original: 1794.0
#     Euclidean after MDS: 1885.5443644772863
# Distance between Rome and Cologne:
#     Original: 1497.0
#     Euclidean after MDS: 1545.2809080718953
# Distance between Rome and Copenhagen:
#     Original: 2050.0
#     Euclidean after MDS: 2095.761294285071
# Distance between Rome and Geneva:
#     Original: 995.0
#     Euclidean after MDS: 991.5854944071589
# Distance between Rome and Gibraltar:
#     Original: 2631.0
#     Euclidean after MDS: 2656.259950924311
# Distance between Rome and Hamburg:
#     Original: 1751.0
#     Euclidean after MDS: 1770.164103402473
# Distance between Rome and Hook of Holland:
#     Original: 1683.0
#     Euclidean after MDS: 1706.033496639806
# Distance between Rome and Lisbon:
#     Original: 2700.0
#     Euclidean after MDS: 2776.0175448895984
# Distance between Rome and Lyons:
#     Original: 1048.0
#     Euclidean after MDS: 1180.2363333373494
# Distance between Rome and Madrid:
#     Original: 2097.0
#     Euclidean after MDS: 2186.209795374655
# Distance between Rome and Marseilles:
#     Original: 1011.0
#     Euclidean after MDS: 1096.5315034140194
# Distance between Rome and Milan:
#     Original: 586.0
#     Euclidean after MDS: 700.91235580789
# Distance between Rome and Munich:
#     Original: 946.0
#     Euclidean after MDS: 933.8887384258528
# Distance between Rome and Paris:
#     Original: 1476.0
#     Euclidean after MDS: 1515.290790865558
# Distance between Rome and Rome:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Stockholm and Athens:
#     Original: 3927.0
#     Euclidean after MDS: 3709.6284299811205
# Distance between Stockholm and Barcelona:
#     Original: 2868.0
#     Euclidean after MDS: 2901.928219289726
# Distance between Stockholm and Brussels:
#     Original: 1616.0
#     Euclidean after MDS: 1590.0825491510807
# Distance between Stockholm and Calais:
#     Original: 1786.0
#     Euclidean after MDS: 1622.2234655897082
# Distance between Stockholm and Cherbourg:
#     Original: 2196.0
#     Euclidean after MDS: 1885.095770821553
# Distance between Stockholm and Cologne:
#     Original: 1403.0
#     Euclidean after MDS: 1409.376008955147
# Distance between Stockholm and Copenhagen:
#     Original: 650.0
#     Euclidean after MDS: 709.0831515702073
# Distance between Stockholm and Geneva:
#     Original: 2068.0
#     Euclidean after MDS: 2260.5386785267356
# Distance between Stockholm and Gibraltar:
#     Original: 3886.0
#     Euclidean after MDS: 3780.2008450957464
# Distance between Stockholm and Hamburg:
#     Original: 949.0
#     Euclidean after MDS: 1052.7694087595007
# Distance between Stockholm and Hook of Holland:
#     Original: 1500.0
#     Euclidean after MDS: 1364.5161711902351
# Distance between Stockholm and Lisbon:
#     Original: 3231.0
#     Euclidean after MDS: 3398.6222469377676
# Distance between Stockholm and Lyons:
#     Original: 2108.0
#     Euclidean after MDS: 2237.5342666094416
# Distance between Stockholm and Madrid:
#     Original: 3188.0
#     Euclidean after MDS: 3101.4551639339666
# Distance between Stockholm and Marseilles:
#     Original: 2428.0
#     Euclidean after MDS: 2553.597545386677
# Distance between Stockholm and Milan:
#     Original: 2187.0
#     Euclidean after MDS: 2282.4193795960837
# Distance between Stockholm and Munich:
#     Original: 1754.0
#     Euclidean after MDS: 1864.312034875326
# Distance between Stockholm and Paris:
#     Original: 1827.0
#     Euclidean after MDS: 1854.0587866469136
# Distance between Stockholm and Rome:
#     Original: 2707.0
#     Euclidean after MDS: 2772.272388365476
# Distance between Stockholm and Stockholm:
#     Original: 0.0
#     Euclidean after MDS: 0.0
# Distance between Vienna and Athens:
#     Original: 1991.0
#     Euclidean after MDS: 1912.9022109334735
# Distance between Vienna and Barcelona:
#     Original: 1802.0
#     Euclidean after MDS: 1847.9262901019708
# Distance between Vienna and Brussels:
#     Original: 1175.0
#     Euclidean after MDS: 1139.048515135131
# Distance between Vienna and Calais:
#     Original: 1381.0
#     Euclidean after MDS: 1336.0980251076937
# Distance between Vienna and Cherbourg:
#     Original: 1588.0
#     Euclidean after MDS: 1643.676057940332
# Distance between Vienna and Cologne:
#     Original: 937.0
#     Euclidean after MDS: 994.7440708032906
# Distance between Vienna and Copenhagen:
#     Original: 1455.0
#     Euclidean after MDS: 1321.8205986046758
# Distance between Vienna and Geneva:
#     Original: 1019.0
#     Euclidean after MDS: 1051.4866049224158
# Distance between Vienna and Gibraltar:
#     Original: 2974.0
#     Euclidean after MDS: 3028.894213218158
# Distance between Vienna and Hamburg:
#     Original: 1155.0
#     Euclidean after MDS: 1048.2837237405113
# Distance between Vienna and Hook of Holland:
#     Original: 1205.0
#     Euclidean after MDS: 1180.581938662763
# Distance between Vienna and Lisbon:
#     Original: 2937.0
#     Euclidean after MDS: 2967.44314208937
# Distance between Vienna and Lyons:
#     Original: 1157.0
#     Euclidean after MDS: 1204.4950622038764
# Distance between Vienna and Madrid:
#     Original: 2409.0
#     Euclidean after MDS: 2423.5461025843492
# Distance between Vienna and Marseilles:
#     Original: 1363.0
#     Euclidean after MDS: 1352.5203152717065
# Distance between Vienna and Milan:
#     Original: 898.0
#     Euclidean after MDS: 792.2997338701468
# Distance between Vienna and Munich:
#     Original: 428.0
#     Euclidean after MDS: 459.2806411856034
# Distance between Vienna and Paris:
#     Original: 1249.0
#     Euclidean after MDS: 1269.6414674317407
# Distance between Vienna and Rome:
#     Original: 1209.0
#     Euclidean after MDS: 891.8331583096337
# Distance between Vienna and Stockholm:
#     Original: 2105.0
#     Euclidean after MDS: 1943.534658382255
# Distance between Vienna and Vienna:
#     Original: 0.0
#     Euclidean after MDS: 0.0

# %% [markdown]
# # Task 3

# %% [markdown]
# a) Are there conditions under which the results of a PCA and a PCoA are equivalent? If so, what are
# they?

# %% [markdown]
# If the pairwise distance between features are defined as Euclidean distance, the results of a PCA and a PCoA are equivalent.

# %% [markdown]
# b) What options exist to determine a meaningful number of dimensions for a PCoA?

# %% [markdown]
# 1. We consider first low dimentional (1D, 2D or 3D) space for better visualization and understanding
#
# *"The minimal dimensionality for a perfect MDS representation is only of
# formal interest. In practice, we always try to represent the data in an MDS
# space of considerably lower dimensionality. The rationale for choosing a low
# dimensionality is the expectation that this will cancel out over- and under- estimation errors in the proximities, thus smoothing the representation (see
# Chapter 3). Moreover, a low-dimensional and preferably two-dimensional
# solution is often precise enough for a first interpretation. For the data in
# Table 4.1, we first try solutions in 1D, 2D, and 3D space (using the MDS
# module of Systat 5.0)."*
#
# -- *Modern Multidimensional Scaling Theory and Application*

# %% [markdown]
# 2. We may choose a dimensionality with both a low stress value and low dimension

# %%
for i in range(1,10):
    pcoa = MDS(n_components=i, n_init= 50, dissimilarity="precomputed", max_iter = 5000, eps=1e-6, normalized_stress='auto')
    pcoa.fit(data)
    print("{}D: ".format(i),pcoa.stress_)
# Out:
# 1D:  48721057.57142857
# 2D:  3356497.3660035618
# 3D:  2856447.1694908887
# 4D:  2755128.4853614043
# 5D:  2724579.6120780907
# 6D:  2721877.837305396
# 7D:  2721878.2053869623
# 8D:  2721885.872596871
# 9D:  2721889.6167773707

# %% [markdown]
# In our case, the 2D or 3D representation might be good for distance representation.

# %% [markdown]
# 3. Shepard diagram
#
# The shepard diagram shows the correlation between the pairwise input dissimilarities and the predicted distances. A clear positive correlation with a low dimension indicates a reasonable number of dimentions.

# %%
fig, ax = plt.subplots(5,1,figsize = (5,30))

for k in range(0, 5):
    pcoa = MDS(n_components=k+1, n_init= 1, dissimilarity="precomputed", max_iter = 5000, eps=1e-6, normalized_stress='auto')
    pcoa.fit(data)
    coordinates = pcoa.fit_transform(data)
    input_distance = []; output_distance = []
    for i in range(len(cities)):
        for j in range(i+1):
            input_distance.append(data[i,j])
            output_distance.append(np.dot(coordinates[i] - coordinates[j], coordinates[i] - coordinates[j])**0.5)

    ind = np.argsort(input_distance)
    input_distance = np.array(input_distance)[ind]
    output_distance = np.array(output_distance)[ind]
    ax[k].scatter(input_distance, output_distance, s=0.5)
    ax[k].set_xlabel('Observed dissimilarity')
    ax[k].set_ylabel('Ordination distance')
    ax[k].set_title('Shepard Diagram: {} dimentional'.format(k+1))
plt.show()

# %% [markdown]
# As the example shows, at dimention = 2, there is already a clear positive correlation.

# %% [markdown]
# # Exercise Class
# ## Task 1 PCA
#
# #### 1) mean normalization
# #### 2) calculating the cov matrix
# #### 3) calculate eigenvalues and eigenvector
# #### 4) calculate the principle components (dot product)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "../../original_files/exercises/Sheet 3/data/dat.csv"

data = pd.read_csv(path, index_col = 0)

# %%
def pca(df):
    df = df - df.mean()
    cov = df.cov()
    eigenvalues, eigenvectors = np.linalg.eig(cov)
    sorted_idx = eigenvalues.argsort()[::-1]

    eigenvalues = eigenvalues[sorted_idx]
    eigenvectors = eigenvectors[:, sorted_idx]

    scores = df.dot(eigenvectors)
    scores.columns = ["PC1", "PC2"]

    plt.scatter(df["x1"], df["x2"])
    plt.axis("equal")
    i = 1
    for vector in eigenvectors:
        plt.arrow(0,0, vector[0], vector[1], width = 0.1)
        plt.text(vector[0] + 0.03, vector[1] + 0.03, "PC{}".format(i))
        i+=1

# %%
pca(data)

# %% [markdown]
# Variance along an axis: variance of the projection of the points to the vector.
#
# Afterwards: we do dimensionality reduction

# %% [markdown]
# ## Task 2 PCoA

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.manifold.MDS.html
#
# stress value as loss function: not a classical MDS

# %%
path = "../../original_files/exercises/Sheet 3/data/eurodist.csv"
dataset = pd.read_csv(path, index_col=0)

# %% [markdown]
# random_state
#
# int, RandomState instance or None, default=None
# Determines the random number generator used to initialize the centers. Pass an int for reproducible results across multiple function calls. See Glossary.

# %%
from sklearn.manifold import MDS

def mds(df):
    mds = MDS(n_components = 2, dissimilarity = "precomputed", random_state=0)
    results = mds.fit_transform(df)
    plt.scatter(results.T[0], results.T[1])

    for i, txt in enumerate(df.index):
        plt.text(results[i][0], results[i][1], txt)

    plt.show()

# %%
mds(dataset)
# Out:
# /home/hongli/anaconda3/envs/APAlg/lib/python3.9/site-packages/sklearn/manifold/_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %% [markdown]
# ## Task 3
# b)
# explained variance
#
# SCREE-plot
