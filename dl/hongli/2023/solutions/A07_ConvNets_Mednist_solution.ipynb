# %% [markdown]
# HHU Deep Learning, WS2023/24, 24.11.2023
#
# Lecture: Prof. Dr. Markus Kollmann
#
# Exercises: Nikolas Adaloglou, Felix Michels
#
# # Assignment 7 - Convolutional Neural Networks in medical image classification
#
# ---
#
# Submit the solved notebook (not a zip) with your full name plus assignment number for the filename as an indicator, e.g `max_mustermann_a1.ipynb` for assignment 1. If we feel like you have genuinely tried to solve the exercise, you will receive **2** point for this assignment, regardless of the quality of your solution.
#
# ## <center> DUE FRIDAY 08.12.2023 2:30 pm </center>
#
# Drop-off link: [https://uni-duesseldorf.sciebo.de/s/uAOgn8nTNMgeBC6](https://uni-duesseldorf.sciebo.de/s/uAOgn8nTNMgeBC6)
#
# ---

# %% [markdown]
# We will use the infamous `medmnist` dataset that contains multiple low-resolution medical imaging datasets for experimentation.
#
# You can install it locally via `pip install medmnist` or in google colab with `!pip install medmnist`. To visualize the confusion matrix we suggest using seaborn, it can be install via pip.
#
#
#
# You will learn how to perform training on the GPU. For this exercise, we highly reccomend using the free GPU resources from [https://colab.research.google.com](https://colab.research.google.com)
#
#
# PS: for the confusion matrix you may use seaborn. You can install it via pip.

# %% [markdown]
# # 1. The story
#
# There exists a model that is deployed, which scores around 80% test accuracy in the bloodmnist dataset.
#
# Our aim is to create a better model that scores around 90% test accuracy.
#
# Your task is to build and train a convolutional network (convnet) classification model for this purpose.
#
# Note: This time we also got a test set, so 3 data splits in total. We will **only use the test split once** to measure the performance of the trained model.
#
# Finally, we will analyze the predictions of the model via a confusion matrix.
#
# ## 1.1 Imports and data information

# %%
# !pip install medmnist
# Out:
# Collecting medmnist
#   Downloading medmnist-2.2.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from medmnist) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from medmnist) (1.5.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from medmnist) (1.2.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from medmnist) (0.19.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from medmnist) (4.66.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from medmnist) (9.4.0)
# Collecting fire (from medmnist)
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from medmnist) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from medmnist) (0.16.0+cu118)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire->medmnist) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->medmnist) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->medmnist) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->medmnist) (2023.3.post1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (1.11.3)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (3.2.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (23.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->medmnist) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->medmnist) (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision->medmnist) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->medmnist) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->medmnist) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->medmnist) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->medmnist) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->medmnist) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->medmnist) (1.3.0)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116933 sha256=38461ba6f3489d0f55f3710d3ea60e2e9ea490c1df9db36cfd130c2839871664
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# Installing collected packages: fire, medmnist
# Successfully installed fire-0.5.0 medmnist-2.2.3

# %%
from tqdm import tqdm
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torchvision.transforms as transforms
import medmnist
from medmnist import INFO, Evaluator
import torch
from torchvision import transforms as T
import torchvision.transforms.functional as TF
import random
import matplotlib.pyplot as plt

# Specify dataset
data_flag = 'bloodmnist'
download = True
bs = 128
info = INFO[data_flag]
n_channels = info['n_channels']
n_classes = len(info['label'])
print("n_classes",n_classes)
DataClass = getattr(medmnist, info['python_class'])
# Out:
# n_classes 8

# %% [markdown]
# ## 1.2 Creating the dataloaders and visuilizing the data

# %%
mean = torch.tensor([0.5], dtype=torch.float32)
std = torch.tensor([0.5], dtype=torch.float32)

# needs to be defined
plain_transform = T.Compose([
        T.ToTensor(),
        T.Normalize(list(mean), list(std))])


# This is a helper function that you can use to visualize the images.
# Not necessary to use.
def imshow(img, i=0, mean=torch.tensor([0.0], dtype=torch.float32), std=torch.tensor([1], dtype=torch.float32)):
    """
    shows an image on the screen. mean of 0 and variance of 1 will show the images unchanged in the screen
    """
    # undoes the normalization
    unnormalize = transforms.Normalize((-mean / std).tolist(), (1.0 / std).tolist())
    plt.subplot(1, 10 ,i+1)
    npimg = unnormalize(img).numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# load the data
train_ds = DataClass(split='train', transform=plain_transform, download=download)
val_ds = DataClass(split='val', transform=plain_transform, download=download)
test_ds = DataClass(split='test', transform=plain_transform, download=download)

# create the data loaders
### START CODE HERE ### (approx. 3 lines)
train_loader = data.DataLoader(dataset=train_ds, batch_size=bs, shuffle=False, drop_last=True)
val_loader = data.DataLoader(dataset=val_ds, batch_size=bs, shuffle=False, drop_last=True)
test_loader = data.DataLoader(dataset=test_ds, batch_size=bs, shuffle=False, drop_last=True)
### END CODE HERE ###

# check image shape and labels
img1, lab = next(iter(train_loader))
print(img1.shape)
print(lab.shape)


# How I used the imshow function to visualize samples:
plt.figure(figsize = (50,20))
for i in range(10):
    imshow(train_ds[i][0], i, mean, std)
# Out:
# Downloading https://zenodo.org/records/6496656/files/bloodmnist.npz to /root/.medmnist/bloodmnist.npz
# 100%|██████████| 35461855/35461855 [00:01<00:00, 19121550.18it/s]
# Using downloaded and verified file: /root/.medmnist/bloodmnist.npz
# Using downloaded and verified file: /root/.medmnist/bloodmnist.npz
# torch.Size([128, 3, 28, 28])
# torch.Size([128, 1])

# %% [markdown]
# ## 1.3 Implement a small Conv Net
#
# Define the following model:
#
# - 2 Blocks of Conv-MaxPool-ReLU Layers
# - 1 Block Conv-ReLU
# - 1 Block of Linear-ReLU-Linear Layers
#
# `base_channels` is a parameter that you should choose. It controls the width (number of parameters per layer) of the whole network.
#
#
# The model will be initialized as follows:
#
# ```
# model = Net(base_channels=2)  # 2 is for illustration purposes
# ```
#
# A test function is provided so that you can check if you model can perform a forward pass.

# %%
from torch import nn

class Net(nn.Module):
    def __init__(self, base_channels=32, n_classes=8):
        super(Net, self).__init__()
        ### START CODE HERE ### (approx. 11 lines)
        # init class members here
        self.conv1 = nn.Conv2d(3, base_channels, 5)
        self.relu1 = nn.ReLU(inplace=True)
        self.pool1 = nn.MaxPool2d(2, 2)

        self.conv2 = nn.Conv2d(base_channels, base_channels*2, 3)
        self.pool2 = nn.MaxPool2d(2, 2)
        self.relu2 = nn.ReLU(inplace=True)

        self.conv3 = nn.Conv2d(base_channels*2, base_channels*4, 3)
        self.relu3 = nn.ReLU(inplace=True)


        self.mlp = nn.Sequential(
            nn.Linear(base_channels*4*3*3, 64),
            nn.ReLU(inplace=True),
            nn.Linear(64, n_classes))
        ### END CODE HERE ###


    def forward(self, x):
        ### START CODE HERE ### (approx. 6 lines)
        bs = x.shape[0]
        x1 = self.pool1(self.relu1(self.conv1(x)))
        x2 = self.pool2(self.relu2(self.conv2(x1)))
        x3 = self.relu3(self.conv3(x2))
        x3 = x3.view(bs, -1)
        x3 = self.mlp(x3)
        ### END CODE HERE ###
        return x3


def test_model_fw():
    model = Net(base_channels=4)
    x = torch.rand(1,3,28,28)
    out = model(x)
    assert list(out.shape) == [1,8]
    print("Test passed")
    print(model)
test_model_fw()
# Out:
# Test passed
# Net(
#   (conv1): Conv2d(3, 4, kernel_size=(5, 5), stride=(1, 1))
#   (relu1): ReLU(inplace=True)
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (relu2): ReLU(inplace=True)
#   (conv3): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#   (relu3): ReLU(inplace=True)
#   (mlp): Sequential(
#     (0): Linear(in_features=144, out_features=64, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=64, out_features=8, bias=True)
#   )
# )

# %% [markdown]
# ## 1.4 Write the train/val code to train the model
#
#  - Train the convnet model. Specify the hyperparameters and write the train/val code to train the model.
#  - Save the model with the lowest validation loss for testing.
#  - You need to keep track of the train accuracy, val accuracy and train loss and val loss for plotting the results of your training.
#
#
# Some help to save and load your model:
# ```
# torch.save({
#             'epoch': EPOCH,
#             'model_state_dict': net.state_dict(),
#             'optimizer_state_dict': optimizer.state_dict(),
#             'loss': LOSS,
#             }, path)
#
#
# model = Net()
# optimizer = optim.SGD(model.parameters(), lr=lr)
#
# checkpoint = torch.load(path)
# model.load_state_dict(checkpoint['model_state_dict'])
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# epoch = checkpoint['epoch']
# loss = checkpoint['loss']
# ```

# %% [markdown]
# In the `validate` function you need to:
#
# 1. Move data and labels to the correct device
# 2. Get a model output
# 3. Compute a prediction based on the model output
# 4. Compute the number of correct predictions and accumulate it in the `correct` variable
# 5. Accumulate the total number of examples in the `total` variable
# 5. Get the Loss for the model output and save it
# 6. After the loop, compute the model's accuracy from `correct` and `total`
# 7. Return the accuracy and mean loss

# %%
def validate(model, val_loader, device):
    model.eval()
    criterion = nn.CrossEntropyLoss()
    correct, total = 0, 0
    loss_step = []
    bs = val_loader.batch_size
    with torch.no_grad():
        for inp_data, labels in val_loader:
            ### START CODE HERE ### (approx. 10 lines)
            # Move the data to the GPU
            labels = labels.view(bs).to(device)
            inp_data = inp_data.to(device)

            outputs = model(inp_data)
            val_loss = criterion(outputs, labels)
            predicted = torch.max(outputs, 1)[1]
            total += labels.size(0)
            correct += (predicted == labels).sum()
            loss_step.append(val_loss.item())
        # dont forget to take the means here
        val_acc = (100 * correct / total).cpu().numpy()
        val_loss_epoch = torch.tensor(loss_step).mean().numpy()
        ### END CODE HERE ###
        return val_acc , val_loss_epoch

# %% [markdown]
# In the `train_one_epoch` function tou need to:
#
# 1. Move data and labels to the correct device
# 2. Get model outputs
# 3. Compute the loss
# 4. Zero the optimizer's gradients
# 5. Compute the backward pass
# 6. Update the model's parameters
# 7. Compute the model's accuracy, similar to the `validate` function, use `correct` and `total` for accumulation
# 8. After the epoch, compute the model's accuracy and mean loss for this epoch

# %%
def train_one_epoch(model, optimizer, train_loader, device):
    model.train()
    criterion = nn.CrossEntropyLoss()
    loss_step = []
    correct, total = 0, 0
    bs = train_loader.batch_size
    for (inp_data, labels) in train_loader:
        ### START CODE HERE ### (approx. 14 lines)
        # Move the data to the GPU
        labels = labels.view(bs).to(device)
        inp_data = inp_data.to(device)
        outputs = model(inp_data)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        with torch.no_grad():
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum()
            loss_step.append(loss.item())
    # dont forget the means here
    loss_curr_epoch = np.mean(loss_step)
    train_acc = (100 * correct / total).cpu()
    ### END CODE HERE ###
    return loss_curr_epoch, train_acc

# %% [markdown]
# The `train` function you need to:
#
# 1. Get the model's accuracy and mean loss for an epoch, using the `train_one_epoch` function
# 2. Get validation accuracy and loss, using the `validate` function

# %%
def train(model, optimizer, num_epochs, train_loader, val_loader, device):
    best_val_loss = 100
    best_val_acc = 0
    dict_log = {"train_acc_epoch":[], "val_acc_epoch":[], "loss_epoch":[], "val_loss":[]}
    train_acc, _ = validate(model, train_loader, device)
    val_acc, _ = validate(model, val_loader, device)
    print(f'Init Accuracy of the model: Train:{train_acc:.3f} \t Val:{val_acc:3f}')
    for epoch in range(num_epochs):
        ### START CODE HERE ### (approx. 2 lines)
        loss_curr_epoch, train_acc = train_one_epoch(model, optimizer, train_loader, device)
        val_acc, val_loss = validate(model, val_loader, device)
        ### END CODE HERE ###

        # Print epoch results to screen
        print(f'Ep {epoch}/{num_epochs}: Accuracy : Train:{train_acc:.2f} \t Val:{val_acc:.2f} || Loss: Train {loss_curr_epoch:.3f} \t Val {val_loss:.3f}')
        # Track stats
        dict_log["train_acc_epoch"].append(train_acc)
        dict_log["val_acc_epoch"].append(val_acc)
        dict_log["loss_epoch"].append(loss_curr_epoch)
        dict_log["val_loss"].append(val_loss)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save({
                  'epoch': epoch,
                  'model_state_dict': model.state_dict(),
                  'optimizer_state_dict': optimizer.state_dict(),
                  'loss': val_loss,
                  }, f'best_model_min_val_loss.pth')

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save({
                  'epoch': epoch,
                  'model_state_dict': model.state_dict(),
                  'optimizer_state_dict': optimizer.state_dict(),
                  'loss': val_loss,
                  }, f'best_model_max_val_acc.pth')
    return dict_log

# %% [markdown]
# ## 1.5 Choose a set of hyperparameters and train the convnet

# %% [markdown]
# Choose a learning rate, weight decay, number of epochs and number of base channels. Initialize your network and run the training.

# %%
device = "cuda"

### START CODE HERE ### (approx. 5 lines)
learning_rate = 0.01
wd = 0.000001
num_epochs = 100
model = Net(32)
model = model.to(device)
### END CODE HERE ###

optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay=wd)
dict_log = train(model, optimizer, num_epochs, train_loader, val_loader, device)
# Out:
# Init Accuracy of the model: Train:8.291 	 Val:8.353366
# Ep 0/100: Accuracy : Train:17.22 	 Val:19.11 || Loss: Train 2.070 	 Val 2.057
# Ep 1/100: Accuracy : Train:18.25 	 Val:18.03 || Loss: Train 2.044 	 Val 2.032
# Ep 2/100: Accuracy : Train:25.84 	 Val:31.91 || Loss: Train 2.016 	 Val 1.998
# Ep 3/100: Accuracy : Train:22.59 	 Val:33.83 || Loss: Train 1.963 	 Val 1.911
# Ep 4/100: Accuracy : Train:42.57 	 Val:47.90 || Loss: Train 1.766 	 Val 1.580
# Ep 5/100: Accuracy : Train:50.00 	 Val:53.06 || Loss: Train 1.426 	 Val 1.296
# Ep 6/100: Accuracy : Train:55.33 	 Val:58.95 || Loss: Train 1.223 	 Val 1.156
# Ep 7/100: Accuracy : Train:58.64 	 Val:63.70 || Loss: Train 1.132 	 Val 1.059
# Ep 8/100: Accuracy : Train:60.91 	 Val:64.78 || Loss: Train 1.072 	 Val 0.986
# Ep 9/100: Accuracy : Train:62.80 	 Val:66.83 || Loss: Train 1.014 	 Val 0.927
# Ep 10/100: Accuracy : Train:64.78 	 Val:68.09 || Loss: Train 0.964 	 Val 0.883
# Ep 11/100: Accuracy : Train:66.22 	 Val:68.87 || Loss: Train 0.922 	 Val 0.850
# Ep 12/100: Accuracy : Train:67.38 	 Val:69.59 || Loss: Train 0.888 	 Val 0.821
# Ep 13/100: Accuracy : Train:68.25 	 Val:70.19 || Loss: Train 0.860 	 Val 0.797
# Ep 14/100: Accuracy : Train:69.03 	 Val:71.15 || Loss: Train 0.836 	 Val 0.777
# Ep 15/100: Accuracy : Train:69.82 	 Val:71.39 || Loss: Train 0.815 	 Val 0.759
# Ep 16/100: Accuracy : Train:70.52 	 Val:72.06 || Loss: Train 0.796 	 Val 0.744
# Ep 17/100: Accuracy : Train:71.27 	 Val:72.48 || Loss: Train 0.778 	 Val 0.729
# Ep 18/100: Accuracy : Train:72.02 	 Val:72.90 || Loss: Train 0.761 	 Val 0.715
# Ep 19/100: Accuracy : Train:72.59 	 Val:73.44 || Loss: Train 0.745 	 Val 0.701
# Ep 20/100: Accuracy : Train:73.14 	 Val:73.80 || Loss: Train 0.728 	 Val 0.688
# Ep 21/100: Accuracy : Train:73.64 	 Val:74.34 || Loss: Train 0.712 	 Val 0.674
# Ep 22/100: Accuracy : Train:74.24 	 Val:74.82 || Loss: Train 0.696 	 Val 0.659
# Ep 23/100: Accuracy : Train:74.88 	 Val:75.00 || Loss: Train 0.679 	 Val 0.644
# Ep 24/100: Accuracy : Train:75.64 	 Val:75.90 || Loss: Train 0.661 	 Val 0.627
# Ep 25/100: Accuracy : Train:76.31 	 Val:76.80 || Loss: Train 0.644 	 Val 0.608
# Ep 26/100: Accuracy : Train:77.13 	 Val:77.40 || Loss: Train 0.626 	 Val 0.591
# Ep 27/100: Accuracy : Train:77.80 	 Val:77.94 || Loss: Train 0.608 	 Val 0.572
# Ep 28/100: Accuracy : Train:78.42 	 Val:78.61 || Loss: Train 0.590 	 Val 0.555
# Ep 29/100: Accuracy : Train:79.17 	 Val:78.85 || Loss: Train 0.573 	 Val 0.539
# Ep 30/100: Accuracy : Train:79.76 	 Val:79.81 || Loss: Train 0.556 	 Val 0.523
# Ep 31/100: Accuracy : Train:80.54 	 Val:80.23 || Loss: Train 0.540 	 Val 0.507
# Ep 32/100: Accuracy : Train:81.18 	 Val:80.95 || Loss: Train 0.526 	 Val 0.493
# Ep 33/100: Accuracy : Train:81.72 	 Val:82.33 || Loss: Train 0.512 	 Val 0.478
# Ep 34/100: Accuracy : Train:82.14 	 Val:82.75 || Loss: Train 0.499 	 Val 0.465
# Ep 35/100: Accuracy : Train:82.64 	 Val:83.47 || Loss: Train 0.486 	 Val 0.453
# Ep 36/100: Accuracy : Train:83.01 	 Val:84.31 || Loss: Train 0.475 	 Val 0.442
# Ep 37/100: Accuracy : Train:83.43 	 Val:84.62 || Loss: Train 0.464 	 Val 0.432
# Ep 38/100: Accuracy : Train:83.79 	 Val:84.98 || Loss: Train 0.454 	 Val 0.423
# Ep 39/100: Accuracy : Train:83.97 	 Val:85.34 || Loss: Train 0.446 	 Val 0.415
# Ep 40/100: Accuracy : Train:84.32 	 Val:85.46 || Loss: Train 0.437 	 Val 0.407
# Ep 41/100: Accuracy : Train:84.61 	 Val:85.64 || Loss: Train 0.429 	 Val 0.400
# Ep 42/100: Accuracy : Train:84.85 	 Val:85.64 || Loss: Train 0.421 	 Val 0.394
# Ep 43/100: Accuracy : Train:85.06 	 Val:86.00 || Loss: Train 0.414 	 Val 0.388
# Ep 44/100: Accuracy : Train:85.35 	 Val:86.54 || Loss: Train 0.407 	 Val 0.381
# Ep 45/100: Accuracy : Train:85.46 	 Val:86.54 || Loss: Train 0.400 	 Val 0.376
# Ep 46/100: Accuracy : Train:85.67 	 Val:86.78 || Loss: Train 0.394 	 Val 0.371
# Ep 47/100: Accuracy : Train:85.82 	 Val:87.26 || Loss: Train 0.388 	 Val 0.366
# Ep 48/100: Accuracy : Train:86.00 	 Val:87.14 || Loss: Train 0.383 	 Val 0.362
# Ep 49/100: Accuracy : Train:86.11 	 Val:87.20 || Loss: Train 0.378 	 Val 0.358
# Ep 50/100: Accuracy : Train:86.25 	 Val:87.38 || Loss: Train 0.373 	 Val 0.356
# Ep 51/100: Accuracy : Train:86.34 	 Val:87.38 || Loss: Train 0.369 	 Val 0.351
# Ep 52/100: Accuracy : Train:86.60 	 Val:87.50 || Loss: Train 0.364 	 Val 0.349
# Ep 53/100: Accuracy : Train:86.71 	 Val:87.74 || Loss: Train 0.360 	 Val 0.345
# Ep 54/100: Accuracy : Train:86.81 	 Val:87.92 || Loss: Train 0.357 	 Val 0.342
# Ep 55/100: Accuracy : Train:86.90 	 Val:87.80 || Loss: Train 0.353 	 Val 0.339
# Ep 56/100: Accuracy : Train:86.99 	 Val:88.16 || Loss: Train 0.349 	 Val 0.337
# Ep 57/100: Accuracy : Train:87.18 	 Val:88.16 || Loss: Train 0.346 	 Val 0.335
# Ep 58/100: Accuracy : Train:87.32 	 Val:88.40 || Loss: Train 0.343 	 Val 0.332
# Ep 59/100: Accuracy : Train:87.53 	 Val:88.40 || Loss: Train 0.339 	 Val 0.327
# Ep 60/100: Accuracy : Train:87.77 	 Val:88.46 || Loss: Train 0.336 	 Val 0.325
# Ep 61/100: Accuracy : Train:87.89 	 Val:88.70 || Loss: Train 0.333 	 Val 0.322
# Ep 62/100: Accuracy : Train:88.02 	 Val:88.82 || Loss: Train 0.330 	 Val 0.320
# Ep 63/100: Accuracy : Train:88.10 	 Val:88.76 || Loss: Train 0.327 	 Val 0.318
# Ep 64/100: Accuracy : Train:88.26 	 Val:88.58 || Loss: Train 0.325 	 Val 0.317
# Ep 65/100: Accuracy : Train:88.42 	 Val:88.76 || Loss: Train 0.322 	 Val 0.314
# Ep 66/100: Accuracy : Train:88.47 	 Val:88.64 || Loss: Train 0.319 	 Val 0.313
# Ep 67/100: Accuracy : Train:88.56 	 Val:88.94 || Loss: Train 0.316 	 Val 0.310
# Ep 68/100: Accuracy : Train:88.62 	 Val:88.94 || Loss: Train 0.314 	 Val 0.309
# Ep 69/100: Accuracy : Train:88.69 	 Val:88.94 || Loss: Train 0.311 	 Val 0.307
# Ep 70/100: Accuracy : Train:88.83 	 Val:88.94 || Loss: Train 0.309 	 Val 0.306
# Ep 71/100: Accuracy : Train:88.96 	 Val:89.12 || Loss: Train 0.306 	 Val 0.304
# Ep 72/100: Accuracy : Train:89.07 	 Val:89.24 || Loss: Train 0.304 	 Val 0.301
# Ep 73/100: Accuracy : Train:89.12 	 Val:89.36 || Loss: Train 0.301 	 Val 0.300
# Ep 74/100: Accuracy : Train:89.21 	 Val:89.24 || Loss: Train 0.299 	 Val 0.299
# Ep 75/100: Accuracy : Train:89.25 	 Val:89.30 || Loss: Train 0.296 	 Val 0.297
# Ep 76/100: Accuracy : Train:89.32 	 Val:89.54 || Loss: Train 0.294 	 Val 0.294
# Ep 77/100: Accuracy : Train:89.40 	 Val:89.54 || Loss: Train 0.291 	 Val 0.293
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-9eee9f902d81> in <cell line: 12>()
#      10
#      11 optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay=wd)
# ---> 12 dict_log = train(model, optimizer, num_epochs, train_loader, val_loader, device)
#
# <ipython-input-9-2aed5546d0f5> in train(model, optimizer, num_epochs, train_loader, val_loader, device)
#       8     for epoch in range(num_epochs):
#       9         ### START CODE HERE ### (approx. 2 lines)
# ---> 10         loss_curr_epoch, train_acc = train_one_epoch(model, optimizer, train_loader, device)
#      11         val_acc, val_loss = validate(model, val_loader, device)
#      12         ### END CODE HERE ###
#
# <ipython-input-8-15aeb6229c88> in train_one_epoch(model, optimizer, train_loader, device)
#       5     correct, total = 0, 0
#       6     bs = train_loader.batch_size
# ----> 7     for (inp_data, labels) in train_loader:
#       8         ### START CODE HERE ### (approx. 14 lines)
#       9         # Move the data to the GPU
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     672     def _next_data(self):
#     673         index = self._next_index()  # may raise StopIteration
# --> 674         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675         if self._pin_memory:
#     676             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/medmnist/dataset.py in __getitem__(self, index)
#     107
#     108         if self.transform is not None:
# --> 109             img = self.transform(img)
#     110
#     111         if self.target_transform is not None:
#
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      93     def __call__(self, img):
#      94         for t in self.transforms:
# ---> 95             img = t(img)
#      96         return img
#      97
#
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#     135             Tensor: Converted image.
#     136         """
# --> 137         return F.to_tensor(pic)
#     138
#     139     def __repr__(self) -> str:
#
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py in to_tensor(pic)
#     164     # handle PIL Image
#     165     mode_to_nptype = {"I": np.int32, "I;16": np.int16, "F": np.float32}
# --> 166     img = torch.from_numpy(np.array(pic, mode_to_nptype.get(pic.mode, np.uint8), copy=True))
#     167
#     168     if pic.mode == "1":
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in __array_interface__(self)
#     699                 new["data"] = self.tobytes("raw", "L")
#     700             else:
# --> 701                 new["data"] = self.tobytes()
#     702         except Exception as e:
#     703             if not isinstance(e, (MemoryError, RecursionError)):
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in tobytes(self, encoder_name, *args)
#     769         data = []
#     770         while True:
# --> 771             l, s, d = e.encode(bufsize)
#     772             data.append(d)
#     773             if s:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Expected results
# ```
# Ep 0/100: Accuracy : Train:16.95 	 Val:17.01 || Loss: Train 2.070 	 Val 2.056
# ...................................
# Ep 20/100: Accuracy : Train:75.65 	 Val:75.30 || Loss: Train 0.702 	 Val 0.647
# ...................................
# Ep 74/100: Accuracy : Train:89.46 	 Val:88.40 || Loss: Train 0.313 	 Val 0.317
# ...................................
# Ep 96/100: Accuracy : Train:91.65 	 Val:89.66 || Loss: Train 0.257 	 Val 0.272
# ```

# %% [markdown]
# ## 1.6 Load your best model and test it on the test set
#
# The code below load the checkpoint for the best models, based on validation loss and accuracy and finds the test loss and test accuracy.
#
# Is it close to the train and val set?
#
# You should get around 90% val accuracy here

# %%
path = "best_model_min_val_loss.pth"
path2 = "best_model_max_val_acc.pth"
def load_model(model, path):
    checkpoint = torch.load(path)
    model.load_state_dict(checkpoint['model_state_dict'])
    print(f"Model {path} is loaded from epoch {checkpoint['epoch']} , loss {checkpoint['loss']}")
    return model

def test_model(model, path, test_loader, device='cuda'):
    model = load_model(model, path)
    model.to("cuda")
    model.eval()
    return validate(model, test_loader, device)

### START CODE HERE ### (approx. 3 lines)
model = Net(32)
test_acc, test_loss = test_model(model, path, test_loader, device)
print(f"Test loss {test_acc} , test acc {test_loss}% ")
 ### END CODE HERE ###
# Out:
# Model best_model_min_val_loss.pth is loaded from epoch 99 , loss 0.27812206745147705
# Test loss 89.51322174072266 , test acc 0.29767152667045593%

# %% [markdown]
# ## 1.7 Plot train/val accuracies and train/val loss
#
# Complete the `plot_stats` function below.

# %%
import matplotlib.pyplot as plt


def plot_stats(dict_log, baseline=90, title=None):
    fontsize = 14
    figsize = (15,10)
    plt.figure(figsize=figsize)
    plt.subplots_adjust(hspace=0.3)
    plt.subplot(2,1,1)
    ### START CODE HERE ### (approx. 5 lines)
    x_axis = list(range(len(dict_log["val_acc_epoch"])))
    plt.plot(dict_log["train_acc_epoch"], label='Train accuracy.')
    plt.scatter(x_axis, dict_log["train_acc_epoch"])

    plt.plot(dict_log["val_acc_epoch"], label='Validation accuracy.')
    plt.scatter(x_axis, dict_log["val_acc_epoch"])
    ### END CODE HERE ###


    plt.ylabel('Accuracy in %')
    plt.xlabel('Number of Epochs')
    plt.title("Accuracy over epochs", fontsize=fontsize)
    plt.axhline(y=baseline, color='red', label="Acceptable accuracy")
    plt.legend(fontsize=fontsize)


    plt.subplot(2,1,2)
    plt.plot(dict_log["loss_epoch"] , label="Training")

    ### START CODE HERE ### (approx. 3 lines)
    plt.scatter(x_axis, dict_log["loss_epoch"], )
    plt.plot(dict_log["val_loss"] , label='Validation')
    plt.scatter(x_axis, dict_log["val_loss"])
    ### END CODE HERE ###

    plt.ylabel('Loss value')
    plt.xlabel('Number of Epochs')
    plt.title("Loss over epochs", fontsize=fontsize)
    plt.legend(fontsize=fontsize)
    if title is not None:
        plt.savefig(title)

plot_stats(dict_log, baseline=90, title='figs/exp_1_bloddmnist.png')

# %% [markdown]
# ![exp_1_bloddmnist.png](https://raw.githubusercontent.com/HHU-MMBS/Deep-Learning-Exercise-Extras/main/a07-08_mednist/figs/exp_1_bloddmnist.png)

# %% [markdown]
# ## 1.8 Use sklearn.metrics to get insights on per class predictions
# ```
# from sklearn.metrics import classification_report
# from sklearn.metrics import confusion_matrix
# ```
# You will need to iterate through the test data with the trained model and generate `y_true` and `y_pred` lists ( labels and predictions respectivly)
#
#
# ### Questions to think about:
#
# Analyze and try to understand the outputs:
#
# - Which class is the harder to predict?
#
# - Are the predictions equally good for all classes? Which class(es) is misclassified more frequently?
#
# - Is accuracy always a good metric? And if not why are the other metrics better to infer the behaviour of the model?

# %%
import os
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import seaborn as sns
fontsize = 14
figsize=(14,14)

# Load the best model
### START CODE HERE ### (approx. 2 lines)
model = Net(32)
model = load_model(model, path)
### END CODE HERE ###

device = 'cuda'
model = model.to(device)
model.eval()

# get test accuracy
test_acc, test_loss = validate(model, test_loader, device)
print(test_acc, test_loss)
y_pred = []
y_true = []
with torch.no_grad():
    for test_data in test_loader:
        test_images, test_labels = (
            test_data[0].to(device),
            test_data[1].to(device),
        )
        pred = model(test_images).argmax(dim=1)
        for i in range(len(pred)):
            y_true.append(test_labels[i].item())
            y_pred.append(pred[i].item())

print(classification_report(
    y_true, y_pred,  digits=3))

# Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

fig = plt.figure(figsize=figsize)
sns.heatmap(conf_matrix/np.sum(conf_matrix), annot=True,
            fmt='.2%', cmap='Blues')
plt.ylabel('Actual Category', fontsize=fontsize)
plt.xlabel('Predicted Category', fontsize=fontsize)

plt.savefig("figs/exp_1_conf_mat.png")
plt.show()
# Out:
# Model best_model_min_val_loss.pth is loaded from epoch 99 , loss 0.27812206745147705
# 89.51322 0.29767153
#               precision    recall  f1-score   support
#
#            0      0.785     0.717     0.749       240
#            1      0.979     0.980     0.979       605
#            2      0.957     0.884     0.919       303
#            3      0.725     0.852     0.783       560
#            4      0.863     0.856     0.860       236
#            5      0.830     0.687     0.752       278
#            6      0.966     0.955     0.960       648
#            7      0.993     0.998     0.996       458
#
#     accuracy                          0.895      3328
#    macro avg      0.887     0.866     0.875      3328
# weighted avg      0.899     0.895     0.895      3328

# %% [markdown]
# ![exp_1_conf.png](https://raw.githubusercontent.com/HHU-MMBS/Deep-Learning-Exercise-Extras/main/a07-08_mednist/figs/exp_1_conf_mat.png)

# %% [markdown]
# # 2. Training tricks and scaling up our model and data
#
# Well, we have trained our small convnet that scores around 90% test accuracy on bloodmnist (17,092 images).
#
# Some questions still arise:
# - Is our convet good enough?
# - How can we further increase our performance?
# - Does it work well enoough with larger amounts of data?
# - What is the critical component of larger scale convnets like Resnets?
#
# To this end, in the 2nd part we will:
#
# - First we will first add some image augmentations to our training data.
# - Then we will see the impact of [Batch normalization](https://arxiv.org/abs/1502.03167) to our small convnet, which is a core component of large scale convnet like resnet and observe the training dynamics.
# - Afterwards, we will scale-up our model from the small convnet to the famous resnet-18.
#
#
#
#
# **End Goal**: We would like to have a validation accuracy over 94% for bloodmnist.

# %% [markdown]
# ## 2.1 Define the data augmentation pipelines
#
# Training data augmentations you should implement:
# - Horizontal flip with 50% probability
# - Vertical flip with 50% probability
# - Random crop images to 80-100 % of the initial size
# - Resize images to 28x28
# - intensity jitter: 20% brightness and 20% contrast with 80% probability
# - Mean/std norm with mean=0.5 and std=0.5 for all channels
#
# At val/test time, only mean/std normalization will be applied.
#
# Hint: use [torchvision](https://pytorch.org/vision/stable/transforms.html) for creating the data augmentation pipeline.

# %%
mean = torch.tensor([0.5], dtype=torch.float32)
std = torch.tensor([0.5], dtype=torch.float32)
batch_size = 128

### START CODE HERE ### (approx. 8 lines)
color_jitter = T.ColorJitter(brightness=0.2, contrast=0.2)
train_transform_augs = T.Compose([
        T.ToTensor(),
        T.RandomHorizontalFlip(),
        T.RandomVerticalFlip(),
        T.RandomResizedCrop(size=28, scale=(0.8,1)),
        T.RandomApply([color_jitter], p=0.8),
        T.Normalize(list(mean), list(std) ) ])
### END CODE HERE ###

plain_transform = T.Compose([
        T.ToTensor(),
        T.Normalize(list(mean), list(std))])

# This is a helper function that you can use to visualize the images.
# Not necessary to use.
def imshow(img, i=0, mean=torch.tensor([0.0], dtype=torch.float32), std=torch.tensor([1], dtype=torch.float32)):
    """
    shows an image on the screen. mean of 0 and variance of 1 will show the images unchanged in the screen
    """
    # undoes the normalization
    unnormalize = T.Normalize((-mean / std).tolist(), (1.0 / std).tolist())
    plt.subplot(1, 10 ,i+1)
    npimg = unnormalize(img).numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# load the data
train_ds = DataClass(split='train', transform=train_transform_augs, download=download)
train_plain = DataClass(split='train', transform=plain_transform, download=download)
val_ds = DataClass(split='val', transform=plain_transform, download=download)
test_ds = DataClass(split='test', transform=plain_transform, download=download)

train_loader = data.DataLoader(dataset=train_ds, batch_size=batch_size, shuffle=True, drop_last=True)
train_loader_plain = data.DataLoader(dataset=train_plain, batch_size=batch_size, shuffle=True, drop_last=True)
val_loader = data.DataLoader(dataset=val_ds, batch_size=batch_size, shuffle=False, drop_last=True)
test_loader = data.DataLoader(dataset=test_ds, batch_size=batch_size, shuffle=False, drop_last=True)

img1, lab = next(iter(train_loader))

# How I used the imshow function to visualize samples:
plt.figure(figsize = (50,20))
for i in range(10):
    imshow(train_ds[i][0], i, mean, std)
# Out:
# Using downloaded and verified file: /home/adaloglo/.medmnist/bloodmnist.npz
# Using downloaded and verified file: /home/adaloglo/.medmnist/bloodmnist.npz
# Using downloaded and verified file: /home/adaloglo/.medmnist/bloodmnist.npz
# Using downloaded and verified file: /home/adaloglo/.medmnist/bloodmnist.npz

# %% [markdown]
# ## 2.2 Add batch normalization to our convnet
#
# Take the convnet from our previous exercise and add 3 batch normalization layers after the convolutions or activation functions (you should decide where).
#
# Questions that may help:
#
# - Should you use `BatchNorm1d`, `BatchNorm2d`, or `BatchNorm3d`? What are the arguments that you should specify? Check the documentation.
# - In which order should you apply the normalization , i.e. before or after the activation function?
# - What training behaviour do you expect? Guess or check the published paper.
#
# The network WITHOUT batch norm should look like this:
#
#
# ```
#  Net(
#   (conv1): Conv2d(in_channels, base_channels, kernel_size=(5, 5), stride=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2)
#   (relu1): ReLU(inplace=True)
#   (conv2): Conv2d(in_channels, base_channels*2 , kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2)
#   (relu2): ReLU(inplace=True)
#   (conv3): Conv2d(in_channels, base_channels*4, kernel_size=(3, 3), stride=(1, 1))
#   (relu3): ReLU(inplace=True)
#
#     (fc0): Linear(in_channels, out_features=64)
#     (act0): ReLU(inplace=True)
#     (fc2): Linear(in_channels, n_classes)
#   )
# )
# ```
#
# The model can be initialized as follows:
#
# ```
# model = Net(base_channels=2, n_classes=2, batch_norm=True) # batch_norm is Optional to implement.
# ```
# Use the same number of base channels as in the previous model without batchnorm so that you can see the differences while training.
#
# - `batch_norm` is a boolean argument. It is optional to implement it this way. The idea is to specify whether we want to add batch norm in the architecture or not.

# %%
import torch.nn as nn

class Net(nn.Module):
    def __init__(self, base_channels=2, n_classes=2, batch_norm=False):
        super(Net, self).__init__()
        ### START CODE HERE ### (approx. 15 lines)
        self.conv1 = nn.Conv2d(3, base_channels, 5)
        self.norm1 = nn.BatchNorm2d(base_channels) if batch_norm else nn.Identity()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.relu1 = nn.ReLU(inplace=True)

        self.conv2 = nn.Conv2d(base_channels, base_channels*2, 3)
        self.norm2 = nn.BatchNorm2d(base_channels*2) if batch_norm else nn.Identity()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.relu2 = nn.ReLU(inplace=True)

        self.conv3 = nn.Conv2d(base_channels*2, base_channels*4, 3)
        self.norm3 = nn.BatchNorm2d(base_channels*4) if batch_norm else nn.Identity()
        self.relu3 = nn.ReLU(inplace=True)

        self.mlp = nn.Sequential(
            nn.Linear(base_channels*4*3*3, 64),
            nn.ReLU(inplace=True),
            nn.Linear(64, n_classes))
        ### END CODE HERE ###

    def forward(self, x):
        bs = x.shape[0]
        ### START CODE HERE ### (approx. 5 lines)
        x1 = self.pool1(self.relu1(self.norm1(self.conv1(x))))
        x2 = self.pool2(self.relu2(self.norm2(self.conv2(x1))))
        x3 = self.relu3(self.norm3(self.conv3(x2)))
        x3 = x3.view(bs, -1)
        x3 = self.mlp(x3)
        ### END CODE HERE ###
        return x3

def test():
    c = 8
    model = Net(base_channels=4,n_classes=c, batch_norm=True)
    x = torch.rand(1,3,28,28)
    out = model(x)
    assert list(out.shape) == [1,c]
    model = Net(base_channels=4,n_classes=c, batch_norm=False)
    assert list(model(x).shape) == [1,c]
    print("Test passed")
test()
# Out:
# Test passed

# %% [markdown]
# ## 2.3 Train the convnet with batch normalization
#
# Use the already implemented functions from part 1 to train the model with the new data and batch norm.
#
# Anything above 50 epochs should be enough. Use the same hyperparameter setup that you found in the previous part.

# %%
device = 'cuda'
num_epochs = 80

print("Training with Batch Normalization and image augmentations")
### START CODE HERE ### (approx. 4 lines)
model_2 = Net(base_channels=32, n_classes=8, batch_norm=True)
optimizer_2 = torch.optim.SGD(model_2.parameters(), lr=learning_rate, weight_decay=wd)
model_2 = model_2.to(device)
dict_log = train(model_2, optimizer_2, num_epochs, train_loader, val_loader, device)
### END CODE HERE ###
# Out:
# Training with Batch Normalization and image augmentations
# Init Accuracy of the model: Train:13.743 	 Val:13.822116
# Ep 0/80: Accuracy : Train:59.06 	 Val:71.33 || Loss: Train 1.409 	 Val 0.920
# Ep 1/80: Accuracy : Train:73.36 	 Val:76.26 || Loss: Train 0.827 	 Val 0.666
# Ep 2/80: Accuracy : Train:76.61 	 Val:78.61 || Loss: Train 0.675 	 Val 0.610
# Ep 3/80: Accuracy : Train:78.45 	 Val:80.83 || Loss: Train 0.613 	 Val 0.565
# Ep 4/80: Accuracy : Train:79.70 	 Val:83.41 || Loss: Train 0.562 	 Val 0.488
# Ep 5/80: Accuracy : Train:81.24 	 Val:82.81 || Loss: Train 0.520 	 Val 0.467
# Ep 6/80: Accuracy : Train:82.69 	 Val:84.68 || Loss: Train 0.490 	 Val 0.427
# Ep 7/80: Accuracy : Train:83.34 	 Val:82.51 || Loss: Train 0.464 	 Val 0.464
# Ep 8/80: Accuracy : Train:84.39 	 Val:83.89 || Loss: Train 0.438 	 Val 0.433
# Ep 9/80: Accuracy : Train:85.24 	 Val:86.90 || Loss: Train 0.416 	 Val 0.375
# Ep 10/80: Accuracy : Train:85.73 	 Val:87.98 || Loss: Train 0.404 	 Val 0.353
# Ep 11/80: Accuracy : Train:86.70 	 Val:88.52 || Loss: Train 0.381 	 Val 0.340
# Ep 12/80: Accuracy : Train:87.03 	 Val:89.06 || Loss: Train 0.365 	 Val 0.326
# Ep 13/80: Accuracy : Train:87.42 	 Val:84.74 || Loss: Train 0.351 	 Val 0.445
# Ep 14/80: Accuracy : Train:87.75 	 Val:90.75 || Loss: Train 0.345 	 Val 0.273
# Ep 15/80: Accuracy : Train:87.95 	 Val:89.42 || Loss: Train 0.334 	 Val 0.303
# Ep 16/80: Accuracy : Train:88.79 	 Val:89.42 || Loss: Train 0.321 	 Val 0.306
# Ep 17/80: Accuracy : Train:88.64 	 Val:87.62 || Loss: Train 0.312 	 Val 0.353
# Ep 18/80: Accuracy : Train:89.63 	 Val:88.82 || Loss: Train 0.300 	 Val 0.306
# Ep 19/80: Accuracy : Train:89.43 	 Val:90.44 || Loss: Train 0.299 	 Val 0.269
# Ep 20/80: Accuracy : Train:89.27 	 Val:90.99 || Loss: Train 0.289 	 Val 0.267
# Ep 21/80: Accuracy : Train:89.55 	 Val:89.36 || Loss: Train 0.285 	 Val 0.288
# Ep 22/80: Accuracy : Train:89.84 	 Val:80.95 || Loss: Train 0.282 	 Val 0.543
# Ep 23/80: Accuracy : Train:89.90 	 Val:88.16 || Loss: Train 0.274 	 Val 0.307
# Ep 24/80: Accuracy : Train:90.38 	 Val:91.77 || Loss: Train 0.267 	 Val 0.242
# Ep 25/80: Accuracy : Train:90.74 	 Val:89.18 || Loss: Train 0.263 	 Val 0.296
# Ep 26/80: Accuracy : Train:90.46 	 Val:90.02 || Loss: Train 0.261 	 Val 0.258
# Ep 27/80: Accuracy : Train:90.38 	 Val:89.60 || Loss: Train 0.260 	 Val 0.264
# Ep 28/80: Accuracy : Train:90.70 	 Val:90.62 || Loss: Train 0.256 	 Val 0.256
# Ep 29/80: Accuracy : Train:91.26 	 Val:90.50 || Loss: Train 0.241 	 Val 0.257
# Ep 30/80: Accuracy : Train:91.41 	 Val:88.76 || Loss: Train 0.241 	 Val 0.311
# Ep 31/80: Accuracy : Train:90.99 	 Val:86.60 || Loss: Train 0.244 	 Val 0.352
# Ep 32/80: Accuracy : Train:91.18 	 Val:91.83 || Loss: Train 0.239 	 Val 0.233
# Ep 33/80: Accuracy : Train:91.52 	 Val:92.97 || Loss: Train 0.231 	 Val 0.213
# Ep 34/80: Accuracy : Train:91.33 	 Val:90.75 || Loss: Train 0.236 	 Val 0.245
# Ep 35/80: Accuracy : Train:91.98 	 Val:92.49 || Loss: Train 0.220 	 Val 0.211
# Ep 36/80: Accuracy : Train:91.94 	 Val:89.48 || Loss: Train 0.225 	 Val 0.280
# Ep 37/80: Accuracy : Train:91.98 	 Val:93.09 || Loss: Train 0.224 	 Val 0.207
# Ep 38/80: Accuracy : Train:92.05 	 Val:93.27 || Loss: Train 0.223 	 Val 0.203
# Ep 39/80: Accuracy : Train:92.00 	 Val:92.01 || Loss: Train 0.222 	 Val 0.227
# Ep 40/80: Accuracy : Train:92.31 	 Val:93.87 || Loss: Train 0.214 	 Val 0.184
# Ep 41/80: Accuracy : Train:91.94 	 Val:89.24 || Loss: Train 0.220 	 Val 0.307
# Ep 42/80: Accuracy : Train:91.94 	 Val:92.73 || Loss: Train 0.214 	 Val 0.206
# Ep 43/80: Accuracy : Train:92.20 	 Val:94.05 || Loss: Train 0.215 	 Val 0.177
# Ep 44/80: Accuracy : Train:92.26 	 Val:92.85 || Loss: Train 0.209 	 Val 0.207
# Ep 45/80: Accuracy : Train:92.79 	 Val:93.57 || Loss: Train 0.202 	 Val 0.187
# Ep 46/80: Accuracy : Train:92.39 	 Val:93.69 || Loss: Train 0.207 	 Val 0.186
# Ep 47/80: Accuracy : Train:92.73 	 Val:93.69 || Loss: Train 0.201 	 Val 0.193
# Ep 48/80: Accuracy : Train:92.67 	 Val:94.53 || Loss: Train 0.202 	 Val 0.172
# Ep 49/80: Accuracy : Train:92.57 	 Val:86.42 || Loss: Train 0.203 	 Val 0.416
# Ep 50/80: Accuracy : Train:92.95 	 Val:87.26 || Loss: Train 0.198 	 Val 0.327
# Ep 51/80: Accuracy : Train:93.22 	 Val:93.15 || Loss: Train 0.191 	 Val 0.190
# Ep 52/80: Accuracy : Train:92.79 	 Val:91.71 || Loss: Train 0.193 	 Val 0.240
# Ep 53/80: Accuracy : Train:92.72 	 Val:94.41 || Loss: Train 0.197 	 Val 0.170
# Ep 54/80: Accuracy : Train:92.88 	 Val:93.39 || Loss: Train 0.193 	 Val 0.200
# Ep 55/80: Accuracy : Train:93.14 	 Val:94.59 || Loss: Train 0.188 	 Val 0.160
# Ep 56/80: Accuracy : Train:93.28 	 Val:94.41 || Loss: Train 0.185 	 Val 0.160
# Ep 57/80: Accuracy : Train:92.97 	 Val:91.23 || Loss: Train 0.191 	 Val 0.244
# Ep 58/80: Accuracy : Train:93.14 	 Val:93.69 || Loss: Train 0.184 	 Val 0.174
# Ep 59/80: Accuracy : Train:93.61 	 Val:88.94 || Loss: Train 0.183 	 Val 0.330
# Ep 60/80: Accuracy : Train:93.46 	 Val:93.75 || Loss: Train 0.180 	 Val 0.175
# Ep 61/80: Accuracy : Train:93.36 	 Val:92.55 || Loss: Train 0.179 	 Val 0.196
# Ep 62/80: Accuracy : Train:93.52 	 Val:93.69 || Loss: Train 0.177 	 Val 0.172
# Ep 63/80: Accuracy : Train:93.36 	 Val:92.49 || Loss: Train 0.178 	 Val 0.202
# Ep 64/80: Accuracy : Train:93.56 	 Val:94.89 || Loss: Train 0.178 	 Val 0.149
# Ep 65/80: Accuracy : Train:93.66 	 Val:93.33 || Loss: Train 0.178 	 Val 0.185
# Ep 66/80: Accuracy : Train:93.37 	 Val:92.61 || Loss: Train 0.178 	 Val 0.208
# Ep 67/80: Accuracy : Train:93.73 	 Val:93.81 || Loss: Train 0.172 	 Val 0.173
# Ep 68/80: Accuracy : Train:93.71 	 Val:93.03 || Loss: Train 0.176 	 Val 0.181
# Ep 69/80: Accuracy : Train:93.77 	 Val:93.81 || Loss: Train 0.172 	 Val 0.167
# Ep 70/80: Accuracy : Train:93.59 	 Val:93.09 || Loss: Train 0.174 	 Val 0.196
# Ep 71/80: Accuracy : Train:93.71 	 Val:92.73 || Loss: Train 0.173 	 Val 0.183
# Ep 72/80: Accuracy : Train:94.20 	 Val:92.31 || Loss: Train 0.164 	 Val 0.198
# Ep 73/80: Accuracy : Train:93.54 	 Val:92.49 || Loss: Train 0.173 	 Val 0.209
# Ep 74/80: Accuracy : Train:94.37 	 Val:94.65 || Loss: Train 0.160 	 Val 0.156
# Ep 75/80: Accuracy : Train:93.98 	 Val:94.53 || Loss: Train 0.165 	 Val 0.164
# Ep 76/80: Accuracy : Train:94.06 	 Val:93.33 || Loss: Train 0.161 	 Val 0.186
# Ep 77/80: Accuracy : Train:94.37 	 Val:94.65 || Loss: Train 0.161 	 Val 0.153
# Ep 78/80: Accuracy : Train:94.35 	 Val:94.83 || Loss: Train 0.159 	 Val 0.154
# Ep 79/80: Accuracy : Train:94.07 	 Val:95.25 || Loss: Train 0.160 	 Val 0.139

# %% [markdown]
# **Expected results:**
#
# ```
# Ep 0/80: Accuracy : Train:56.88 	 Val:73.62 || Loss: Train 1.403 	 Val 0.872
# Ep 1/80: Accuracy : Train:73.20 	 Val:76.74 || Loss: Train 0.812 	 Val 0.665
# Ep 2/80: Accuracy : Train:76.00 	 Val:79.21 || Loss: Train 0.675 	 Val 0.575
# Ep 3/80: Accuracy : Train:78.16 	 Val:80.29 || Loss: Train 0.602 	 Val 0.528
# Ep 4/80: Accuracy : Train:80.00 	 Val:80.41 || Loss: Train 0.554 	 Val 0.512
# Ep 5/80: Accuracy : Train:81.17 	 Val:83.59 || Loss: Train 0.519 	 Val 0.459
# Ep 6/80: Accuracy : Train:82.01 	 Val:83.47 || Loss: Train 0.496 	 Val 0.443
# Ep 7/80: Accuracy : Train:83.48 	 Val:85.28 || Loss: Train 0.467 	 Val 0.414
# Ep 8/80: Accuracy : Train:84.24 	 Val:86.36 || Loss: Train 0.442 	 Val 0.389
# Ep 9/80: Accuracy : Train:84.81 	 Val:85.88 || Loss: Train 0.419 	 Val 0.385
# Ep 10/80: Accuracy : Train:85.66 	 Val:88.46 || Loss: Train 0.398 	 Val 0.336
# Ep 11/80: Accuracy : Train:86.48 	 Val:87.38 || Loss: Train 0.387 	 Val 0.356
# Ep 12/80: Accuracy : Train:87.00 	 Val:88.22 || Loss: Train 0.369 	 Val 0.339
# Ep 13/80: Accuracy : Train:87.05 	 Val:89.06 || Loss: Train 0.359 	 Val 0.313
# Ep 14/80: Accuracy : Train:87.42 	 Val:88.10 || Loss: Train 0.345 	 Val 0.310
# Ep 15/80: Accuracy : Train:87.89 	 Val:90.81 || Loss: Train 0.337 	 Val 0.273
# Ep 16/80: Accuracy : Train:88.71 	 Val:90.44 || Loss: Train 0.324 	 Val 0.275
# Ep 17/80: Accuracy : Train:88.63 	 Val:88.64 || Loss: Train 0.311 	 Val 0.325
# Ep 18/80: Accuracy : Train:89.21 	 Val:91.29 || Loss: Train 0.306 	 Val 0.259
# Ep 19/80: Accuracy : Train:89.04 	 Val:91.71 || Loss: Train 0.301 	 Val 0.247
# Ep 20/80: Accuracy : Train:89.50 	 Val:90.56 || Loss: Train 0.291 	 Val 0.259
# Ep 21/80: Accuracy : Train:89.75 	 Val:90.56 || Loss: Train 0.286 	 Val 0.254
# Ep 22/80: Accuracy : Train:90.05 	 Val:87.20 || Loss: Train 0.279 	 Val 0.324
# ...
# Ep 30/80: Accuracy : Train:91.23 	 Val:92.37 || Loss: Train 0.242 	 Val 0.206
# Ep 31/80: Accuracy : Train:91.43 	 Val:92.79 || Loss: Train 0.239 	 Val 0.202
# Ep 32/80: Accuracy : Train:91.58 	 Val:91.59 || Loss: Train 0.233 	 Val 0.220
# Ep 33/80: Accuracy : Train:91.89 	 Val:90.38 || Loss: Train 0.232 	 Val 0.266
# ```

# %% [markdown]
# ## 2.4 Test the model and plot the training stats.
#
# Use the same function from part 1 to:
# - Plot the training stats.
# - Test the model on the test data and print the test accuracy.

# %%
### START CODE HERE ### (approx. 5 lines)
device = "cuda"
path = "best_model_min_val_loss.pth"
plot_stats(dict_log, baseline=90, title='figs/exp_2_bloddmnist.png')
model = Net(base_channels=32, n_classes=8, batch_norm=True)
test_acc, test_loss = test_model(model, path, test_loader, device)
print(f"Test loss {test_acc} , test acc {test_loss}% ")
 ### END CODE HERE ###
# Out:
# Model best_model_min_val_loss.pth is loaded from epoch 79 , loss 0.1394263058900833
# Test loss 94.47116088867188 , test acc 0.167348712682724%

# %% [markdown]
# **Expected Results:**
#
# ![exp_2.png](https://raw.githubusercontent.com/HHU-MMBS/Deep-Learning-Exercise-Extras/main/a07-08_mednist/figs/exp_2_bloddmnist.png)

# %% [markdown]
# ## 2.5 Load, mofidy and train the resnet18
#
# Now we will use `torchvision.models`.
#
# - Load Resnet 18 from torchvision. How many trainble parameters does the network have?
# - Important: Do **not** use pretrained weights. We will train the model from scratch.
#
# Print the model.
# A. How should you modify the last linear layer?
# B. How is the first layer look like? If you were to modify the input conv layer how would you modify it for `bloddmnist` (3-channeled 28x28 images) ?
# Think about the size of the input image and the first conv layer. Is it a good choice? If not, what would you replace it with? Hint: resnets are designed for higher resolution images, i.e. 224x224.
#
#
# Train for at least 40 epochs and save the model with the best val score Compare the results with our small convnet.
#
# Expected results: 94-95 % validation set accuracy.
# No augmentations should been applied in the validation set. In this way, we can make an estimation of the test set performance (given the i.i.d. assumption).

# %%
import torchvision

def get_resnet18(in_channels, n_classes):
    ### START CODE HERE ### (approx. 3 lines)
    model = torchvision.models.resnet18(pretrained=False)
    model.conv1 = nn.Conv2d(in_channels, 64, kernel_size=3, stride=1, bias=False)
    model.fc = nn.Linear(512, n_classes)
    ### END CODE HERE ###
    return model

model_3 = get_resnet18(3, 8)
# Out:
# /home/adaloglo/miniconda3/envs/teach/lib/python3.7/site-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /home/adaloglo/miniconda3/envs/teach/lib/python3.7/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %% [markdown]
# ## 2.6 Train the resnet18
#
# - Train the resnet for at least 40 epochs (we trained for 80 epochs)
# - Plot train stats
# - Compute test accuracy

# %%
num_epochs = 80
path = "best_model_min_val_loss.pth"
### START CODE HERE ### (approx. 6 lines)
optimizer_3 = torch.optim.SGD(model_3.parameters(), lr=learning_rate, weight_decay=wd)
model_3 = model_3.to(device)
dict_log = train(model_3, optimizer_3, num_epochs, train_loader, val_loader, device)
plot_stats(dict_log, baseline=94, title='figs/exp_3_bloddmnist_resnet.png')
test_acc, test_loss = test_model(model_3, path, test_loader, device)
print(test_acc, test_loss)
### END CODE HERE ###
# Out:
# Init Accuracy of the model: Train:13.760 	 Val:13.822116
# Ep 0/80: Accuracy : Train:58.62 	 Val:73.38 || Loss: Train 1.258 	 Val 0.737
# Ep 1/80: Accuracy : Train:76.02 	 Val:78.67 || Loss: Train 0.682 	 Val 0.597
# Ep 2/80: Accuracy : Train:79.28 	 Val:82.27 || Loss: Train 0.559 	 Val 0.489
# Ep 3/80: Accuracy : Train:82.27 	 Val:84.80 || Loss: Train 0.489 	 Val 0.427
# Ep 4/80: Accuracy : Train:83.75 	 Val:85.64 || Loss: Train 0.446 	 Val 0.412
# Ep 5/80: Accuracy : Train:85.27 	 Val:86.42 || Loss: Train 0.404 	 Val 0.386
# Ep 6/80: Accuracy : Train:86.69 	 Val:87.74 || Loss: Train 0.378 	 Val 0.341
# Ep 7/80: Accuracy : Train:87.74 	 Val:85.16 || Loss: Train 0.341 	 Val 0.406
# Ep 8/80: Accuracy : Train:87.94 	 Val:90.08 || Loss: Train 0.328 	 Val 0.276
# Ep 9/80: Accuracy : Train:88.68 	 Val:89.24 || Loss: Train 0.310 	 Val 0.305
# Ep 10/80: Accuracy : Train:89.70 	 Val:85.46 || Loss: Train 0.290 	 Val 0.411
# Ep 11/80: Accuracy : Train:89.98 	 Val:90.32 || Loss: Train 0.280 	 Val 0.254
# Ep 12/80: Accuracy : Train:90.53 	 Val:89.90 || Loss: Train 0.264 	 Val 0.279
# Ep 13/80: Accuracy : Train:90.54 	 Val:91.77 || Loss: Train 0.259 	 Val 0.227
# Ep 14/80: Accuracy : Train:90.91 	 Val:90.93 || Loss: Train 0.252 	 Val 0.246
# Ep 15/80: Accuracy : Train:91.58 	 Val:87.68 || Loss: Train 0.238 	 Val 0.343
# Ep 16/80: Accuracy : Train:91.36 	 Val:86.90 || Loss: Train 0.238 	 Val 0.356
# Ep 17/80: Accuracy : Train:91.91 	 Val:93.21 || Loss: Train 0.228 	 Val 0.203
# Ep 18/80: Accuracy : Train:92.03 	 Val:92.13 || Loss: Train 0.215 	 Val 0.226
# Ep 19/80: Accuracy : Train:91.79 	 Val:89.72 || Loss: Train 0.225 	 Val 0.277
# Ep 20/80: Accuracy : Train:92.31 	 Val:92.43 || Loss: Train 0.213 	 Val 0.206
# Ep 21/80: Accuracy : Train:92.20 	 Val:92.97 || Loss: Train 0.211 	 Val 0.198
# Ep 22/80: Accuracy : Train:92.56 	 Val:93.03 || Loss: Train 0.205 	 Val 0.186
# Ep 23/80: Accuracy : Train:92.88 	 Val:92.85 || Loss: Train 0.198 	 Val 0.201
# Ep 24/80: Accuracy : Train:92.96 	 Val:82.39 || Loss: Train 0.193 	 Val 0.554
# Ep 25/80: Accuracy : Train:93.02 	 Val:93.27 || Loss: Train 0.189 	 Val 0.184
# Ep 26/80: Accuracy : Train:93.01 	 Val:91.77 || Loss: Train 0.187 	 Val 0.243
# Ep 27/80: Accuracy : Train:93.12 	 Val:92.19 || Loss: Train 0.189 	 Val 0.220
# Ep 28/80: Accuracy : Train:93.31 	 Val:93.27 || Loss: Train 0.185 	 Val 0.202
# Ep 29/80: Accuracy : Train:93.37 	 Val:92.55 || Loss: Train 0.180 	 Val 0.203
# Ep 30/80: Accuracy : Train:93.68 	 Val:89.48 || Loss: Train 0.174 	 Val 0.287
# Ep 31/80: Accuracy : Train:93.60 	 Val:94.77 || Loss: Train 0.180 	 Val 0.155
# Ep 32/80: Accuracy : Train:93.94 	 Val:93.51 || Loss: Train 0.166 	 Val 0.197
# Ep 33/80: Accuracy : Train:93.98 	 Val:93.87 || Loss: Train 0.166 	 Val 0.177
# Ep 34/80: Accuracy : Train:93.88 	 Val:95.01 || Loss: Train 0.167 	 Val 0.153
# Ep 35/80: Accuracy : Train:94.05 	 Val:94.29 || Loss: Train 0.164 	 Val 0.150
# Ep 36/80: Accuracy : Train:93.83 	 Val:92.73 || Loss: Train 0.164 	 Val 0.198
# Ep 37/80: Accuracy : Train:94.33 	 Val:92.73 || Loss: Train 0.157 	 Val 0.189
# Ep 38/80: Accuracy : Train:94.33 	 Val:94.17 || Loss: Train 0.158 	 Val 0.154
# Ep 39/80: Accuracy : Train:94.55 	 Val:95.13 || Loss: Train 0.151 	 Val 0.143
# Ep 40/80: Accuracy : Train:94.36 	 Val:93.75 || Loss: Train 0.154 	 Val 0.170
# Ep 41/80: Accuracy : Train:94.52 	 Val:94.17 || Loss: Train 0.146 	 Val 0.167
# Ep 42/80: Accuracy : Train:94.75 	 Val:93.69 || Loss: Train 0.144 	 Val 0.183
# Ep 43/80: Accuracy : Train:94.49 	 Val:94.89 || Loss: Train 0.148 	 Val 0.158
# Ep 44/80: Accuracy : Train:94.62 	 Val:95.19 || Loss: Train 0.145 	 Val 0.136
# Ep 45/80: Accuracy : Train:94.84 	 Val:94.41 || Loss: Train 0.140 	 Val 0.153
# Ep 46/80: Accuracy : Train:94.93 	 Val:92.55 || Loss: Train 0.141 	 Val 0.211
# Ep 47/80: Accuracy : Train:95.23 	 Val:94.41 || Loss: Train 0.132 	 Val 0.175
# Ep 48/80: Accuracy : Train:95.17 	 Val:88.88 || Loss: Train 0.133 	 Val 0.336
# Ep 49/80: Accuracy : Train:94.94 	 Val:93.69 || Loss: Train 0.137 	 Val 0.177
# Ep 50/80: Accuracy : Train:95.02 	 Val:94.71 || Loss: Train 0.133 	 Val 0.150
# Ep 51/80: Accuracy : Train:94.63 	 Val:92.67 || Loss: Train 0.137 	 Val 0.195
# Ep 52/80: Accuracy : Train:95.07 	 Val:95.31 || Loss: Train 0.131 	 Val 0.138
# Ep 53/80: Accuracy : Train:94.97 	 Val:94.71 || Loss: Train 0.130 	 Val 0.159
# Ep 54/80: Accuracy : Train:95.14 	 Val:95.31 || Loss: Train 0.132 	 Val 0.137
# Ep 55/80: Accuracy : Train:95.32 	 Val:92.31 || Loss: Train 0.131 	 Val 0.223
# Ep 56/80: Accuracy : Train:95.32 	 Val:94.23 || Loss: Train 0.122 	 Val 0.162
# Ep 57/80: Accuracy : Train:95.47 	 Val:93.87 || Loss: Train 0.122 	 Val 0.172
# Ep 58/80: Accuracy : Train:95.53 	 Val:94.05 || Loss: Train 0.122 	 Val 0.159
# Ep 59/80: Accuracy : Train:95.21 	 Val:94.71 || Loss: Train 0.129 	 Val 0.145
# Ep 60/80: Accuracy : Train:95.75 	 Val:95.67 || Loss: Train 0.118 	 Val 0.128
# Ep 61/80: Accuracy : Train:95.56 	 Val:94.83 || Loss: Train 0.121 	 Val 0.141
# Ep 62/80: Accuracy : Train:95.58 	 Val:95.49 || Loss: Train 0.118 	 Val 0.136
# Ep 63/80: Accuracy : Train:95.61 	 Val:94.23 || Loss: Train 0.116 	 Val 0.167
# Ep 64/80: Accuracy : Train:95.61 	 Val:95.13 || Loss: Train 0.119 	 Val 0.131
# Ep 65/80: Accuracy : Train:95.88 	 Val:93.69 || Loss: Train 0.113 	 Val 0.183
# Ep 66/80: Accuracy : Train:95.82 	 Val:95.49 || Loss: Train 0.114 	 Val 0.142
# Ep 67/80: Accuracy : Train:95.69 	 Val:94.35 || Loss: Train 0.116 	 Val 0.157
# Ep 68/80: Accuracy : Train:95.99 	 Val:93.45 || Loss: Train 0.109 	 Val 0.187
# Ep 69/80: Accuracy : Train:95.92 	 Val:94.05 || Loss: Train 0.111 	 Val 0.176
# Ep 70/80: Accuracy : Train:96.21 	 Val:94.89 || Loss: Train 0.109 	 Val 0.146
# Ep 71/80: Accuracy : Train:96.23 	 Val:91.17 || Loss: Train 0.103 	 Val 0.260
# Ep 72/80: Accuracy : Train:95.83 	 Val:95.25 || Loss: Train 0.111 	 Val 0.141
# Ep 73/80: Accuracy : Train:96.28 	 Val:94.47 || Loss: Train 0.104 	 Val 0.153
# Ep 74/80: Accuracy : Train:96.17 	 Val:94.47 || Loss: Train 0.106 	 Val 0.139
# Ep 75/80: Accuracy : Train:96.40 	 Val:91.59 || Loss: Train 0.101 	 Val 0.248
# Ep 76/80: Accuracy : Train:96.12 	 Val:94.29 || Loss: Train 0.106 	 Val 0.151
# Ep 77/80: Accuracy : Train:96.22 	 Val:94.71 || Loss: Train 0.105 	 Val 0.155
# Ep 78/80: Accuracy : Train:96.02 	 Val:94.17 || Loss: Train 0.106 	 Val 0.162
# Ep 79/80: Accuracy : Train:96.27 	 Val:94.83 || Loss: Train 0.099 	 Val 0.141
# Model best_model_min_val_loss.pth is loaded from epoch 60 , loss 0.1275501400232315
# 95.04207 0.14829579

# %% [markdown]
# ### Expected results
# ```
# Ep 1/80: Accuracy : Train:78.91 	 Val:82.63 || Loss: Train 0.643 	 Val 0.484
# .........
# Ep 13/80: Accuracy : Train:90.65 	 Val:92.55 || Loss: Train 0.276 	 Val 0.212
# .........
# Ep 32/80: Accuracy : Train:94.26 	 Val:94.47 || Loss: Train 0.176 	 Val 0.154
# .........
# Ep 42/80: Accuracy : Train:94.99 	 Val:94.95 || Loss: Train 0.152 	 Val 0.139
# .........
# Ep 60/80: Accuracy : Train:95.98 	 Val:95.31 || Loss: Train 0.126 	 Val 0.132
# .........
#
# ```

# %% [markdown]
# ![exp_3.png](https://raw.githubusercontent.com/HHU-MMBS/Deep-Learning-Exercise-Extras/main/a07-08_mednist/figs/exp_3_bloddmnist_resnet.png)

# %% [markdown]
# # 3. Scaling up to a larger dataset: pathmnist
#
# In this last part, we will scale up our dataset. We will use 'pathmnist' that has  `107,180 images`.
#
# **End Goal**: We would like to have a validation accuracy over 90% on pathmnist.
#
# ## 3.1 Load the new dataset and create the dataloaders
# We will use the same augmentations from part 2. Use a batch size of 256.

# %%
# Specify dataset
data_flag = 'pathmnist'
download = True
batch_size = 256
info = INFO[data_flag]
n_channels = info['n_channels']
n_classes = len(info['label'])
print("n_classes",n_classes)
DataClass = getattr(medmnist, info['python_class'])

mean = torch.tensor([0.5], dtype=torch.float32)
std = torch.tensor([0.5], dtype=torch.float32)


# Note: train_transform_augs needs to be already defined from part 2

plain_transform = T.Compose([
        T.ToTensor(),
        T.Normalize(list(mean), list(std))])

# load the data
train_ds = DataClass(split='train', transform=train_transform_augs, download=download)
train_plain = DataClass(split='train', transform=plain_transform, download=download)
val_ds = DataClass(split='val', transform=plain_transform, download=download)
test_ds = DataClass(split='test', transform=plain_transform, download=download)

train_loader = data.DataLoader(dataset=train_ds, batch_size=batch_size, shuffle=True, drop_last=True)
train_loader_plain = data.DataLoader(dataset=train_plain, batch_size=batch_size, shuffle=False, drop_last=True)
val_loader = data.DataLoader(dataset=val_ds, batch_size=batch_size, shuffle=False, drop_last=True)
test_loader = data.DataLoader(dataset=test_ds, batch_size=batch_size, shuffle=False, drop_last=True)

plt.figure(figsize = (50,20))
for i in range(10):
    imshow(train_ds[i][0], i, mean, std)
# Out:
# n_classes 9
# Using downloaded and verified file: /home/adaloglo/.medmnist/pathmnist.npz
# Using downloaded and verified file: /home/adaloglo/.medmnist/pathmnist.npz
# Using downloaded and verified file: /home/adaloglo/.medmnist/pathmnist.npz
# Using downloaded and verified file: /home/adaloglo/.medmnist/pathmnist.npz

# %% [markdown]
# ## 3.2 Train resnet18 on the pathmnist data
#
# The small convnet with batch-normalization we built in part 2 scores around 87% validation accuracy on pathmnist.
#
# We would like to have at least 90% though.
#
# You task is to surpass the performance of the convnet with resnet18. Train for at least 15 epochs (we trained for 30).

# %%
num_epochs = 30

# get the model and optimizer and launch training
### START CODE HERE ### (approx. 4 lines)
model_4 = get_resnet18(3, n_classes)
optimizer_4 = torch.optim.SGD(model_4.parameters(), lr=learning_rate, weight_decay=wd)
model_4 = model_4.to(device)
dict_log = train(model_4, optimizer_4, num_epochs, train_loader, val_loader, device)
### END CODE HERE ###
# Out:
# Init Accuracy of the model: Train:4.117 	 Val:3.695914
# Ep 0/30: Accuracy : Train:53.87 	 Val:63.17 || Loss: Train 1.269 	 Val 1.021
# Ep 1/30: Accuracy : Train:68.81 	 Val:69.71 || Loss: Train 0.846 	 Val 0.823
# Ep 2/30: Accuracy : Train:75.10 	 Val:75.76 || Loss: Train 0.679 	 Val 0.655
# Ep 3/30: Accuracy : Train:78.57 	 Val:77.27 || Loss: Train 0.586 	 Val 0.629
# Ep 4/30: Accuracy : Train:80.87 	 Val:70.96 || Loss: Train 0.523 	 Val 0.832
# Ep 5/30: Accuracy : Train:82.80 	 Val:77.95 || Loss: Train 0.470 	 Val 0.644
# Ep 6/30: Accuracy : Train:84.09 	 Val:72.80 || Loss: Train 0.436 	 Val 0.725
# Ep 7/30: Accuracy : Train:85.35 	 Val:73.39 || Loss: Train 0.406 	 Val 0.749
# Ep 8/30: Accuracy : Train:86.08 	 Val:73.60 || Loss: Train 0.381 	 Val 0.851
# Ep 9/30: Accuracy : Train:87.00 	 Val:83.94 || Loss: Train 0.360 	 Val 0.458
# Ep 10/30: Accuracy : Train:87.47 	 Val:75.18 || Loss: Train 0.346 	 Val 0.797
# Ep 11/30: Accuracy : Train:88.16 	 Val:88.63 || Loss: Train 0.329 	 Val 0.312
# Ep 12/30: Accuracy : Train:88.41 	 Val:86.16 || Loss: Train 0.321 	 Val 0.387
# Ep 13/30: Accuracy : Train:88.99 	 Val:84.43 || Loss: Train 0.307 	 Val 0.437
# Ep 14/30: Accuracy : Train:89.26 	 Val:85.80 || Loss: Train 0.297 	 Val 0.433
# Ep 15/30: Accuracy : Train:89.62 	 Val:84.19 || Loss: Train 0.287 	 Val 0.434
# Ep 16/30: Accuracy : Train:89.86 	 Val:89.70 || Loss: Train 0.279 	 Val 0.268
# Ep 17/30: Accuracy : Train:90.35 	 Val:89.76 || Loss: Train 0.270 	 Val 0.276
# Ep 18/30: Accuracy : Train:90.66 	 Val:84.74 || Loss: Train 0.260 	 Val 0.442
# Ep 19/30: Accuracy : Train:90.85 	 Val:85.30 || Loss: Train 0.252 	 Val 0.417
# Ep 20/30: Accuracy : Train:91.06 	 Val:77.20 || Loss: Train 0.247 	 Val 0.732
# Ep 21/30: Accuracy : Train:91.34 	 Val:90.67 || Loss: Train 0.240 	 Val 0.263
# Ep 22/30: Accuracy : Train:91.51 	 Val:81.66 || Loss: Train 0.235 	 Val 0.629
# Ep 23/30: Accuracy : Train:91.70 	 Val:91.94 || Loss: Train 0.229 	 Val 0.241
# Ep 24/30: Accuracy : Train:91.94 	 Val:88.81 || Loss: Train 0.223 	 Val 0.313
# Ep 25/30: Accuracy : Train:92.02 	 Val:89.47 || Loss: Train 0.220 	 Val 0.312
# Ep 26/30: Accuracy : Train:92.30 	 Val:89.36 || Loss: Train 0.215 	 Val 0.302
# Ep 27/30: Accuracy : Train:92.37 	 Val:90.96 || Loss: Train 0.212 	 Val 0.253
# Ep 28/30: Accuracy : Train:92.56 	 Val:89.28 || Loss: Train 0.207 	 Val 0.286
# Ep 29/30: Accuracy : Train:92.80 	 Val:88.30 || Loss: Train 0.201 	 Val 0.315

# %% [markdown]
# ### Expected results
#
# ```
# Ep 0/30: Accuracy : Train:54.65 	 Val:59.77 || Loss: Train 1.250 	 Val 1.109
# Ep 1/30: Accuracy : Train:68.83 	 Val:67.56 || Loss: Train 0.846 	 Val 0.856
# Ep 2/30: Accuracy : Train:74.67 	 Val:77.20 || Loss: Train 0.683 	 Val 0.626
# Ep 3/30: Accuracy : Train:78.21 	 Val:77.19 || Loss: Train 0.592 	 Val 0.616
# Ep 4/30: Accuracy : Train:80.79 	 Val:75.09 || Loss: Train 0.523 	 Val 0.701
# Ep 5/30: Accuracy : Train:82.82 	 Val:77.75 || Loss: Train 0.473 	 Val 0.612
# Ep 6/30: Accuracy : Train:84.26 	 Val:75.41 || Loss: Train 0.432 	 Val 0.812
# Ep 7/30: Accuracy : Train:85.42 	 Val:82.15 || Loss: Train 0.403 	 Val 0.493
# Ep 8/30: Accuracy : Train:86.25 	 Val:85.77 || Loss: Train 0.380 	 Val 0.376
# Ep 9/30: Accuracy : Train:86.97 	 Val:84.85 || Loss: Train 0.359 	 Val 0.434
# Ep 10/30: Accuracy : Train:87.64 	 Val:87.33 || Loss: Train 0.344 	 Val 0.348
# Ep 11/30: Accuracy : Train:88.25 	 Val:82.01 || Loss: Train 0.327 	 Val 0.498
# Ep 12/30: Accuracy : Train:88.48 	 Val:85.16 || Loss: Train 0.318 	 Val 0.402
# Ep 13/30: Accuracy : Train:89.02 	 Val:64.41 || Loss: Train 0.302 	 Val 1.363
# Ep 14/30: Accuracy : Train:89.69 	 Val:87.13 || Loss: Train 0.288 	 Val 0.355
# Ep 15/30: Accuracy : Train:89.99 	 Val:76.81 || Loss: Train 0.278 	 Val 0.824
# Ep 16/30: Accuracy : Train:90.34 	 Val:85.36 || Loss: Train 0.270 	 Val 0.422
# Ep 17/30: Accuracy : Train:90.33 	 Val:88.70 || Loss: Train 0.266 	 Val 0.318
# Ep 18/30: Accuracy : Train:90.86 	 Val:90.31 || Loss: Train 0.255 	 Val 0.270
# Ep 19/30: Accuracy : Train:91.02 	 Val:88.05 || Loss: Train 0.252 	 Val 0.338
# Ep 20/30: Accuracy : Train:91.33 	 Val:85.67 || Loss: Train 0.242 	 Val 0.465
# Ep 21/30: Accuracy : Train:91.67 	 Val:88.29 || Loss: Train 0.234 	 Val 0.332
# Ep 22/30: Accuracy : Train:91.70 	 Val:88.51 || Loss: Train 0.234 	 Val 0.320
# Ep 23/30: Accuracy : Train:91.96 	 Val:86.76 || Loss: Train 0.226 	 Val 0.363
# ...
# Ep 26/30: Accuracy : Train:92.47 	 Val:83.11 || Loss: Train 0.209 	 Val 0.488
# Ep 27/30: Accuracy : Train:92.68 	 Val:90.78 || Loss: Train 0.205 	 Val 0.266
# Ep 28/30: Accuracy : Train:92.88 	 Val:91.98 || Loss: Train 0.198 	 Val 0.225
# Ep 29/30: Accuracy : Train:92.99 	 Val:90.18 || Loss: Train 0.196 	 Val 0.271
# ```

# %%
path = "best_model_min_val_loss.pth"
# Load model and plot training curves and compute test accuracy
### START CODE HERE ### (approx. 4 lines)
plot_stats(dict_log, baseline=90, title='figs/exp_4_pathmnist_resnet.png')
model_4 = get_resnet18(3, n_classes)
test_acc, test_loss = test_model(model_4, path, test_loader, device)
print(test_acc, test_loss)
### END CODE HERE ###
# Out:
# Model best_model_min_val_loss.pth is loaded from epoch 23 , loss 0.2413192093372345
# 85.47713 0.53939235

# %% [markdown]
# ## Expected results
#
# Model best_model_min_val_loss.pth is loaded from epoch 28 , loss 0.22461184859275818
# Test acc 83.314735 , test loss 0.58688146
#
# ![exp_4_pathmnist_resnet.png](https://raw.githubusercontent.com/HHU-MMBS/Deep-Learning-Exercise-Extras/main/a07-08_mednist/figs/exp_4_pathmnist_resnet.png)
#
#
# How is the train/val/test accuracies are related? What differences do you observe compared to using when scaling up to the larger dataset?

# %% [markdown]
# # Further reading
# - [Skip connections](https://theaisummer.com/skip-connections/)
# - [Why does batch norm work](https://www.youtube.com/watch?v=nUUqwaxLnWs)
