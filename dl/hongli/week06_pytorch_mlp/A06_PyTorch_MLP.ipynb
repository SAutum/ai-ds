# %% [markdown]
# HHU Deep Learning, WS2023/24, 17.11.2023
#
# Lecture: Prof. Dr. Markus Kollmann
#
# Exercises: Nikolas Adaloglou, Felix Michels
#
# # Assignment 6 - Neural Networks with PyTorch
#
# ---
#
# Submit the solved notebook (not a zip) with your full name plus assingment number for the filename as an indicator, e.g `max_mustermann_a1.ipynb` for assignment 1. If we feel like you have genuinely tried to solve the exercise, you will receive 1 point for this assignment, regardless of the quality of your solution.
#
# ## <center> DUE FRIDAY 24.11.2023 2:30 pm </center>
#
# Drop-off link: [https://uni-duesseldorf.sciebo.de/s/1OQhEkR4QtlzkfF](https://uni-duesseldorf.sciebo.de/s/1OQhEkR4QtlzkfF)
#
# ---

# %% [markdown]
# Until now, we have used the numpy package to write our own helper functions for forward-, backward-passes of layers, activation functions, wrote our own cost functions and optimizers, etc. Now, we want to automate all of this with the use of a Deep Learning Framework.
#
# There are various big packages (frameworks) that offer functionality specialized in Machine/Deep Learning.
#
# The two most well known ones are **PyTorch** from Meta and **TensorFlow** from Google. In this course, we will work with PyTorch as it provides a good tradeoff between ease of use for academic purposes and scalability to large projects in future reasearch.
#
# Next to implementations of functions like Neural Network layers, optimizers, etc., PyTorch has three main features:
# - The tensor datastructure, which is similar to the Numpy ndarray
# - Automatic differentiation for training neural networks
# - It allows us to run code on a GPU, which offers significantly  faster computations.
#
# ![Pytorch_logo.png](https://github.com/HHU-MMBS/Deep-Learning-Exercise-Extras/raw/main/a06_pytorch_mlp/images/Pytorch_logo.png)
#
# Feel free to use the PyTorch Introduction from week 1 as a look-up for basic PyTorch functionality.
#
# ---
#
# For this assignment, you will use PyTorch to implement a fully connected Neural Network, perform a set of experiments on the famous CIFAR10 dataset and report your results and findings.
#
# For your experiments, you will create a multilayer perceptron (MLP) Neural Network and train it on the CIFAR10 dataset to predict object class based on the input image. CIFAR10 image dimensions are 32 by 32, with 3 values for each pixel (R, G, B).
#
# **Goal: Your goal is to develop an image classifier that scores more than 50% accuracy on the validation data.**

# %% [markdown]
# # 1. Imports and preparing the dataset and dataloaders
#
#
# If you are using google colab remember to change the runtime type to GPU.
#
# To get started, run the following code to import the libraries you will need.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (7.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# We will be using a GPU to accelerate training and testing. PyTorch lets you use the GPU with very little additional code. The `torch.cuda` package contains all available functions for GPU usage. Check out the docs on the [package](https://pytorch.org/docs/stable/cuda.html) and on [cuda semantics](https://pytorch.org/docs/stable/notes/cuda.html#cuda-semantics) if you want to learn more, this is not required for this assignment though.
#
# If you don't have a dedicated GPU in your own machine, the easiest way to get one is Google Colab! It's free, all you need is a Google account and you get ~8 hrs of GPU time per day.
#
# Below is a small, good-practice, GPU setup to check the availability of a GPU in your system.

# %%
# GPU
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
print('device:', device)
# Out:
# device: cuda:0

# %% [markdown]
# # 2. CIFAR-10 Dataset
#
# Today, we'll use the famous CIFAR-10 dataset for an image classification task. PyTorch provides many built-in datasets in the [torchvision.datasets](https://pytorch.org/vision/stable/datasets.html) module, as well as utility classes for building your own datasets.
#
# The code below:
# - Defines some basic transforms for preprocessing the data
# - Loads the CIFAR-10 dataset as a PyTorch dataset class. The raw data is stored locally on your machine.

# %%
# Data transforms
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# Datasets
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
valset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# PyTorch provides a convenient solution for batch training. After loading the dataset and setting parameters like batch_size, train and an optional transformation (normalization in this case), we can use the DataLoader object as an iterator for the training loop. It will return the outputs of the `__getitem__(...)` function of the dataset class in a batched form, ready to be used for batch-gradient descent.
#
# **Exercise:** Instantiate two DataLoaders, one for the training set and one for the validation set. Adjust the batch size to your available GPU memory, usual choices are powers of 2, like 16, 32, 64, ..., for reasons that have to do with the hardware layout on GPUs.

# %%
### START CODE HERE ### (approx. 2 lines)
train_loader = torch.utils.data.DataLoader(trainset, batch_size = 128, shuffle = True, num_workers = 1)
val_loader = torch.utils.data.DataLoader(valset, batch_size = 128, shuffle = True, num_workers = 1)
### END CODE HERE ###

# %% [markdown]
# Below you can see how to access information regarding the dataset and the dataloaders.

# %%
# dataset instance
print("List of label names are:", trainset.classes)
print("Total training images:", len(trainset))
img, label = trainset[0]
print(f"Example image with shape {img.shape}, label {label}, which is a {trainset.classes[label]} ")

# DataLoader instance
print(f'The dataloader contains {len(train_loader)} batches.')
imgs_batch , labels_batch = next(iter(train_loader))
print(f"A batch of images has shape {imgs_batch.shape}, labels {labels_batch.shape}")
# Out:
# List of label names are: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Total training images: 50000
# Example image with shape torch.Size([3, 32, 32]), label 6, which is a frog
# The dataloader contains 391 batches.
# A batch of images has shape torch.Size([128, 3, 32, 32]), labels torch.Size([128])

# %% [markdown]
# # 3. Define the MLP model
#
# Now it's your turn to implement a Multi-Layer Perceptron (MLP / fully connected net) with variable depth, similar to the last exercise. Your Network needs to:
#
# - Have L-1 blocks of linear layers, followed by ReLU activations, check out nn.Linear and nn.ReLU
# - Have a final 'out_layer' with just a linear layer
# - Have choosable dimensions for all hidden layers, via the 'hidden_sizes' parameter, e.g. [32, 16] is a three-layer model.
#
# The `torch.nn` functions, like `nn.Linear`, have all the functionality you need for training the network already built into them. No more manual backward-computation or remembering intermediate results in a cache, PyTorch takes care of that.
#
# You need to define your network architecture in the `__init__`, by initialising things like layers and activation functions and then call them in the forward pass to process the input `x`.
#
# Tip: In the `__init__`, you can save 'nn.' objects in a list and then pass them to `nn.Sequential` as an unpacked list:
#
# ```
# layers = nn.ModuleList()
# ... fill the list ...
# self.layers = nn.Sequential(*layers)
# ```
#
# See the `PyTorch Module API` and `PyTorch Sequential API` sections from the PyTorch Introduction from week 1 for help on the implementation here.

# %%
# Model structure
class MLP(nn.Module):
    def __init__(self, in_channels, num_classes, hidden_sizes=[64]):
        super(MLP, self).__init__()
        assert len(hidden_sizes) >= 1 , "specify at least one hidden layer"
        ### START CODE HERE ### (approx. 7 lines)
        self.layers = []
        for i in range(len(hidden_sizes)):
          if i == 0:
            self.layers.append(nn.Linear(in_channels, hidden_sizes[i]))
          else:
            self.layers.append(nn.Linear(hidden_sizes[i-1], hidden_sizes[i]))
          self.layers.append(nn.ReLU())
        self.layers = nn.Sequential(*self.layers)
        self.out_layer = nn.Linear(hidden_sizes[i], num_classes)
        ### END CODE HERE ###

    def forward(self, x):
        ### START CODE HERE ### (approx. 3 lines)
        out = x.view(x.shape[0], -1)
        for layer in self.layers:
          out = layer(out)
        out = self.out_layer(out)
        ### END CODE HERE ###
        return out

# %% [markdown]
# Use the function below to test your implementation. The parameter settings are not fitted to CIFAR-10, you will need different values later on!
#
# Below you also find an expected output of what the network structure should look like. Note that this print varies based on your syntax, even if the logic is correct. Use it as a guide, you don't need to exactly replicate it.

# %%
# Test your implementation with random data
test_model = MLP(in_channels=3*10*10, num_classes=4, hidden_sizes=[64, 32, 16]).to(device)

a = torch.rand(16, 3, 10, 10).to(device)
b = test_model(a)
assert b.shape == (16,4)
print('Shape test passed')
print(test_model)
# Out:
# Shape test passed
# MLP(
#   (layers): Sequential(
#     (0): Linear(in_features=300, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): ReLU()
#   )
#   (out_layer): Linear(in_features=16, out_features=4, bias=True)
# )

# %% [markdown]
# **Expected Output:**
#
# ```
# Shape test passed
# Net(
#   (layers): Sequential(
#     (0): Linear(in_features=300, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): ReLU()
#   )
#   (out_layer): Linear(in_features=16, out_features=4, bias=True)
# )
# ```

# %% [markdown]
# # 4. Training and Validation
#
# Equipped with our MLP model, we now want to train it.
#
# First, we implement the validation function, so we can use it in the train function. The idea is to test our model on the (unseen) validation data in regular intervals during training, e.g. after every epoch (traversal of the whole dataset).
#
# **Exercise:** Implement the validation function, which reads in data from the `val_loader`, runs a forward pass and records the classification accuracy, as well as the loss. Both are returned for plotting purposes.
#
# We will be using the `nn.CrossEntropyLoss` as our loss function. Please have a look at the [docs](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html) for this loss function, you will use it more often in the future.
#
# Loss functions in PyTorch are instantiated as class objects (nn.CrossEntropyLoss is the class here) and can then be used like a function:
#
# ```
# criterion = nn.CrossEntropyLoss()
# loss = criterion(input,target)
# ```
#
# Note, that `nn.CrossEntropyLoss` combines a Softmax activation with the actual loss function, a negative log-likelihood loss. So, it expects **unnormalized!** scores from our network, i.e. no activation funciton after the last layer.

# %%
def validation(model, val_loader):
    criterion = nn.CrossEntropyLoss()
    correct = 0
    val_loss = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            ### START CODE HERE ### (approx. 8 lines)
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            val_loss += criterion(outputs, labels)
            correct += sum(outputs.argmax(dim=1) == labels)
    val_acc = correct/len(val_loader.dataset) # number of validation samples
    val_acc = val_acc.item()
    val_loss = (val_loss/len(val_loader)).item() # number of batches(batch size)
    ### END CODE HERE ###
    return val_acc, val_loss

# %%
# Don't mind this, is just for testing
class dummy_dataset(torch.utils.data.Dataset):
    def __init__(self):
        self.data = torch.rand(16, 3, 10, 10)
        self.labels = torch.randint(0, 4, (16,))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

# %% [markdown]
# Use the code below to test your implementation with the above initialized `test_model`.

# %%
# Test validation with an untrained model
test_set = dummy_dataset()
test_loader = torch.utils.data.DataLoader(test_set, batch_size=4)

# Needs to run without errors
validation(test_model, test_loader)
# Out:
# (0.25, 1.4458050727844238)

# %% [markdown]
# Now, we can implement the train loop itself.  You are already familiar with the basic training procedure:
#
# Loop for num_iterations:
# 1. Forward propagation
# 2. Compute loss function
# 3. Backward propagation
# 4. Update parameters

# %%
def train(model, train_loader, val_loader, epochs, lr, momentum, wd):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=wd)
    train_loss_hist = []
    val_loss_hist = []
    val_acc_hist = []
    for epoch in range(epochs):
        for inputs, labels in train_loader:
            ### START CODE HERE ### (approx. 7 lines)
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            train_loss = criterion(outputs, labels)

            optimizer.zero_grad()
            train_loss.backward()
            optimizer.step()

            train_loss_hist.append(train_loss.item())
            ### END CODE HERE ###
        # stats
        val_acc, val_loss = validation(model, val_loader)
        val_acc_hist.append(val_acc)
        val_loss_hist.append(val_loss)
        print(f"Epoch {epoch+1}/{epochs} done. Train loss: {np.mean(train_loss_hist[-len(train_loader):]):.3f} val loss: {val_loss_hist[-1]:.3f} Val. Accuracy : {val_acc_hist[-1]*100:.3f}%.")

    dict_log = {"train_loss_hist": train_loss_hist, "val_loss_hist": val_loss_hist, "val_acc_hist": val_acc_hist}
    return dict_log

# %% [markdown]
# **Exercise:** Choose a single set of hyperparameters (lr, momentum, wd, epochs), as well as a model configuration and see how the model performs. Save the dict_log for plotting later on.

# %%
### START CODE HERE ### (approx. 4 lines)
in_channels = img.shape[0] * img.shape[1] * img.shape[2]
num_classes = len(trainset.classes)
hidden_sizes = [75, 35, 12]
lr, momentum, wd, epochs = [0.01, 0.9,  0.001, 30]
### END CODE HERE ###

model = MLP(in_channels, num_classes, hidden_sizes).to(device)

dict_log = train(model, train_loader, val_loader, epochs, lr, momentum, wd)
# Out:
# Epoch 1/30 done. Train loss: 1.989 val loss: 1.730 Val. Accuracy : 37.490%.
# Epoch 2/30 done. Train loss: 1.654 val loss: 1.578 Val. Accuracy : 43.720%.
# Epoch 3/30 done. Train loss: 1.534 val loss: 1.497 Val. Accuracy : 46.790%.
# Epoch 4/30 done. Train loss: 1.452 val loss: 1.471 Val. Accuracy : 48.010%.
# Epoch 5/30 done. Train loss: 1.393 val loss: 1.435 Val. Accuracy : 48.700%.
# Epoch 6/30 done. Train loss: 1.349 val loss: 1.423 Val. Accuracy : 49.980%.
# Epoch 7/30 done. Train loss: 1.310 val loss: 1.404 Val. Accuracy : 50.280%.
# Epoch 8/30 done. Train loss: 1.275 val loss: 1.375 Val. Accuracy : 51.610%.
# Epoch 9/30 done. Train loss: 1.250 val loss: 1.418 Val. Accuracy : 49.970%.
# Epoch 10/30 done. Train loss: 1.226 val loss: 1.408 Val. Accuracy : 50.050%.
# Epoch 11/30 done. Train loss: 1.210 val loss: 1.402 Val. Accuracy : 50.730%.
# Epoch 12/30 done. Train loss: 1.191 val loss: 1.396 Val. Accuracy : 51.010%.
# Epoch 13/30 done. Train loss: 1.164 val loss: 1.392 Val. Accuracy : 50.960%.
# Epoch 14/30 done. Train loss: 1.148 val loss: 1.384 Val. Accuracy : 51.580%.
# Epoch 15/30 done. Train loss: 1.143 val loss: 1.412 Val. Accuracy : 50.670%.
# Epoch 16/30 done. Train loss: 1.119 val loss: 1.381 Val. Accuracy : 51.540%.
# Epoch 17/30 done. Train loss: 1.110 val loss: 1.389 Val. Accuracy : 51.150%.
# Epoch 18/30 done. Train loss: 1.093 val loss: 1.426 Val. Accuracy : 50.820%.
# Epoch 19/30 done. Train loss: 1.085 val loss: 1.410 Val. Accuracy : 51.320%.
# Epoch 20/30 done. Train loss: 1.074 val loss: 1.424 Val. Accuracy : 51.740%.
# Epoch 21/30 done. Train loss: 1.062 val loss: 1.439 Val. Accuracy : 50.600%.
# Epoch 22/30 done. Train loss: 1.058 val loss: 1.426 Val. Accuracy : 51.140%.
# Epoch 23/30 done. Train loss: 1.052 val loss: 1.439 Val. Accuracy : 50.420%.
# Epoch 24/30 done. Train loss: 1.038 val loss: 1.422 Val. Accuracy : 51.180%.
# Epoch 25/30 done. Train loss: 1.027 val loss: 1.446 Val. Accuracy : 51.340%.
# Epoch 26/30 done. Train loss: 1.024 val loss: 1.439 Val. Accuracy : 50.360%.
# Epoch 27/30 done. Train loss: 1.016 val loss: 1.431 Val. Accuracy : 51.030%.
# Epoch 28/30 done. Train loss: 1.006 val loss: 1.447 Val. Accuracy : 51.040%.
# Epoch 29/30 done. Train loss: 0.998 val loss: 1.477 Val. Accuracy : 50.480%.
# Epoch 30/30 done. Train loss: 0.993 val loss: 1.462 Val. Accuracy : 50.450%.

# %% [markdown]
# # 6. Plotting results
#
# The code below plots the results of the training. We compare train and validation loss in the same plot to check for overfitting or other undesirable training behaviour.

# %%
def loss_plot(title):
    plt.figure(figsize=(10,5))
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Cross Entropy Loss")

def acc_plot(title):
    plt.figure(figsize=(10,5))
    plt.title(title)
    plt.axhline(y = 0.5, color = 'r', linestyle = '-', label='Good accuracy')
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")

# %%
x_val = np.arange(1, epochs+1)
train_loss_hist_epochs = [np.mean(dict_log["train_loss_hist"][i*len(train_loader):(i+1)*len(train_loader)]) for i in range(epochs)]

loss_plot('Losses per Epoch')
plt.scatter(x_val, dict_log["val_loss_hist"], label='Validation loss')
plt.scatter(x_val, train_loss_hist_epochs, label='Train loss')
plt.legend()
plt.savefig('Losses1.png')
plt.show()

plt.figure(figsize=(14,8))
acc_plot('Validation Accuracy per epoch')
plt.scatter(x_val, dict_log["val_acc_hist"])
plt.plot(x_val, dict_log["val_acc_hist"], label='Validation Accuracy')
plt.legend()
plt.savefig('Accuracy1.png')
plt.show()

# %% [markdown]
# **Expected Output:** Your plots should look somewhat similar to this:
#
# ![Losses1.png](https://github.com/HHU-MMBS/Deep-Learning-Exercise-Extras/raw/main/a06_pytorch_mlp/images/Losses1.png)

# %% [markdown]
# ![Accuracy1.png](https://github.com/HHU-MMBS/Deep-Learning-Exercise-Extras/raw/main/a06_pytorch_mlp/images/Accuracy1.png)

# %% [markdown]
# # 7. Hyperparameter tuning
#
# Lastly, we want to squeeze some more performance out of our model by tuning its hyperparameters.
#
# **Exercise:** Implement the function hparam_tuning below. It should:
# - Take in lists of hyperparameters
# - Test every possible combination of them.
#
# The epochs, in_channels and num_classes are fixed. You can experiment with the parameters hidden sizes, learning rate, momentum and weight decay.
#
# Save the dictionaries returned by the train function in the logs_out list. Don't forget to re-initialize your model before each run with new hyperparameters

# %%
def hparam_tuning(epochs, in_channels, hidden_sizes, lrs, momentums, wds, num_classes=10):
    """
    params:
    epochs: int
    in_channels: int
    num_classes: int
    hidden_sizes: list of lists of ints
    lrs/momentums/wds: list of floats
    """
    logs_out = []
    ### START CODE HERE ### (approx. 7 lines)
    for hidden_size in hidden_sizes:
      model = MLP(in_channels, num_classes, hidden_size).to(device)
      lrs_, momentums_, wds_ = torch.meshgrid(torch.tensor(lrs), torch.tensor(momentums), torch.tensor(wds))
      for lr, momentum, wd in zip(torch.flatten(lrs_), torch.flatten(momentums_), torch.flatten(wds_)):
        dict_log = train(model, train_loader, val_loader, epochs, lr.item(), momentum.item(), wd.item())
        logs_out.append(dict_log)
    ### END CODE HERE ###
    return logs_out

# %% [markdown]
# **Exercise:** Pick **at least 4 combinations of hyperparameters** and use them for a comparative series of training runs. Since you pass lists of hyperparameters, this means two of the lists need to be at least of length 2.

# %%
### START CODE HERE ### (approx. 4 lines)
epochs = 40
hidden_sizes = [[60, 30, 10]]
lrs = [0.01, 0.1]
momentums = [0.85, 0.9]
wds = [0.005]
### END CODE HERE ###

logs_out = hparam_tuning(epochs, in_channels, hidden_sizes, lrs, momentums, wds)

plt.figure(figsize=(14,8))
acc_plot("Validation accuracy for different hyperparameter sets")
for c, dict_out in enumerate(logs_out):
    x_val = list(range(len(dict_out["val_acc_hist"])))
    plt.scatter(x_val, dict_out["val_acc_hist"])
    plt.plot(x_val, dict_out["val_acc_hist"], label=f"HP set {c+1}")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Epoch 1/40 done. Train loss: 2.053 val loss: 1.804 Val. Accuracy : 36.600%.
# Epoch 2/40 done. Train loss: 1.727 val loss: 1.639 Val. Accuracy : 41.340%.
# Epoch 3/40 done. Train loss: 1.605 val loss: 1.570 Val. Accuracy : 43.850%.
# Epoch 4/40 done. Train loss: 1.534 val loss: 1.536 Val. Accuracy : 45.120%.
# Epoch 5/40 done. Train loss: 1.487 val loss: 1.499 Val. Accuracy : 46.390%.
# Epoch 6/40 done. Train loss: 1.447 val loss: 1.505 Val. Accuracy : 46.420%.
# Epoch 7/40 done. Train loss: 1.414 val loss: 1.433 Val. Accuracy : 49.100%.
# Epoch 8/40 done. Train loss: 1.390 val loss: 1.442 Val. Accuracy : 48.410%.
# Epoch 9/40 done. Train loss: 1.365 val loss: 1.426 Val. Accuracy : 49.140%.
# Epoch 10/40 done. Train loss: 1.343 val loss: 1.415 Val. Accuracy : 50.070%.
# Epoch 11/40 done. Train loss: 1.333 val loss: 1.423 Val. Accuracy : 49.930%.
# Epoch 12/40 done. Train loss: 1.319 val loss: 1.398 Val. Accuracy : 50.490%.
# Epoch 13/40 done. Train loss: 1.304 val loss: 1.416 Val. Accuracy : 50.130%.
# Epoch 14/40 done. Train loss: 1.298 val loss: 1.411 Val. Accuracy : 49.840%.
# Epoch 15/40 done. Train loss: 1.285 val loss: 1.411 Val. Accuracy : 49.580%.
# Epoch 16/40 done. Train loss: 1.276 val loss: 1.388 Val. Accuracy : 50.560%.
# Epoch 17/40 done. Train loss: 1.267 val loss: 1.375 Val. Accuracy : 51.390%.
# Epoch 18/40 done. Train loss: 1.260 val loss: 1.402 Val. Accuracy : 51.070%.
# Epoch 19/40 done. Train loss: 1.258 val loss: 1.417 Val. Accuracy : 49.620%.
# Epoch 20/40 done. Train loss: 1.247 val loss: 1.429 Val. Accuracy : 49.550%.
# Epoch 21/40 done. Train loss: 1.247 val loss: 1.376 Val. Accuracy : 51.680%.
# Epoch 22/40 done. Train loss: 1.239 val loss: 1.384 Val. Accuracy : 51.280%.
# Epoch 23/40 done. Train loss: 1.234 val loss: 1.369 Val. Accuracy : 51.980%.
# Epoch 24/40 done. Train loss: 1.227 val loss: 1.371 Val. Accuracy : 51.880%.
# Epoch 25/40 done. Train loss: 1.225 val loss: 1.359 Val. Accuracy : 52.010%.
# Epoch 26/40 done. Train loss: 1.219 val loss: 1.355 Val. Accuracy : 52.060%.
# Epoch 27/40 done. Train loss: 1.216 val loss: 1.390 Val. Accuracy : 51.470%.
# Epoch 28/40 done. Train loss: 1.212 val loss: 1.368 Val. Accuracy : 51.950%.
# Epoch 29/40 done. Train loss: 1.210 val loss: 1.428 Val. Accuracy : 49.710%.
# Epoch 30/40 done. Train loss: 1.204 val loss: 1.388 Val. Accuracy : 50.510%.
# Epoch 31/40 done. Train loss: 1.201 val loss: 1.356 Val. Accuracy : 52.090%.
# Epoch 32/40 done. Train loss: 1.198 val loss: 1.375 Val. Accuracy : 50.960%.
# Epoch 33/40 done. Train loss: 1.199 val loss: 1.361 Val. Accuracy : 51.980%.
# Epoch 34/40 done. Train loss: 1.196 val loss: 1.384 Val. Accuracy : 51.410%.
# Epoch 35/40 done. Train loss: 1.192 val loss: 1.376 Val. Accuracy : 51.890%.
# Epoch 36/40 done. Train loss: 1.188 val loss: 1.374 Val. Accuracy : 51.830%.
# Epoch 37/40 done. Train loss: 1.185 val loss: 1.367 Val. Accuracy : 51.180%.
# Epoch 38/40 done. Train loss: 1.187 val loss: 1.373 Val. Accuracy : 51.730%.
# Epoch 39/40 done. Train loss: 1.184 val loss: 1.377 Val. Accuracy : 51.440%.
# Epoch 40/40 done. Train loss: 1.178 val loss: 1.367 Val. Accuracy : 51.900%.
# Epoch 1/40 done. Train loss: 1.239 val loss: 1.395 Val. Accuracy : 50.660%.
# Epoch 2/40 done. Train loss: 1.237 val loss: 1.398 Val. Accuracy : 49.930%.
# Epoch 3/40 done. Train loss: 1.235 val loss: 1.389 Val. Accuracy : 50.670%.
# Epoch 4/40 done. Train loss: 1.228 val loss: 1.381 Val. Accuracy : 50.730%.
# Epoch 5/40 done. Train loss: 1.233 val loss: 1.372 Val. Accuracy : 51.420%.
# Epoch 6/40 done. Train loss: 1.232 val loss: 1.369 Val. Accuracy : 51.250%.
# Epoch 7/40 done. Train loss: 1.231 val loss: 1.400 Val. Accuracy : 50.850%.
# Epoch 8/40 done. Train loss: 1.235 val loss: 1.373 Val. Accuracy : 51.890%.
# Epoch 9/40 done. Train loss: 1.228 val loss: 1.359 Val. Accuracy : 51.910%.
# Epoch 10/40 done. Train loss: 1.230 val loss: 1.359 Val. Accuracy : 51.800%.
# Epoch 11/40 done. Train loss: 1.227 val loss: 1.378 Val. Accuracy : 51.280%.
# Epoch 12/40 done. Train loss: 1.228 val loss: 1.359 Val. Accuracy : 51.950%.
# Epoch 13/40 done. Train loss: 1.226 val loss: 1.395 Val. Accuracy : 50.120%.
# Epoch 14/40 done. Train loss: 1.228 val loss: 1.365 Val. Accuracy : 51.460%.
# Epoch 15/40 done. Train loss: 1.227 val loss: 1.364 Val. Accuracy : 51.790%.
# Epoch 16/40 done. Train loss: 1.224 val loss: 1.360 Val. Accuracy : 51.950%.
# Epoch 17/40 done. Train loss: 1.226 val loss: 1.360 Val. Accuracy : 52.100%.
# Epoch 18/40 done. Train loss: 1.224 val loss: 1.412 Val. Accuracy : 50.170%.
# Epoch 19/40 done. Train loss: 1.224 val loss: 1.366 Val. Accuracy : 51.600%.
# Epoch 20/40 done. Train loss: 1.224 val loss: 1.386 Val. Accuracy : 50.830%.
# Epoch 21/40 done. Train loss: 1.220 val loss: 1.370 Val. Accuracy : 50.720%.
# Epoch 22/40 done. Train loss: 1.218 val loss: 1.424 Val. Accuracy : 48.920%.
# Epoch 23/40 done. Train loss: 1.222 val loss: 1.373 Val. Accuracy : 51.180%.
# Epoch 24/40 done. Train loss: 1.213 val loss: 1.332 Val. Accuracy : 52.770%.
# Epoch 25/40 done. Train loss: 1.217 val loss: 1.359 Val. Accuracy : 51.750%.
# Epoch 26/40 done. Train loss: 1.213 val loss: 1.403 Val. Accuracy : 50.660%.
# Epoch 27/40 done. Train loss: 1.217 val loss: 1.384 Val. Accuracy : 51.380%.
# Epoch 28/40 done. Train loss: 1.214 val loss: 1.383 Val. Accuracy : 50.800%.
# Epoch 29/40 done. Train loss: 1.213 val loss: 1.388 Val. Accuracy : 50.910%.
# Epoch 30/40 done. Train loss: 1.214 val loss: 1.358 Val. Accuracy : 51.380%.
# Epoch 31/40 done. Train loss: 1.212 val loss: 1.371 Val. Accuracy : 51.490%.
# Epoch 32/40 done. Train loss: 1.216 val loss: 1.350 Val. Accuracy : 51.650%.
# Epoch 33/40 done. Train loss: 1.214 val loss: 1.380 Val. Accuracy : 51.000%.
# Epoch 34/40 done. Train loss: 1.211 val loss: 1.367 Val. Accuracy : 51.650%.
# Epoch 35/40 done. Train loss: 1.211 val loss: 1.388 Val. Accuracy : 50.470%.
# Epoch 36/40 done. Train loss: 1.222 val loss: 1.345 Val. Accuracy : 52.290%.
# Epoch 37/40 done. Train loss: 1.205 val loss: 1.353 Val. Accuracy : 52.220%.
# Epoch 38/40 done. Train loss: 1.207 val loss: 1.367 Val. Accuracy : 51.520%.
# Epoch 39/40 done. Train loss: 1.208 val loss: 1.373 Val. Accuracy : 50.950%.
# Epoch 40/40 done. Train loss: 1.198 val loss: 1.353 Val. Accuracy : 52.070%.
# Epoch 1/40 done. Train loss: 1.613 val loss: 1.628 Val. Accuracy : 41.070%.
# Epoch 2/40 done. Train loss: 1.590 val loss: 1.619 Val. Accuracy : 41.240%.
# Epoch 3/40 done. Train loss: 1.590 val loss: 1.590 Val. Accuracy : 43.700%.
# Epoch 4/40 done. Train loss: 1.591 val loss: 1.600 Val. Accuracy : 42.310%.
# Epoch 5/40 done. Train loss: 1.584 val loss: 1.572 Val. Accuracy : 44.530%.
# Epoch 6/40 done. Train loss: 1.587 val loss: 1.582 Val. Accuracy : 43.610%.
# Epoch 7/40 done. Train loss: 1.586 val loss: 1.544 Val. Accuracy : 44.780%.
# Epoch 8/40 done. Train loss: 1.584 val loss: 1.623 Val. Accuracy : 42.370%.
# Epoch 9/40 done. Train loss: 1.583 val loss: 1.586 Val. Accuracy : 43.860%.
# Epoch 10/40 done. Train loss: 1.584 val loss: 1.611 Val. Accuracy : 43.560%.
# Epoch 11/40 done. Train loss: 1.579 val loss: 1.583 Val. Accuracy : 44.280%.
# Epoch 12/40 done. Train loss: 1.579 val loss: 1.621 Val. Accuracy : 43.100%.
# Epoch 13/40 done. Train loss: 1.586 val loss: 1.630 Val. Accuracy : 43.540%.
# Epoch 14/40 done. Train loss: 1.579 val loss: 1.558 Val. Accuracy : 43.970%.
# Epoch 15/40 done. Train loss: 1.575 val loss: 1.590 Val. Accuracy : 43.630%.
# Epoch 16/40 done. Train loss: 1.581 val loss: 1.603 Val. Accuracy : 43.340%.
# Epoch 17/40 done. Train loss: 1.588 val loss: 1.558 Val. Accuracy : 44.880%.
# Epoch 18/40 done. Train loss: 1.585 val loss: 1.653 Val. Accuracy : 42.390%.
# Epoch 19/40 done. Train loss: 1.578 val loss: 1.561 Val. Accuracy : 44.300%.
# Epoch 20/40 done. Train loss: 1.582 val loss: 1.595 Val. Accuracy : 43.510%.
# Epoch 21/40 done. Train loss: 1.575 val loss: 1.629 Val. Accuracy : 41.490%.
# Epoch 22/40 done. Train loss: 1.581 val loss: 1.571 Val. Accuracy : 44.180%.
# Epoch 23/40 done. Train loss: 1.575 val loss: 1.606 Val. Accuracy : 42.840%.
# Epoch 24/40 done. Train loss: 1.577 val loss: 1.564 Val. Accuracy : 43.680%.
# Epoch 25/40 done. Train loss: 1.571 val loss: 1.618 Val. Accuracy : 43.160%.
# Epoch 26/40 done. Train loss: 1.583 val loss: 1.621 Val. Accuracy : 43.250%.
# Epoch 27/40 done. Train loss: 1.569 val loss: 1.619 Val. Accuracy : 43.500%.
# Epoch 28/40 done. Train loss: 1.579 val loss: 1.629 Val. Accuracy : 41.810%.
# Epoch 29/40 done. Train loss: 1.582 val loss: 1.525 Val. Accuracy : 46.180%.
# Epoch 30/40 done. Train loss: 1.578 val loss: 1.592 Val. Accuracy : 44.840%.
# Epoch 31/40 done. Train loss: 1.581 val loss: 1.548 Val. Accuracy : 45.140%.
# Epoch 32/40 done. Train loss: 1.587 val loss: 1.565 Val. Accuracy : 44.660%.
# Epoch 33/40 done. Train loss: 1.582 val loss: 1.555 Val. Accuracy : 44.510%.
# Epoch 34/40 done. Train loss: 1.576 val loss: 1.583 Val. Accuracy : 44.120%.
# Epoch 35/40 done. Train loss: 1.585 val loss: 1.563 Val. Accuracy : 45.130%.
# Epoch 36/40 done. Train loss: 1.583 val loss: 1.602 Val. Accuracy : 43.380%.
# Epoch 37/40 done. Train loss: 1.579 val loss: 1.535 Val. Accuracy : 44.680%.
# Epoch 38/40 done. Train loss: 1.584 val loss: 1.629 Val. Accuracy : 41.610%.
# Epoch 39/40 done. Train loss: 1.577 val loss: 1.521 Val. Accuracy : 46.370%.
# Epoch 40/40 done. Train loss: 1.571 val loss: 1.593 Val. Accuracy : 43.010%.
# Epoch 1/40 done. Train loss: 1.671 val loss: 1.662 Val. Accuracy : 40.350%.
# Epoch 2/40 done. Train loss: 1.679 val loss: 1.777 Val. Accuracy : 37.220%.
# Epoch 3/40 done. Train loss: 1.689 val loss: 1.706 Val. Accuracy : 40.170%.
# Epoch 4/40 done. Train loss: 1.694 val loss: 1.666 Val. Accuracy : 41.570%.
# Epoch 5/40 done. Train loss: 1.686 val loss: 1.642 Val. Accuracy : 41.700%.
# Epoch 6/40 done. Train loss: 1.689 val loss: 1.693 Val. Accuracy : 40.070%.
# Epoch 7/40 done. Train loss: 1.681 val loss: 1.733 Val. Accuracy : 36.540%.
# Epoch 8/40 done. Train loss: 1.697 val loss: 1.666 Val. Accuracy : 39.840%.
# Epoch 9/40 done. Train loss: 1.691 val loss: 1.690 Val. Accuracy : 38.670%.
# Epoch 10/40 done. Train loss: 1.684 val loss: 1.728 Val. Accuracy : 38.650%.
# Epoch 11/40 done. Train loss: 1.691 val loss: 1.665 Val. Accuracy : 40.890%.
# Epoch 12/40 done. Train loss: 1.687 val loss: 1.758 Val. Accuracy : 38.020%.
# Epoch 13/40 done. Train loss: 1.690 val loss: 1.674 Val. Accuracy : 41.020%.
# Epoch 14/40 done. Train loss: 1.683 val loss: 1.688 Val. Accuracy : 39.700%.
# Epoch 15/40 done. Train loss: 1.692 val loss: 1.627 Val. Accuracy : 41.790%.
# Epoch 16/40 done. Train loss: 1.683 val loss: 1.688 Val. Accuracy : 40.120%.
# Epoch 17/40 done. Train loss: 1.698 val loss: 1.680 Val. Accuracy : 41.170%.
# Epoch 18/40 done. Train loss: 1.681 val loss: 1.705 Val. Accuracy : 38.400%.
# Epoch 19/40 done. Train loss: 1.690 val loss: 1.705 Val. Accuracy : 39.010%.
# Epoch 20/40 done. Train loss: 1.690 val loss: 1.659 Val. Accuracy : 40.960%.
# Epoch 21/40 done. Train loss: 1.681 val loss: 1.665 Val. Accuracy : 40.070%.
# Epoch 22/40 done. Train loss: 1.703 val loss: 1.721 Val. Accuracy : 37.650%.
# Epoch 23/40 done. Train loss: 1.695 val loss: 1.695 Val. Accuracy : 40.650%.
# Epoch 24/40 done. Train loss: 1.687 val loss: 1.653 Val. Accuracy : 40.970%.
# Epoch 25/40 done. Train loss: 1.689 val loss: 1.687 Val. Accuracy : 40.420%.
# Epoch 26/40 done. Train loss: 1.693 val loss: 1.707 Val. Accuracy : 39.740%.
# Epoch 27/40 done. Train loss: 1.690 val loss: 1.690 Val. Accuracy : 39.690%.
# Epoch 28/40 done. Train loss: 1.680 val loss: 1.699 Val. Accuracy : 39.200%.
# Epoch 29/40 done. Train loss: 1.690 val loss: 1.666 Val. Accuracy : 39.940%.
# Epoch 30/40 done. Train loss: 1.686 val loss: 1.694 Val. Accuracy : 38.460%.
# Epoch 31/40 done. Train loss: 1.680 val loss: 1.664 Val. Accuracy : 40.790%.
# Epoch 32/40 done. Train loss: 1.691 val loss: 1.737 Val. Accuracy : 37.920%.
# Epoch 33/40 done. Train loss: 1.696 val loss: 1.723 Val. Accuracy : 39.070%.
# Epoch 34/40 done. Train loss: 1.688 val loss: 1.656 Val. Accuracy : 41.500%.
# Epoch 35/40 done. Train loss: 1.695 val loss: 1.701 Val. Accuracy : 40.160%.
# Epoch 36/40 done. Train loss: 1.695 val loss: 1.697 Val. Accuracy : 39.450%.
# Epoch 37/40 done. Train loss: 1.686 val loss: 1.644 Val. Accuracy : 41.310%.
# Epoch 38/40 done. Train loss: 1.696 val loss: 1.679 Val. Accuracy : 40.520%.
# Epoch 39/40 done. Train loss: 1.689 val loss: 1.655 Val. Accuracy : 41.290%.
# Epoch 40/40 done. Train loss: 1.681 val loss: 1.639 Val. Accuracy : 41.540%.

# %%
lrs_, momentums_, wds_ = torch.meshgrid(torch.tensor(lrs), torch.tensor(momentums), torch.tensor(wds))
i = 1
for lr, momentum, wd in zip(torch.flatten(lrs_), torch.flatten(momentums_), torch.flatten(wds_)):
  print("HP set {}: learning rate {:.3f}; momentum {:.3f}, weight decay {:.3f}".format(i, lr.item(), momentum.item(), wd.item()))
  i+=1
# Out:
# HP set 1: learning rate 0.010; momentum 0.850, weight decay 0.005
# HP set 2: learning rate 0.010; momentum 0.900, weight decay 0.005
# HP set 3: learning rate 0.100; momentum 0.850, weight decay 0.005
# HP set 4: learning rate 0.100; momentum 0.900, weight decay 0.005

# %% [markdown]
# **Expected Output:** Your plots should look somewhat similar to this:
#
# ![Accuracy2.png](https://github.com/HHU-MMBS/Deep-Learning-Exercise-Extras/raw/main/a06_pytorch_mlp/images/Accuracy2.png)
