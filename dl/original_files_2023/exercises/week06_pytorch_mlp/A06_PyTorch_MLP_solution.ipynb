# %% [markdown]
# HHU Deep Learning, WS2023/24, 17.11.2023
#
# Lecture: Prof. Dr. Markus Kollmann
#
# Exercises: Nikolas Adaloglou, Felix Michels
#
# # Assignment 6 - Neural Networks with PyTorch
#
# ---
#
# Submit the solved notebook (not a zip) with your full name plus assingment number for the filename as an indicator, e.g `max_mustermann_a1.ipynb` for assignment 1. If we feel like you have genuinely tried to solve the exercise, you will receive 1 point for this assignment, regardless of the quality of your solution.
#
# ## <center> DUE FRIDAY 24.11.2023 2:30 pm </center>
#
# Drop-off link: [https://uni-duesseldorf.sciebo.de/s/1OQhEkR4QtlzkfF](https://uni-duesseldorf.sciebo.de/s/1OQhEkR4QtlzkfF)
#
# ---

# %% [markdown]
# Until now, we have used the numpy package to write our own helper functions for forward-, backward-passes of layers, activation functions, wrote our own cost functions and optimizers, etc. Now, we want to automate all of this with the use of a Deep Learning Framework.
#
# There are various big packages (frameworks) that offer functionality specialized in Machine/Deep Learning.
#
# The two most well known ones are **PyTorch** from Meta and **TensorFlow** from Google. In this course, we will work with PyTorch as it provides a good tradeoff between ease of use for academic purposes and scalability to large projects in future reasearch.
#
# Next to implementations of functions like Neural Network layers, optimizers, etc., PyTorch has three main features:
# - The tensor datastructure, which is similar to the Numpy ndarray
# - Automatic differentiation for training neural networks
# - It allows us to run code on a GPU, which offers significantly  faster computations.
#
# ![Pytorch_logo.png](https://github.com/HHU-MMBS/Deep-Learning-Exercise-Extras/raw/main/a06_pytorch_mlp/images/Pytorch_logo.png)
#
# Feel free to use the PyTorch Introduction from week 1 as a look-up for basic PyTorch functionality.
#
# ---
#
# For this assignment, you will use PyTorch to implement a fully connected Neural Network, perform a set of experiments on the famous CIFAR10 dataset and report your results and findings.
#
# For your experiments, you will create a multilayer perceptron (MLP) Neural Network and train it on the CIFAR10 dataset to predict object class based on the input image. CIFAR10 image dimensions are 32 by 32, with 3 values for each pixel (R, G, B).
#
# **Goal: Your goal is to develop an image classifier that scores more than 50% accuracy on the validation data.**

# %% [markdown]
# # 1. Imports and preparing the dataset and dataloaders
#
#
# If you are using google colab remember to change the runtime type to GPU.
#
# To get started, run the following code to import the libraries you will need.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (7.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# We will be using a GPU to accelerate training and testing. PyTorch lets you use the GPU with very little additional code. The `torch.cuda` package contains all available functions for GPU usage. Check out the docs on the [package](https://pytorch.org/docs/stable/cuda.html) and on [cuda semantics](https://pytorch.org/docs/stable/notes/cuda.html#cuda-semantics) if you want to learn more, this is not required for this assignment though.
#
# If you don't have a dedicated GPU in your own machine, the easiest way to get one is Google Colab! It's free, all you need is a Google account and you get ~8 hrs of GPU time per day.
#
# Below is a small, good-practice, GPU setup to check the availability of a GPU in your system.

# %%
# GPU
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
print('device:', device)
# Out:
# device: cuda:0

# %% [markdown]
# # 2. CIFAR-10 Dataset
#
# Today, we'll use the famous CIFAR-10 dataset for an image classification task. PyTorch provides many built-in datasets in the [torchvision.datasets](https://pytorch.org/vision/stable/datasets.html) module, as well as utility classes for building your own datasets.
#
# The code below:
# - Defines some basic transforms for preprocessing the data
# - Loads the CIFAR-10 dataset as a PyTorch dataset class. The raw data is stored locally on your machine.

# %%
# Data transforms
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# Datasets
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
valset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# PyTorch provides a convenient solution for batch training. After loading the dataset and setting parameters like batch_size, train and an optional transformation (normalization in this case), we can use the DataLoader object as an iterator for the training loop. It will return the outputs of the `__getitem__(...)` function of the dataset class in a batched form, ready to be used for batch-gradient descent.
#
# **Exercise:** Instantiate two DataLoaders, one for the training set and one for the validation set. Adjust the batch size to your available GPU memory, usual choices are powers of 2, like 16, 32, 64, ..., for reasons that have to do with the hardware layout on GPUs.

# %%
### START CODE HERE ### (approx. 2 lines)
# Dataloaders
train_loader = torch.utils.data.DataLoader(trainset, batch_size=256, shuffle=True, num_workers=0)
val_loader = torch.utils.data.DataLoader(valset, batch_size=256, shuffle=False, num_workers=0)
### END CODE HERE ###

# %% [markdown]
# Below you can see how to access information regarding the dataset and the dataloaders.

# %%
# dataset instance
print("List of label names are:", trainset.classes)
print("Total training images:", len(trainset))
img, label = trainset[0]
print(f"Example image with shape {img.shape}, label {label}, which is a {trainset.classes[label]} ")

# DataLoader instance
print(f'The dataloader contains {len(train_loader)} batches.')
imgs_batch , labels_batch = next(iter(train_loader))
print(f"A batch of images has shape {imgs_batch.shape}, labels {labels_batch.shape}")
# Out:
# List of label names are: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Total training images: 50000
# Example image with shape torch.Size([3, 32, 32]), label 6, which is a frog
# The dataloader contains 196 batches.
# A batch of images has shape torch.Size([256, 3, 32, 32]), labels torch.Size([256])

# %% [markdown]
# # 3. Define the MLP model
#
# Now it's your turn to implement a Multi-Layer Perceptron (MLP / fully connected net) with variable depth, similar to the last exercise. Your Network needs to:
#
# - Have L-1 blocks of linear layers, followed by ReLU activations, check out nn.Linear and nn.ReLU
# - Have a final 'out_layer' with just a linear layer
# - Have choosable dimensions for all hidden layers, via the 'hidden_sizes' parameter, e.g. [32, 16] is a three-layer model.
#
# The `torch.nn` functions, like `nn.Linear`, have all the functionality you need for training the network already built into them. No more manual backward-computation or remembering intermediate results in a cache, PyTorch takes care of that.
#
# You need to define your network architecture in the `__init__`, by initialising things like layers and activation functions and then call them in the forward pass to process the input `x`.
#
# Tip: In the `__init__`, you can save 'nn.' objects in a list and then pass them to `nn.Sequential` as an unpacked list:
#
# ```
# layers = nn.ModuleList()
# ... fill the list ...
# self.layers = nn.Sequential(*layers)
# ```
#
# See the `PyTorch Module API` and `PyTorch Sequential API` sections from the PyTorch Introduction from week 1 for help on the implementation here.

# %%
# Model structure
class MLP(nn.Module):
    def __init__(self, in_channels, num_classes, hidden_sizes=[64]):
        super(MLP, self).__init__()
        assert len(hidden_sizes) >= 1 , "specify at least one hidden layer"
        ### START CODE HERE ### (approx. 7 lines)
        layers = nn.ModuleList()
        layer_sizes = [in_channels] + hidden_sizes
        for dim_in, dim_out in zip(layer_sizes[:-1], layer_sizes[1:]):
            layers.append(nn.Linear(dim_in, dim_out))
            layers.append(nn.ReLU())

        self.layers = nn.Sequential(*layers)
        self.out_layer = nn.Linear(hidden_sizes[-1], num_classes)
        ### END CODE HERE ###

    def forward(self, x):
        ### START CODE HERE ### (approx. 3 lines)
        out = x.view(x.shape[0], -1)  # flatten the input
        out = self.layers(out)
        out = self.out_layer(out)
        ### END CODE HERE ###
        return out

# %% [markdown]
# Use the function below to test your implementation. The parameter settings are not fitted to CIFAR-10, you will need different values later on!
#
# Below you also find an expected output of what the network structure should look like. Note that this print varies based on your syntax, even if the logic is correct. Use it as a guide, you don't need to exactly replicate it.

# %%
# Test your implementation with random data
test_model = MLP(in_channels=3*10*10, num_classes=4, hidden_sizes=[64, 32, 16]).to(device)

a = torch.rand(16, 3, 10, 10).to(device)
b = test_model(a)
assert b.shape == (16,4)
print('Shape test passed')
print(test_model)
# Out:
# Shape test passed
# MLP(
#   (layers): Sequential(
#     (0): Linear(in_features=300, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): ReLU()
#   )
#   (out_layer): Linear(in_features=16, out_features=4, bias=True)
# )

# %% [markdown]
# **Expected Output:**
#
# ```
# Shape test passed
# Net(
#   (layers): Sequential(
#     (0): Linear(in_features=300, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=16, bias=True)
#     (5): ReLU()
#   )
#   (out_layer): Linear(in_features=16, out_features=4, bias=True)
# )
# ```

# %% [markdown]
# # 4. Training and Validation
#
# Equipped with our MLP model, we now want to train it.
#
# First, we implement the validation function, so we can use it in the train function. The idea is to test our model on the (unseen) validation data in regular intervals during training, e.g. after every epoch (traversal of the whole dataset).
#
# **Exercise:** Implement the validation function, which reads in data from the `val_loader`, runs a forward pass and records the classification accuracy, as well as the loss. Both are returned for plotting purposes.
#
# We will be using the `nn.CrossEntropyLoss` as our loss function. Please have a look at the [docs](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html) for this loss function, you will use it more often in the future.
#
# Loss functions in PyTorch are instantiated as class objects (nn.CrossEntropyLoss is the class here) and can then be used like a function:
#
# ```
# criterion = nn.CrossEntropyLoss()
# loss = criterion(input,target)
# ```
#
# Note, that `nn.CrossEntropyLoss` combines a Softmax activation with the actual loss function, a negative log-likelihood loss. So, it expects **unnormalized!** scores from our network, i.e. no activation funciton after the last layer.

# %%
def validation(model, val_loader):
    criterion = nn.CrossEntropyLoss()
    correct = 0
    val_loss = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            ### START CODE HERE ### (approx. 8 lines)
            # Move inputs and labels to the GPU, if possible
            inputs, labels = inputs.to(device), labels.to(device)
            # Forward pass
            outputs = model(inputs)
            # Compute and record loss
            val_loss += criterion(outputs, labels).item()
            # Get prediction by taking the maximum score in the output
            predicted = torch.max(outputs, dim=1)[1]
            # Accumulate number of correct predictions
            correct += (predicted == labels).sum().item()
            # Accumulate loss
    # Normalize loss
    val_loss /= len(val_loader)
    # Normalize number of correct predictions to get an accuracy
    val_acc = correct / len(val_loader.dataset)
    ### END CODE HERE ###
    return val_acc, val_loss

# %%
# Don't mind this, is just for testing
class dummy_dataset(torch.utils.data.Dataset):
    def __init__(self):
        self.data = torch.rand(16, 3, 10, 10)
        self.labels = torch.randint(0, 4, (16,))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

# %% [markdown]
# Use the code below to test your implementation with the above initialized `test_model`.

# %%
# Test validation with an untrained model
test_set = dummy_dataset()
test_loader = torch.utils.data.DataLoader(test_set, batch_size=4)

# Needs to run without errors
validation(test_model, test_loader)
# Out:
# (0.25, 1.3933473825454712)

# %% [markdown]
# Now, we can implement the train loop itself.  You are already familiar with the basic training procedure:
#
# Loop for num_iterations:
# 1. Forward propagation
# 2. Compute loss function
# 3. Backward propagation
# 4. Update parameters

# %%
def train(model, train_loader, val_loader, epochs, lr, momentum, wd):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=wd)
    train_loss_hist = []
    val_loss_hist = []
    val_acc_hist = []
    for epoch in range(epochs):
        for inputs, labels in train_loader:
            ### START CODE HERE ### (approx. 7 lines)
            # Move inputs and labels to the GPU, if possible
            inputs, labels = inputs.to(device), labels.to(device)
            # Zero the optimizers gradient cache (look this up if it's unclear why this is necessary)
            optimizer.zero_grad()
            # Forward pass
            outputs = model(inputs)
            # Compute loss
            loss = criterion(outputs, labels)
            # Backward pass
            loss.backward()
            # Update the parameters
            optimizer.step()
            # record loss statistics
            train_loss_hist.append(loss.item())
            ### END CODE HERE ###
        # stats
        val_acc, val_loss = validation(model, val_loader)
        val_acc_hist.append(val_acc)
        val_loss_hist.append(val_loss)
        print(f"Epoch {epoch+1}/{epochs} done. Train loss: {np.mean(train_loss_hist[-len(train_loader):]):.3f} val loss: {val_loss_hist[-1]:.3f} Val. Accuracy : {val_acc_hist[-1]*100:.3f}%.")

    dict_log = {"train_loss_hist": train_loss_hist, "val_loss_hist": val_loss_hist, "val_acc_hist": val_acc_hist}
    return dict_log

# %% [markdown]
# **Exercise:** Choose a single set of hyperparameters (lr, momentum, wd, epochs), as well as a model configuration and see how the model performs. Save the dict_log for plotting later on.

# %%
### START CODE HERE ### (approx. 4 lines)
# Model settings
in_channels = 3 * 32 * 32
num_classes = 10
hidden_sizes = [128]

# hyper-parameters
epochs = 40
lr = 1e-3
momentum = 0.9
wd = 1e-4
### END CODE HERE ###

model = MLP(in_channels, num_classes, hidden_sizes).to(device)

dict_log = train(model, train_loader, val_loader, epochs, lr, momentum, wd)
# Out:
# Epoch 1/40 done. Train loss: 2.091 val loss: 1.952 Val. Accuracy : 32.880%.
# Epoch 2/40 done. Train loss: 1.893 val loss: 1.831 Val. Accuracy : 36.610%.
# Epoch 3/40 done. Train loss: 1.801 val loss: 1.761 Val. Accuracy : 39.090%.
# Epoch 4/40 done. Train loss: 1.742 val loss: 1.713 Val. Accuracy : 40.430%.
# Epoch 5/40 done. Train loss: 1.700 val loss: 1.676 Val. Accuracy : 41.800%.
# Epoch 6/40 done. Train loss: 1.667 val loss: 1.649 Val. Accuracy : 42.700%.
# Epoch 7/40 done. Train loss: 1.640 val loss: 1.626 Val. Accuracy : 43.640%.
# Epoch 8/40 done. Train loss: 1.617 val loss: 1.607 Val. Accuracy : 44.170%.
# Epoch 9/40 done. Train loss: 1.598 val loss: 1.591 Val. Accuracy : 44.590%.
# Epoch 10/40 done. Train loss: 1.580 val loss: 1.578 Val. Accuracy : 45.030%.
# Epoch 11/40 done. Train loss: 1.565 val loss: 1.565 Val. Accuracy : 45.570%.
# Epoch 12/40 done. Train loss: 1.550 val loss: 1.554 Val. Accuracy : 46.010%.
# Epoch 13/40 done. Train loss: 1.537 val loss: 1.543 Val. Accuracy : 46.440%.
# Epoch 14/40 done. Train loss: 1.523 val loss: 1.533 Val. Accuracy : 46.760%.
# Epoch 15/40 done. Train loss: 1.512 val loss: 1.524 Val. Accuracy : 47.030%.
# Epoch 16/40 done. Train loss: 1.501 val loss: 1.516 Val. Accuracy : 47.340%.
# Epoch 17/40 done. Train loss: 1.490 val loss: 1.509 Val. Accuracy : 47.480%.
# Epoch 18/40 done. Train loss: 1.479 val loss: 1.500 Val. Accuracy : 47.890%.
# Epoch 19/40 done. Train loss: 1.469 val loss: 1.494 Val. Accuracy : 47.970%.
# Epoch 20/40 done. Train loss: 1.460 val loss: 1.487 Val. Accuracy : 48.300%.
# Epoch 21/40 done. Train loss: 1.451 val loss: 1.481 Val. Accuracy : 48.400%.
# Epoch 22/40 done. Train loss: 1.441 val loss: 1.475 Val. Accuracy : 48.770%.
# Epoch 23/40 done. Train loss: 1.432 val loss: 1.468 Val. Accuracy : 49.060%.
# Epoch 24/40 done. Train loss: 1.423 val loss: 1.463 Val. Accuracy : 49.030%.
# Epoch 25/40 done. Train loss: 1.415 val loss: 1.458 Val. Accuracy : 49.320%.
# Epoch 26/40 done. Train loss: 1.406 val loss: 1.452 Val. Accuracy : 49.490%.
# Epoch 27/40 done. Train loss: 1.399 val loss: 1.448 Val. Accuracy : 49.620%.
# Epoch 28/40 done. Train loss: 1.390 val loss: 1.444 Val. Accuracy : 49.580%.
# Epoch 29/40 done. Train loss: 1.383 val loss: 1.438 Val. Accuracy : 50.230%.
# Epoch 30/40 done. Train loss: 1.376 val loss: 1.433 Val. Accuracy : 49.940%.
# Epoch 31/40 done. Train loss: 1.368 val loss: 1.430 Val. Accuracy : 50.080%.
# Epoch 32/40 done. Train loss: 1.360 val loss: 1.425 Val. Accuracy : 50.460%.
# Epoch 33/40 done. Train loss: 1.353 val loss: 1.424 Val. Accuracy : 50.440%.
# Epoch 34/40 done. Train loss: 1.347 val loss: 1.420 Val. Accuracy : 50.450%.
# Epoch 35/40 done. Train loss: 1.339 val loss: 1.416 Val. Accuracy : 50.630%.
# Epoch 36/40 done. Train loss: 1.332 val loss: 1.414 Val. Accuracy : 50.400%.
# Epoch 37/40 done. Train loss: 1.327 val loss: 1.409 Val. Accuracy : 50.700%.
# Epoch 38/40 done. Train loss: 1.319 val loss: 1.403 Val. Accuracy : 50.990%.
# Epoch 39/40 done. Train loss: 1.312 val loss: 1.402 Val. Accuracy : 50.860%.
# Epoch 40/40 done. Train loss: 1.307 val loss: 1.400 Val. Accuracy : 50.970%.

# %% [markdown]
# # 6. Plotting results
#
# The code below plots the results of the training. We compare train and validation loss in the same plot to check for overfitting or other undesirable training behaviour.

# %%
def loss_plot(title):
    plt.figure(figsize=(10,5))
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Cross Entropy Loss")

def acc_plot(title):
    plt.figure(figsize=(10,5))
    plt.title(title)
    plt.axhline(y = 0.5, color = 'r', linestyle = '-', label='Good accuracy')
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")

# %%
x_val = np.arange(1, epochs+1)
train_loss_hist_epochs = [np.mean(dict_log["train_loss_hist"][i*len(train_loader):(i+1)*len(train_loader)]) for i in range(epochs)]

loss_plot('Losses per Epoch')
plt.scatter(x_val, dict_log["val_loss_hist"], label='Validation loss')
plt.scatter(x_val, train_loss_hist_epochs, label='Train loss')
plt.legend()
plt.savefig('Losses1.png')
plt.show()

plt.figure(figsize=(14,8))
acc_plot('Validation Accuracy per epoch')
plt.scatter(x_val, dict_log["val_acc_hist"])
plt.plot(x_val, dict_log["val_acc_hist"], label='Validation Accuracy')
plt.legend()
plt.savefig('Accuracy1.png')
plt.show()

# %% [markdown]
# **Expected Output:** Your plots should look somewhat similar to this:
#
# ![Losses1.png](https://github.com/HHU-MMBS/Deep-Learning-Exercise-Extras/raw/main/a06_pytorch_mlp/images/Losses1.png)

# %% [markdown]
# ![Accuracy1.png](https://github.com/HHU-MMBS/Deep-Learning-Exercise-Extras/raw/main/a06_pytorch_mlp/images/Accuracy1.png)

# %% [markdown]
# # 7. Hyperparameter tuning
#
# Lastly, we want to squeeze some more performance out of our model by tuning its hyperparameters.
#
# **Exercise:** Implement the function hparam_tuning below. It should:
# - Take in lists of hyperparameters
# - Test every possible combination of them.
#
# The epochs, in_channels and num_classes are fixed. You can experiment with the parameters hidden sizes, learning rate, momentum and weight decay.
#
# Save the dictionaries returned by the train function in the logs_out list. Don't forget to re-initialize your model before each run with new hyperparameters

# %%
def hparam_tuning(epochs, in_channels, hidden_sizes, lrs, momentums, wds, num_classes=10):
    """
    params:
    epochs: int
    in_channels: int
    num_classes: int
    hidden_sizes: list of lists of ints
    lrs/momentums/wds: list of floats
    """
    logs_out = []
    ### START CODE HERE ### (approx. 7 lines)
    for hs in hidden_sizes:
        for lr in lrs:
            for mom in momentums:
                for wd in wds:
                    model = MLP(in_channels, num_classes, hs).to(device)
                    print(f"Starting run for: hiddensizes {hs}, lr {lr}, momentum {mom}, wd {wd}")
                    dict_log = train(model, train_loader, val_loader,
                                     lr=lr, wd=wd, momentum=mom, epochs=epochs)
                    logs_out.append(dict_log)
    ### END CODE HERE ###
    return logs_out

# %% [markdown]
# **Exercise:** Pick **at least 4 combinations of hyperparameters** and use them for a comparative series of training runs. Since you pass lists of hyperparameters, this means two of the lists need to be at least of length 2.

# %%
### START CODE HERE ### (approx. 4 lines)
hidden_sizes = [[128], [64, 64]]
lrs = [0.005, 0.01]
momentums = [0.9]
wds = [0.001, 0.0001]
### END CODE HERE ###

logs_out = hparam_tuning(epochs, in_channels, hidden_sizes, lrs, momentums, wds)

plt.figure(figsize=(14,8))
acc_plot("Validation accuracy for different hyperparameter sets")
for c, dict_out in enumerate(logs_out):
    x_val = list(range(len(dict_out["val_acc_hist"])))
    plt.scatter(x_val, dict_out["val_acc_hist"])
    plt.plot(x_val, dict_out["val_acc_hist"], label=f"HP set {c+1}")
plt.legend()
plt.show()
# Out:
# Starting run for: hiddensizes [128], lr 0.005, momentum 0.9, wd 0.001
# Epoch 1/40 done. Train loss: 1.890 val loss: 1.711 Val. Accuracy : 40.270%.
# Epoch 2/40 done. Train loss: 1.659 val loss: 1.599 Val. Accuracy : 44.470%.
# Epoch 3/40 done. Train loss: 1.573 val loss: 1.541 Val. Accuracy : 46.160%.
# Epoch 4/40 done. Train loss: 1.516 val loss: 1.506 Val. Accuracy : 47.990%.
# Epoch 5/40 done. Train loss: 1.470 val loss: 1.473 Val. Accuracy : 48.610%.
# Epoch 6/40 done. Train loss: 1.432 val loss: 1.454 Val. Accuracy : 49.000%.
# Epoch 7/40 done. Train loss: 1.399 val loss: 1.431 Val. Accuracy : 49.640%.
# Epoch 8/40 done. Train loss: 1.368 val loss: 1.412 Val. Accuracy : 50.280%.
# Epoch 9/40 done. Train loss: 1.340 val loss: 1.399 Val. Accuracy : 50.910%.
# Epoch 10/40 done. Train loss: 1.315 val loss: 1.389 Val. Accuracy : 51.490%.
# Epoch 11/40 done. Train loss: 1.292 val loss: 1.392 Val. Accuracy : 51.220%.
# Epoch 12/40 done. Train loss: 1.272 val loss: 1.369 Val. Accuracy : 51.810%.
# Epoch 13/40 done. Train loss: 1.252 val loss: 1.368 Val. Accuracy : 51.960%.
# Epoch 14/40 done. Train loss: 1.231 val loss: 1.366 Val. Accuracy : 52.140%.
# Epoch 15/40 done. Train loss: 1.214 val loss: 1.344 Val. Accuracy : 52.770%.
# Epoch 16/40 done. Train loss: 1.196 val loss: 1.343 Val. Accuracy : 52.630%.
# Epoch 17/40 done. Train loss: 1.180 val loss: 1.345 Val. Accuracy : 52.710%.
# Epoch 18/40 done. Train loss: 1.163 val loss: 1.355 Val. Accuracy : 52.490%.
# Epoch 19/40 done. Train loss: 1.149 val loss: 1.342 Val. Accuracy : 52.920%.
# Epoch 20/40 done. Train loss: 1.136 val loss: 1.333 Val. Accuracy : 52.830%.
# Epoch 21/40 done. Train loss: 1.120 val loss: 1.337 Val. Accuracy : 53.110%.
# Epoch 22/40 done. Train loss: 1.106 val loss: 1.334 Val. Accuracy : 53.180%.
# Epoch 23/40 done. Train loss: 1.091 val loss: 1.341 Val. Accuracy : 52.930%.
# Epoch 24/40 done. Train loss: 1.080 val loss: 1.342 Val. Accuracy : 53.020%.
# Epoch 25/40 done. Train loss: 1.070 val loss: 1.333 Val. Accuracy : 53.220%.
# Epoch 26/40 done. Train loss: 1.054 val loss: 1.351 Val. Accuracy : 52.820%.
# Epoch 27/40 done. Train loss: 1.045 val loss: 1.345 Val. Accuracy : 53.400%.
# Epoch 28/40 done. Train loss: 1.032 val loss: 1.333 Val. Accuracy : 53.300%.
# Epoch 29/40 done. Train loss: 1.023 val loss: 1.340 Val. Accuracy : 53.410%.
# Epoch 30/40 done. Train loss: 1.012 val loss: 1.346 Val. Accuracy : 52.900%.
# Epoch 31/40 done. Train loss: 1.003 val loss: 1.347 Val. Accuracy : 53.290%.
# Epoch 32/40 done. Train loss: 0.990 val loss: 1.349 Val. Accuracy : 53.560%.
# Epoch 33/40 done. Train loss: 0.977 val loss: 1.354 Val. Accuracy : 52.770%.
# Epoch 34/40 done. Train loss: 0.970 val loss: 1.363 Val. Accuracy : 52.640%.
# Epoch 35/40 done. Train loss: 0.961 val loss: 1.350 Val. Accuracy : 53.420%.
# Epoch 36/40 done. Train loss: 0.949 val loss: 1.364 Val. Accuracy : 52.970%.
# Epoch 37/40 done. Train loss: 0.943 val loss: 1.366 Val. Accuracy : 52.840%.
# Epoch 38/40 done. Train loss: 0.936 val loss: 1.357 Val. Accuracy : 53.880%.
# Epoch 39/40 done. Train loss: 0.922 val loss: 1.368 Val. Accuracy : 53.260%.
# Epoch 40/40 done. Train loss: 0.915 val loss: 1.372 Val. Accuracy : 53.310%.
# Starting run for: hiddensizes [128], lr 0.005, momentum 0.9, wd 0.0001
# Epoch 1/40 done. Train loss: 1.879 val loss: 1.699 Val. Accuracy : 40.920%.
# Epoch 2/40 done. Train loss: 1.645 val loss: 1.588 Val. Accuracy : 44.480%.
# Epoch 3/40 done. Train loss: 1.561 val loss: 1.538 Val. Accuracy : 46.470%.
# Epoch 4/40 done. Train loss: 1.505 val loss: 1.504 Val. Accuracy : 47.790%.
# Epoch 5/40 done. Train loss: 1.461 val loss: 1.471 Val. Accuracy : 48.840%.
# Epoch 6/40 done. Train loss: 1.422 val loss: 1.447 Val. Accuracy : 49.310%.
# Epoch 7/40 done. Train loss: 1.390 val loss: 1.434 Val. Accuracy : 49.720%.
# Epoch 8/40 done. Train loss: 1.360 val loss: 1.411 Val. Accuracy : 51.170%.
# Epoch 9/40 done. Train loss: 1.333 val loss: 1.401 Val. Accuracy : 51.030%.
# Epoch 10/40 done. Train loss: 1.308 val loss: 1.393 Val. Accuracy : 51.450%.
# Epoch 11/40 done. Train loss: 1.286 val loss: 1.382 Val. Accuracy : 51.410%.
# Epoch 12/40 done. Train loss: 1.264 val loss: 1.373 Val. Accuracy : 51.860%.
# Epoch 13/40 done. Train loss: 1.243 val loss: 1.363 Val. Accuracy : 52.270%.
# Epoch 14/40 done. Train loss: 1.223 val loss: 1.365 Val. Accuracy : 52.440%.
# Epoch 15/40 done. Train loss: 1.203 val loss: 1.367 Val. Accuracy : 52.500%.
# Epoch 16/40 done. Train loss: 1.185 val loss: 1.361 Val. Accuracy : 52.090%.
# Epoch 17/40 done. Train loss: 1.168 val loss: 1.356 Val. Accuracy : 52.460%.
# Epoch 18/40 done. Train loss: 1.152 val loss: 1.371 Val. Accuracy : 52.390%.
# Epoch 19/40 done. Train loss: 1.137 val loss: 1.354 Val. Accuracy : 53.050%.
# Epoch 20/40 done. Train loss: 1.123 val loss: 1.354 Val. Accuracy : 52.810%.
# Epoch 21/40 done. Train loss: 1.105 val loss: 1.351 Val. Accuracy : 52.870%.
# Epoch 22/40 done. Train loss: 1.091 val loss: 1.360 Val. Accuracy : 52.860%.
# Epoch 23/40 done. Train loss: 1.078 val loss: 1.354 Val. Accuracy : 53.170%.
# Epoch 24/40 done. Train loss: 1.062 val loss: 1.364 Val. Accuracy : 53.110%.
# Epoch 25/40 done. Train loss: 1.049 val loss: 1.363 Val. Accuracy : 52.990%.
# Epoch 26/40 done. Train loss: 1.037 val loss: 1.369 Val. Accuracy : 52.850%.
# Epoch 27/40 done. Train loss: 1.021 val loss: 1.368 Val. Accuracy : 52.970%.
# Epoch 28/40 done. Train loss: 1.011 val loss: 1.378 Val. Accuracy : 52.690%.
# Epoch 29/40 done. Train loss: 0.998 val loss: 1.374 Val. Accuracy : 53.360%.
# Epoch 30/40 done. Train loss: 0.986 val loss: 1.397 Val. Accuracy : 52.770%.
# Epoch 31/40 done. Train loss: 0.974 val loss: 1.380 Val. Accuracy : 53.420%.
# Epoch 32/40 done. Train loss: 0.967 val loss: 1.392 Val. Accuracy : 52.920%.
# Epoch 33/40 done. Train loss: 0.953 val loss: 1.400 Val. Accuracy : 53.180%.
# Epoch 34/40 done. Train loss: 0.939 val loss: 1.394 Val. Accuracy : 52.980%.
# Epoch 35/40 done. Train loss: 0.929 val loss: 1.406 Val. Accuracy : 52.520%.
# Epoch 36/40 done. Train loss: 0.915 val loss: 1.405 Val. Accuracy : 53.330%.
# Epoch 37/40 done. Train loss: 0.906 val loss: 1.411 Val. Accuracy : 52.760%.
# Epoch 38/40 done. Train loss: 0.898 val loss: 1.425 Val. Accuracy : 51.950%.
# Epoch 39/40 done. Train loss: 0.886 val loss: 1.425 Val. Accuracy : 52.680%.
# Epoch 40/40 done. Train loss: 0.874 val loss: 1.438 Val. Accuracy : 52.420%.
# Starting run for: hiddensizes [128], lr 0.01, momentum 0.9, wd 0.001
# Epoch 1/40 done. Train loss: 1.805 val loss: 1.624 Val. Accuracy : 43.360%.
# Epoch 2/40 done. Train loss: 1.579 val loss: 1.541 Val. Accuracy : 46.310%.
# Epoch 3/40 done. Train loss: 1.492 val loss: 1.487 Val. Accuracy : 47.590%.
# Epoch 4/40 done. Train loss: 1.427 val loss: 1.448 Val. Accuracy : 49.850%.
# Epoch 5/40 done. Train loss: 1.375 val loss: 1.420 Val. Accuracy : 50.360%.
# Epoch 6/40 done. Train loss: 1.332 val loss: 1.399 Val. Accuracy : 50.270%.
# Epoch 7/40 done. Train loss: 1.297 val loss: 1.386 Val. Accuracy : 51.520%.
# Epoch 8/40 done. Train loss: 1.263 val loss: 1.370 Val. Accuracy : 52.030%.
# Epoch 9/40 done. Train loss: 1.232 val loss: 1.367 Val. Accuracy : 52.080%.
# Epoch 10/40 done. Train loss: 1.208 val loss: 1.377 Val. Accuracy : 51.960%.
# Epoch 11/40 done. Train loss: 1.180 val loss: 1.379 Val. Accuracy : 52.030%.
# Epoch 12/40 done. Train loss: 1.162 val loss: 1.353 Val. Accuracy : 52.740%.
# Epoch 13/40 done. Train loss: 1.138 val loss: 1.357 Val. Accuracy : 52.640%.
# Epoch 14/40 done. Train loss: 1.119 val loss: 1.347 Val. Accuracy : 53.230%.
# Epoch 15/40 done. Train loss: 1.098 val loss: 1.357 Val. Accuracy : 52.930%.
# Epoch 16/40 done. Train loss: 1.079 val loss: 1.366 Val. Accuracy : 53.040%.
# Epoch 17/40 done. Train loss: 1.066 val loss: 1.364 Val. Accuracy : 52.730%.
# Epoch 18/40 done. Train loss: 1.048 val loss: 1.365 Val. Accuracy : 53.050%.
# Epoch 19/40 done. Train loss: 1.034 val loss: 1.368 Val. Accuracy : 52.870%.
# Epoch 20/40 done. Train loss: 1.016 val loss: 1.373 Val. Accuracy : 52.750%.
# Epoch 21/40 done. Train loss: 1.001 val loss: 1.366 Val. Accuracy : 52.550%.
# Epoch 22/40 done. Train loss: 0.988 val loss: 1.390 Val. Accuracy : 52.500%.
# Epoch 23/40 done. Train loss: 0.974 val loss: 1.367 Val. Accuracy : 53.450%.
# Epoch 24/40 done. Train loss: 0.965 val loss: 1.386 Val. Accuracy : 53.000%.
# Epoch 25/40 done. Train loss: 0.947 val loss: 1.408 Val. Accuracy : 51.830%.
# Epoch 26/40 done. Train loss: 0.933 val loss: 1.392 Val. Accuracy : 53.200%.
# Epoch 27/40 done. Train loss: 0.926 val loss: 1.397 Val. Accuracy : 53.020%.
# Epoch 28/40 done. Train loss: 0.913 val loss: 1.392 Val. Accuracy : 53.040%.
# Epoch 29/40 done. Train loss: 0.901 val loss: 1.412 Val. Accuracy : 53.020%.
# Epoch 30/40 done. Train loss: 0.895 val loss: 1.422 Val. Accuracy : 52.660%.
# Epoch 31/40 done. Train loss: 0.880 val loss: 1.432 Val. Accuracy : 52.290%.
# Epoch 32/40 done. Train loss: 0.873 val loss: 1.463 Val. Accuracy : 51.870%.
# Epoch 33/40 done. Train loss: 0.868 val loss: 1.445 Val. Accuracy : 52.310%.
# Epoch 34/40 done. Train loss: 0.855 val loss: 1.442 Val. Accuracy : 52.850%.
# Epoch 35/40 done. Train loss: 0.844 val loss: 1.435 Val. Accuracy : 52.530%.
# Epoch 36/40 done. Train loss: 0.833 val loss: 1.452 Val. Accuracy : 52.860%.
# Epoch 37/40 done. Train loss: 0.820 val loss: 1.455 Val. Accuracy : 52.430%.
# Epoch 38/40 done. Train loss: 0.812 val loss: 1.447 Val. Accuracy : 52.730%.
# Epoch 39/40 done. Train loss: 0.808 val loss: 1.462 Val. Accuracy : 52.470%.
# Epoch 40/40 done. Train loss: 0.798 val loss: 1.511 Val. Accuracy : 51.800%.
# Starting run for: hiddensizes [128], lr 0.01, momentum 0.9, wd 0.0001
# Epoch 1/40 done. Train loss: 1.804 val loss: 1.621 Val. Accuracy : 42.990%.
# Epoch 2/40 done. Train loss: 1.572 val loss: 1.533 Val. Accuracy : 46.360%.
# Epoch 3/40 done. Train loss: 1.486 val loss: 1.485 Val. Accuracy : 48.050%.
# Epoch 4/40 done. Train loss: 1.422 val loss: 1.438 Val. Accuracy : 49.500%.
# Epoch 5/40 done. Train loss: 1.373 val loss: 1.416 Val. Accuracy : 50.340%.
# Epoch 6/40 done. Train loss: 1.327 val loss: 1.399 Val. Accuracy : 50.810%.
# Epoch 7/40 done. Train loss: 1.290 val loss: 1.381 Val. Accuracy : 51.910%.
# Epoch 8/40 done. Train loss: 1.253 val loss: 1.382 Val. Accuracy : 51.510%.
# Epoch 9/40 done. Train loss: 1.226 val loss: 1.371 Val. Accuracy : 51.700%.
# Epoch 10/40 done. Train loss: 1.197 val loss: 1.379 Val. Accuracy : 51.880%.
# Epoch 11/40 done. Train loss: 1.173 val loss: 1.372 Val. Accuracy : 51.970%.
# Epoch 12/40 done. Train loss: 1.144 val loss: 1.369 Val. Accuracy : 52.190%.
# Epoch 13/40 done. Train loss: 1.128 val loss: 1.373 Val. Accuracy : 52.180%.
# Epoch 14/40 done. Train loss: 1.097 val loss: 1.377 Val. Accuracy : 52.500%.
# Epoch 15/40 done. Train loss: 1.077 val loss: 1.377 Val. Accuracy : 52.320%.
# Epoch 16/40 done. Train loss: 1.058 val loss: 1.387 Val. Accuracy : 52.220%.
# Epoch 17/40 done. Train loss: 1.038 val loss: 1.385 Val. Accuracy : 52.030%.
# Epoch 18/40 done. Train loss: 1.022 val loss: 1.401 Val. Accuracy : 52.220%.
# Epoch 19/40 done. Train loss: 1.003 val loss: 1.410 Val. Accuracy : 51.470%.
# Epoch 20/40 done. Train loss: 0.986 val loss: 1.410 Val. Accuracy : 52.420%.
# Epoch 21/40 done. Train loss: 0.966 val loss: 1.414 Val. Accuracy : 52.280%.
# Epoch 22/40 done. Train loss: 0.955 val loss: 1.415 Val. Accuracy : 52.470%.
# Epoch 23/40 done. Train loss: 0.937 val loss: 1.446 Val. Accuracy : 51.880%.
# Epoch 24/40 done. Train loss: 0.923 val loss: 1.459 Val. Accuracy : 51.740%.
# Epoch 25/40 done. Train loss: 0.904 val loss: 1.467 Val. Accuracy : 51.550%.
# Epoch 26/40 done. Train loss: 0.889 val loss: 1.468 Val. Accuracy : 51.210%.
# Epoch 27/40 done. Train loss: 0.876 val loss: 1.500 Val. Accuracy : 50.660%.
# Epoch 28/40 done. Train loss: 0.862 val loss: 1.493 Val. Accuracy : 51.530%.
# Epoch 29/40 done. Train loss: 0.855 val loss: 1.543 Val. Accuracy : 50.580%.
# Epoch 30/40 done. Train loss: 0.836 val loss: 1.513 Val. Accuracy : 51.080%.
# Epoch 31/40 done. Train loss: 0.825 val loss: 1.559 Val. Accuracy : 50.890%.
# Epoch 32/40 done. Train loss: 0.813 val loss: 1.555 Val. Accuracy : 51.230%.
# Epoch 33/40 done. Train loss: 0.806 val loss: 1.560 Val. Accuracy : 50.960%.
# Epoch 34/40 done. Train loss: 0.791 val loss: 1.583 Val. Accuracy : 50.610%.
# Epoch 35/40 done. Train loss: 0.772 val loss: 1.564 Val. Accuracy : 51.440%.
# Epoch 36/40 done. Train loss: 0.762 val loss: 1.598 Val. Accuracy : 50.870%.
# Epoch 37/40 done. Train loss: 0.754 val loss: 1.631 Val. Accuracy : 50.290%.
# Epoch 38/40 done. Train loss: 0.736 val loss: 1.603 Val. Accuracy : 51.000%.
# Epoch 39/40 done. Train loss: 0.723 val loss: 1.623 Val. Accuracy : 51.450%.
# Epoch 40/40 done. Train loss: 0.718 val loss: 1.643 Val. Accuracy : 51.070%.
# Starting run for: hiddensizes [64, 64], lr 0.005, momentum 0.9, wd 0.001
# Epoch 1/40 done. Train loss: 2.061 val loss: 1.851 Val. Accuracy : 34.560%.
# Epoch 2/40 done. Train loss: 1.761 val loss: 1.682 Val. Accuracy : 40.130%.
# Epoch 3/40 done. Train loss: 1.644 val loss: 1.598 Val. Accuracy : 44.210%.
# Epoch 4/40 done. Train loss: 1.575 val loss: 1.552 Val. Accuracy : 45.080%.
# Epoch 5/40 done. Train loss: 1.521 val loss: 1.518 Val. Accuracy : 46.810%.
# Epoch 6/40 done. Train loss: 1.477 val loss: 1.482 Val. Accuracy : 48.030%.
# Epoch 7/40 done. Train loss: 1.439 val loss: 1.457 Val. Accuracy : 48.490%.
# Epoch 8/40 done. Train loss: 1.404 val loss: 1.438 Val. Accuracy : 49.230%.
# Epoch 9/40 done. Train loss: 1.373 val loss: 1.423 Val. Accuracy : 49.630%.
# Epoch 10/40 done. Train loss: 1.349 val loss: 1.409 Val. Accuracy : 50.170%.
# Epoch 11/40 done. Train loss: 1.322 val loss: 1.400 Val. Accuracy : 50.200%.
# Epoch 12/40 done. Train loss: 1.302 val loss: 1.394 Val. Accuracy : 50.400%.
# Epoch 13/40 done. Train loss: 1.282 val loss: 1.393 Val. Accuracy : 50.640%.
# Epoch 14/40 done. Train loss: 1.263 val loss: 1.379 Val. Accuracy : 51.400%.
# Epoch 15/40 done. Train loss: 1.246 val loss: 1.388 Val. Accuracy : 50.990%.
# Epoch 16/40 done. Train loss: 1.232 val loss: 1.374 Val. Accuracy : 51.420%.
# Epoch 17/40 done. Train loss: 1.215 val loss: 1.382 Val. Accuracy : 50.650%.
# Epoch 18/40 done. Train loss: 1.202 val loss: 1.375 Val. Accuracy : 51.340%.
# Epoch 19/40 done. Train loss: 1.185 val loss: 1.372 Val. Accuracy : 51.570%.
# Epoch 20/40 done. Train loss: 1.175 val loss: 1.379 Val. Accuracy : 51.530%.
# Epoch 21/40 done. Train loss: 1.159 val loss: 1.373 Val. Accuracy : 51.640%.
# Epoch 22/40 done. Train loss: 1.146 val loss: 1.387 Val. Accuracy : 51.060%.
# Epoch 23/40 done. Train loss: 1.139 val loss: 1.388 Val. Accuracy : 51.290%.
# Epoch 24/40 done. Train loss: 1.129 val loss: 1.386 Val. Accuracy : 51.410%.
# Epoch 25/40 done. Train loss: 1.116 val loss: 1.389 Val. Accuracy : 51.450%.
# Epoch 26/40 done. Train loss: 1.108 val loss: 1.378 Val. Accuracy : 51.610%.
# Epoch 27/40 done. Train loss: 1.100 val loss: 1.379 Val. Accuracy : 51.880%.
# Epoch 28/40 done. Train loss: 1.090 val loss: 1.380 Val. Accuracy : 51.720%.
# Epoch 29/40 done. Train loss: 1.078 val loss: 1.399 Val. Accuracy : 51.570%.
# Epoch 30/40 done. Train loss: 1.073 val loss: 1.380 Val. Accuracy : 51.310%.
# Epoch 31/40 done. Train loss: 1.061 val loss: 1.382 Val. Accuracy : 51.850%.
# Epoch 32/40 done. Train loss: 1.050 val loss: 1.406 Val. Accuracy : 51.370%.
# Epoch 33/40 done. Train loss: 1.044 val loss: 1.418 Val. Accuracy : 51.260%.
# Epoch 34/40 done. Train loss: 1.038 val loss: 1.388 Val. Accuracy : 51.980%.
# Epoch 35/40 done. Train loss: 1.025 val loss: 1.406 Val. Accuracy : 51.260%.
# Epoch 36/40 done. Train loss: 1.021 val loss: 1.415 Val. Accuracy : 51.200%.
# Epoch 37/40 done. Train loss: 1.014 val loss: 1.410 Val. Accuracy : 51.400%.
# Epoch 38/40 done. Train loss: 1.009 val loss: 1.405 Val. Accuracy : 51.610%.
# Epoch 39/40 done. Train loss: 1.000 val loss: 1.423 Val. Accuracy : 51.300%.
# Epoch 40/40 done. Train loss: 0.992 val loss: 1.430 Val. Accuracy : 51.450%.
# Starting run for: hiddensizes [64, 64], lr 0.005, momentum 0.9, wd 0.0001
# Epoch 1/40 done. Train loss: 2.035 val loss: 1.823 Val. Accuracy : 35.080%.
# Epoch 2/40 done. Train loss: 1.747 val loss: 1.674 Val. Accuracy : 40.810%.
# Epoch 3/40 done. Train loss: 1.638 val loss: 1.596 Val. Accuracy : 43.830%.
# Epoch 4/40 done. Train loss: 1.571 val loss: 1.550 Val. Accuracy : 45.530%.
# Epoch 5/40 done. Train loss: 1.521 val loss: 1.518 Val. Accuracy : 46.510%.
# Epoch 6/40 done. Train loss: 1.477 val loss: 1.489 Val. Accuracy : 47.860%.
# Epoch 7/40 done. Train loss: 1.440 val loss: 1.462 Val. Accuracy : 48.670%.
# Epoch 8/40 done. Train loss: 1.406 val loss: 1.445 Val. Accuracy : 49.260%.
# Epoch 9/40 done. Train loss: 1.376 val loss: 1.424 Val. Accuracy : 50.210%.
# Epoch 10/40 done. Train loss: 1.347 val loss: 1.419 Val. Accuracy : 50.210%.
# Epoch 11/40 done. Train loss: 1.323 val loss: 1.409 Val. Accuracy : 51.050%.
# Epoch 12/40 done. Train loss: 1.300 val loss: 1.402 Val. Accuracy : 51.000%.
# Epoch 13/40 done. Train loss: 1.279 val loss: 1.403 Val. Accuracy : 50.700%.
# Epoch 14/40 done. Train loss: 1.260 val loss: 1.411 Val. Accuracy : 50.680%.
# Epoch 15/40 done. Train loss: 1.244 val loss: 1.393 Val. Accuracy : 51.410%.
# Epoch 16/40 done. Train loss: 1.224 val loss: 1.399 Val. Accuracy : 50.610%.
# Epoch 17/40 done. Train loss: 1.207 val loss: 1.395 Val. Accuracy : 50.990%.
# Epoch 18/40 done. Train loss: 1.194 val loss: 1.396 Val. Accuracy : 51.070%.
# Epoch 19/40 done. Train loss: 1.181 val loss: 1.390 Val. Accuracy : 51.620%.
# Epoch 20/40 done. Train loss: 1.166 val loss: 1.406 Val. Accuracy : 51.180%.
# Epoch 21/40 done. Train loss: 1.152 val loss: 1.402 Val. Accuracy : 51.420%.
# Epoch 22/40 done. Train loss: 1.137 val loss: 1.405 Val. Accuracy : 51.310%.
# Epoch 23/40 done. Train loss: 1.126 val loss: 1.405 Val. Accuracy : 51.160%.
# Epoch 24/40 done. Train loss: 1.115 val loss: 1.408 Val. Accuracy : 51.840%.
# Epoch 25/40 done. Train loss: 1.104 val loss: 1.421 Val. Accuracy : 50.700%.
# Epoch 26/40 done. Train loss: 1.090 val loss: 1.421 Val. Accuracy : 51.620%.
# Epoch 27/40 done. Train loss: 1.081 val loss: 1.428 Val. Accuracy : 51.750%.
# Epoch 28/40 done. Train loss: 1.068 val loss: 1.439 Val. Accuracy : 51.030%.
# Epoch 29/40 done. Train loss: 1.061 val loss: 1.421 Val. Accuracy : 51.550%.
# Epoch 30/40 done. Train loss: 1.049 val loss: 1.432 Val. Accuracy : 51.120%.
# Epoch 31/40 done. Train loss: 1.041 val loss: 1.442 Val. Accuracy : 51.200%.
# Epoch 32/40 done. Train loss: 1.032 val loss: 1.456 Val. Accuracy : 50.950%.
# Epoch 33/40 done. Train loss: 1.018 val loss: 1.446 Val. Accuracy : 51.200%.
# Epoch 34/40 done. Train loss: 1.011 val loss: 1.449 Val. Accuracy : 51.320%.
# Epoch 35/40 done. Train loss: 1.005 val loss: 1.446 Val. Accuracy : 51.580%.
# Epoch 36/40 done. Train loss: 0.996 val loss: 1.455 Val. Accuracy : 51.340%.
# Epoch 37/40 done. Train loss: 0.979 val loss: 1.487 Val. Accuracy : 50.610%.
# Epoch 38/40 done. Train loss: 0.973 val loss: 1.473 Val. Accuracy : 51.380%.
# Epoch 39/40 done. Train loss: 0.965 val loss: 1.488 Val. Accuracy : 50.800%.
# Epoch 40/40 done. Train loss: 0.959 val loss: 1.481 Val. Accuracy : 51.350%.
# Starting run for: hiddensizes [64, 64], lr 0.01, momentum 0.9, wd 0.001
# Epoch 1/40 done. Train loss: 1.956 val loss: 1.715 Val. Accuracy : 38.920%.
# Epoch 2/40 done. Train loss: 1.654 val loss: 1.591 Val. Accuracy : 43.480%.
# Epoch 3/40 done. Train loss: 1.548 val loss: 1.520 Val. Accuracy : 46.560%.
# Epoch 4/40 done. Train loss: 1.475 val loss: 1.472 Val. Accuracy : 48.460%.
# Epoch 5/40 done. Train loss: 1.422 val loss: 1.441 Val. Accuracy : 48.680%.
# Epoch 6/40 done. Train loss: 1.379 val loss: 1.421 Val. Accuracy : 49.410%.
# Epoch 7/40 done. Train loss: 1.342 val loss: 1.410 Val. Accuracy : 50.760%.
# Epoch 8/40 done. Train loss: 1.310 val loss: 1.409 Val. Accuracy : 50.000%.
# Epoch 9/40 done. Train loss: 1.288 val loss: 1.394 Val. Accuracy : 50.470%.
# Epoch 10/40 done. Train loss: 1.258 val loss: 1.394 Val. Accuracy : 50.220%.
# Epoch 11/40 done. Train loss: 1.239 val loss: 1.392 Val. Accuracy : 50.440%.
# Epoch 12/40 done. Train loss: 1.219 val loss: 1.390 Val. Accuracy : 50.940%.
# Epoch 13/40 done. Train loss: 1.200 val loss: 1.389 Val. Accuracy : 50.610%.
# Epoch 14/40 done. Train loss: 1.179 val loss: 1.396 Val. Accuracy : 51.360%.
# Epoch 15/40 done. Train loss: 1.170 val loss: 1.384 Val. Accuracy : 51.360%.
# Epoch 16/40 done. Train loss: 1.152 val loss: 1.371 Val. Accuracy : 51.790%.
# Epoch 17/40 done. Train loss: 1.135 val loss: 1.378 Val. Accuracy : 51.200%.
# Epoch 18/40 done. Train loss: 1.121 val loss: 1.381 Val. Accuracy : 51.410%.
# Epoch 19/40 done. Train loss: 1.115 val loss: 1.391 Val. Accuracy : 51.210%.
# Epoch 20/40 done. Train loss: 1.100 val loss: 1.404 Val. Accuracy : 51.060%.
# Epoch 21/40 done. Train loss: 1.089 val loss: 1.394 Val. Accuracy : 51.180%.
# Epoch 22/40 done. Train loss: 1.075 val loss: 1.399 Val. Accuracy : 51.110%.
# Epoch 23/40 done. Train loss: 1.067 val loss: 1.379 Val. Accuracy : 51.310%.
# Epoch 24/40 done. Train loss: 1.057 val loss: 1.383 Val. Accuracy : 51.970%.
# Epoch 25/40 done. Train loss: 1.047 val loss: 1.381 Val. Accuracy : 51.910%.
# Epoch 26/40 done. Train loss: 1.033 val loss: 1.405 Val. Accuracy : 51.260%.
# Epoch 27/40 done. Train loss: 1.027 val loss: 1.391 Val. Accuracy : 52.050%.
# Epoch 28/40 done. Train loss: 1.018 val loss: 1.437 Val. Accuracy : 50.750%.
# Epoch 29/40 done. Train loss: 1.010 val loss: 1.410 Val. Accuracy : 51.230%.
# Epoch 30/40 done. Train loss: 1.008 val loss: 1.416 Val. Accuracy : 51.530%.
# Epoch 31/40 done. Train loss: 0.991 val loss: 1.427 Val. Accuracy : 51.640%.
# Epoch 32/40 done. Train loss: 0.985 val loss: 1.433 Val. Accuracy : 51.570%.
# Epoch 33/40 done. Train loss: 0.976 val loss: 1.436 Val. Accuracy : 51.520%.
# Epoch 34/40 done. Train loss: 0.970 val loss: 1.442 Val. Accuracy : 51.060%.
# Epoch 35/40 done. Train loss: 0.963 val loss: 1.449 Val. Accuracy : 50.990%.
# Epoch 36/40 done. Train loss: 0.957 val loss: 1.465 Val. Accuracy : 50.910%.
# Epoch 37/40 done. Train loss: 0.953 val loss: 1.449 Val. Accuracy : 50.960%.
# Epoch 38/40 done. Train loss: 0.944 val loss: 1.460 Val. Accuracy : 51.560%.
# Epoch 39/40 done. Train loss: 0.945 val loss: 1.485 Val. Accuracy : 50.430%.
# Epoch 40/40 done. Train loss: 0.938 val loss: 1.490 Val. Accuracy : 50.410%.
# Starting run for: hiddensizes [64, 64], lr 0.01, momentum 0.9, wd 0.0001
# Epoch 1/40 done. Train loss: 1.938 val loss: 1.716 Val. Accuracy : 39.510%.
# Epoch 2/40 done. Train loss: 1.650 val loss: 1.576 Val. Accuracy : 44.380%.
# Epoch 3/40 done. Train loss: 1.541 val loss: 1.520 Val. Accuracy : 46.110%.
# Epoch 4/40 done. Train loss: 1.473 val loss: 1.481 Val. Accuracy : 48.300%.
# Epoch 5/40 done. Train loss: 1.421 val loss: 1.444 Val. Accuracy : 48.700%.
# Epoch 6/40 done. Train loss: 1.376 val loss: 1.433 Val. Accuracy : 49.800%.
# Epoch 7/40 done. Train loss: 1.338 val loss: 1.401 Val. Accuracy : 50.580%.
# Epoch 8/40 done. Train loss: 1.311 val loss: 1.417 Val. Accuracy : 49.720%.
# Epoch 9/40 done. Train loss: 1.276 val loss: 1.392 Val. Accuracy : 50.900%.
# Epoch 10/40 done. Train loss: 1.255 val loss: 1.407 Val. Accuracy : 50.540%.
# Epoch 11/40 done. Train loss: 1.228 val loss: 1.379 Val. Accuracy : 51.450%.
# Epoch 12/40 done. Train loss: 1.204 val loss: 1.393 Val. Accuracy : 51.320%.
# Epoch 13/40 done. Train loss: 1.187 val loss: 1.391 Val. Accuracy : 50.910%.
# Epoch 14/40 done. Train loss: 1.168 val loss: 1.386 Val. Accuracy : 51.780%.
# Epoch 15/40 done. Train loss: 1.148 val loss: 1.391 Val. Accuracy : 51.790%.
# Epoch 16/40 done. Train loss: 1.134 val loss: 1.387 Val. Accuracy : 51.960%.
# Epoch 17/40 done. Train loss: 1.119 val loss: 1.402 Val. Accuracy : 51.600%.
# Epoch 18/40 done. Train loss: 1.102 val loss: 1.405 Val. Accuracy : 50.780%.
# Epoch 19/40 done. Train loss: 1.086 val loss: 1.414 Val. Accuracy : 51.740%.
# Epoch 20/40 done. Train loss: 1.075 val loss: 1.420 Val. Accuracy : 51.550%.
# Epoch 21/40 done. Train loss: 1.059 val loss: 1.421 Val. Accuracy : 51.960%.
# Epoch 22/40 done. Train loss: 1.047 val loss: 1.442 Val. Accuracy : 50.880%.
# Epoch 23/40 done. Train loss: 1.040 val loss: 1.470 Val. Accuracy : 50.350%.
# Epoch 24/40 done. Train loss: 1.022 val loss: 1.483 Val. Accuracy : 50.910%.
# Epoch 25/40 done. Train loss: 1.009 val loss: 1.457 Val. Accuracy : 50.740%.
# Epoch 26/40 done. Train loss: 1.003 val loss: 1.480 Val. Accuracy : 50.970%.
# Epoch 27/40 done. Train loss: 0.990 val loss: 1.479 Val. Accuracy : 51.260%.
# Epoch 28/40 done. Train loss: 0.980 val loss: 1.461 Val. Accuracy : 51.680%.
# Epoch 29/40 done. Train loss: 0.967 val loss: 1.495 Val. Accuracy : 50.630%.
# Epoch 30/40 done. Train loss: 0.960 val loss: 1.483 Val. Accuracy : 50.940%.
# Epoch 31/40 done. Train loss: 0.949 val loss: 1.496 Val. Accuracy : 51.280%.
# Epoch 32/40 done. Train loss: 0.938 val loss: 1.516 Val. Accuracy : 50.740%.
# Epoch 33/40 done. Train loss: 0.931 val loss: 1.544 Val. Accuracy : 49.720%.
# Epoch 34/40 done. Train loss: 0.921 val loss: 1.534 Val. Accuracy : 50.480%.
# Epoch 35/40 done. Train loss: 0.913 val loss: 1.513 Val. Accuracy : 51.100%.
# Epoch 36/40 done. Train loss: 0.902 val loss: 1.577 Val. Accuracy : 50.230%.
# Epoch 37/40 done. Train loss: 0.893 val loss: 1.550 Val. Accuracy : 50.790%.
# Epoch 38/40 done. Train loss: 0.886 val loss: 1.554 Val. Accuracy : 51.110%.
# Epoch 39/40 done. Train loss: 0.883 val loss: 1.568 Val. Accuracy : 50.740%.
# Epoch 40/40 done. Train loss: 0.870 val loss: 1.551 Val. Accuracy : 50.460%.

# %% [markdown]
# **Expected Output:** Your plots should look somewhat similar to this:
#
# ![Accuracy2.png](https://github.com/HHU-MMBS/Deep-Learning-Exercise-Extras/raw/main/a06_pytorch_mlp/images/Accuracy2.png)
