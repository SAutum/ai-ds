# %%
import numpy as np

# %%
w=100; h=80

# %%
I = np.zeros((h, w))
I[40:70, 30:60] = 1

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
plt.imshow(I, cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="640">
